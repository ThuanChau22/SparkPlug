# %% [markdown]
# ## Setup

# %%
import pandas as pd
import os
from dotenv import load_dotenv
import random
import mysql.connector
from mysql.connector import Error
import random

# %%
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Load environment variables from .env file
load_dotenv()

# Get the connection parameters from environment variables
host = os.getenv("DB_HOST")
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
database = os.getenv("DB_DATABASE")

# Create a connection to the MySQL database
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database
)

# %%
# Read the CSV file into a dataframe
file_path = 'data/g6stations.csv'
df = pd.read_csv(file_path)

# Handle missing values (NaN) in the dataframe
df = df.fillna('')

# Sort the dataframe by the "ID" column
df = df.sort_values(by='ID')

# Print the dataframe
print(df.head())
# Out:
#                          Station Name           Street Address         City  \
# 33723   Los Angeles Convention Center       1201 S Figueroa St  Los Angeles
# 36593  California Air Resources Board         9530 Telstar Ave     El Monte
# 37097          Scripps Green Hospital  10666 N Torrey Pines Rd     La Jolla
# 35965                   Galpin Motors        15421 Roscoe Blvd    Sepulveda
# 38171               Galleria at Tyler   1299 Galleria at Tyler    Riverside
#
#       State    ZIP EV Level1 EVSE Num EV Level2 EVSE Num EV DC Fast Count  \
# 33723    CA  90015                                   7.0
# 36593    CA  91731                                   3.0
# 37097    CA  92037                                   1.0
# 35965    CA  91343                                   2.0
# 38171    CA  92503                                   4.0
#
#        lvl 1 present  lvl 2 present  ...   Longitude    ID  \
# 33723          False           True  ... -118.271387  1523
# 36593          False           True  ... -118.064000  1583
# 37097          False           True  ... -117.243000  6355
# 35965          False           True  ... -118.468371  6405
# 38171          False           True  ... -117.459053  6425
#
#                     Updated At  Owner Type Code  EV Connector Types  \
# 33723  2023-02-14 15:54:11 UTC                P               J1772
# 36593  2023-02-14 15:54:11 UTC               SG               J1772
# 37097  2023-02-14 15:54:11 UTC                P               J1772
# 35965  2023-08-10 16:58:49 UTC                P               J1772
# 38171  2023-08-17 18:44:25 UTC                P               J1772
#
#         Facility Type         EV Pricing EV On-Site Renewable Source  \
# 33723  PARKING_GARAGE  Free; parking fee
# 36593       STATE_GOV               Free
# 37097        HOSPITAL  Free; parking fee
# 35965      CAR_DEALER
# 38171   SHOPPING_MALL               Free
#
#       Restricted Access Maximum Vehicle Class
# 33723             False                    LD
# 36593             False
# 37097             False
# 35965              True                    MD
# 38171             False
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Data Exploration

# %%
# Assuming your dataframe is named df and the relevant columns are 'Street Address', 'City', and 'State'
grouped = df.groupby(['Street Address', 'City', 'State']).size()

# DataFrame with counts
counts_df = grouped.reset_index(name='Count')

# Addresses with only one entry
single_entry_addresses = counts_df[counts_df['Count'] == 1]

# Addresses with multiple entries
multiple_entries_addresses = counts_df[counts_df['Count'] > 1]

# Display the results
print(f"Number of addresses with a single entry: {len(single_entry_addresses)}")
print(f"Number of addresses with multiple entries: {len(multiple_entries_addresses)}")

# Optionally, display the actual addresses
print(single_entry_addresses)
sorted_multiple_entries = multiple_entries_addresses.sort_values('Count', ascending=False)
print(sorted_multiple_entries)
# Out:
# Number of addresses with a single entry: 31080
# Number of addresses with multiple entries: 7579
#                      Street Address               City State  Count
# 0          #1 Business Loop 70 East           Columbia    MO      1
# 1            #42 Montana Highway 84             Norris    MT      1
# 2                            #NAME?  Carmel-By-The-Sea    CA      1
# 3      - Skyland Upper Loop Mile 41              Luray    VA      1
# 4                       0 Asbury St           Hamilton    MA      1
# ...                             ...                ...   ...    ...
# 38653       York St & Thornton Pkwy           Thornton    CO      1
# 38654         York St Thornton pkwy           Thornton    CO      1
# 38655                   Yosemite Rd             Fresno    CA      1
# 38657               atlas cedar way         Sacramento    CA      1
# 38658                   highway 190       Death Valley    CA      1
#
# [31080 rows x 4 columns]
#                               Street Address           City State  Count
# 4863                            1201 Pine St        Oakland    CA     81
# 18527                       2910 Tannery Way    Santa Clara    CA     79
# 174                           1 Facebook Way     Menlo Park    CA     57
# 34552  806 S Airport Blvd Long Term Garage 2  San Francisco    CA     57
# 20100                          3162 Olin Ave       San Jose    CA     49
# ...                                      ...            ...   ...    ...
# 9334                         1600 Willow Ave         Clovis    CA      2
# 22724                            381 Main St   West Newbury    MA      2
# 22723                381 Cherry Blossom Spur     Georgetown    KY      2
# 9350                     1601 Dean Forest Rd       Savannah    GA      2
# 19509                 3049 Country Club Road      Melbourne    FL      2
#
# [7579 rows x 4 columns]

# %%
# Specify the file path and name for the CSV file
output_file_path = 'sorted_multiple_entries.csv'

# Export the DataFrame to a CSV file
sorted_multiple_entries.to_csv(output_file_path, index=False)

print(f"Data exported to '{output_file_path}' successfully.")
# Out:
# Data exported to 'sorted_multiple_entries.csv' successfully.

# %% [markdown]
# ## Approach 1: Each row is a site, generate stations
# ### Previous approach, do not run

# %%
"""
def calculate_station_coordinates(base_lat, base_lon, station_index, total_stations):
    # Calculate row and column in a square grid
    grid_size = int(total_stations**0.5) + 1
    row = (station_index - 1) // grid_size
    col = (station_index - 1) % grid_size

    # Calculate the offset
    offset = 0.000022
    new_lat = base_lat + (offset * row) - (offset * grid_size / 2)
    new_lon = base_lon + (offset * col) - (offset * grid_size / 2)

    return new_lat, new_lon

statuses = ['Available', 'Occupied', 'Unavailable', 'Faulted', 'Offline']
weights = [0.6, 0.32, 0.04, 0.02, 0.02]

try:
    # Create a cursor object
    cursor = connection.cursor()

    # Iterate through each row of the dataframe
    for index, row in df.iterrows():
        # Generate a random owner_id between 1 and 10
        owner_id = random.randint(1, 10)
        
        # Extract the values from the row
        ID = row['ID']
        Latitude = row['Latitude']
        Longitude = row['Longitude']
        Station_Name = row['Station Name']
        Street_Address = row['Street Address']
        ZIP = row['ZIP']
        City = row['City']
        State = row['State']
        
        # Insert the values into the Site table
        query = "INSERT INTO Site (id, owner_id, latitude, longitude, name, street_address, zip_code, city, state) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"
        values = (ID, owner_id, Latitude, Longitude, Station_Name, Street_Address, ZIP, City, State)
        
        try:
            cursor.execute(query, values)
        except Error as e:
            print(f"Error: {e}")
        
        # Commit in batches
        if index % 100 == 0:
            connection.commit()

        # Calculate the total number of stations for this site
        level1_count = int(row['EV Level1 EVSE Num'] or 0)
        level2_count = int(row['EV Level2 EVSE Num'] or 0)
        dc_fast_count = int(row['EV DC Fast Count'] or 0)
        total_stations = level1_count + level2_count + dc_fast_count

        # Connector types mapping based on charge level
        connector_types_map = {
            1: ['J1772', 'NEMA515', 'NEMA520'],
            2: ['J1772', 'TESLA'],
            3: ['CHADEMO', 'J1772COMBO', 'TESLA']
        }

        # Current site connector types
        site_connector_types = row['EV Connector Types'].split()

        # Initialize station index
        station_index = 1

        # Assign a random status
        status = random.choices(statuses, weights, k=1)[0]

        # Generate stations
        for level, count in [(1, level1_count), (2, level2_count), (3, dc_fast_count)]:
            for _ in range(count):

                # Assign a random status
                status = random.choices(statuses, weights, k=1)[0]
                
                # Station details
                name = f"{row['Station Name']} {station_index}"
                charge_level = level
                connector_types = ' '.join([ct for ct in connector_types_map[level] if ct in site_connector_types])
                latitude, longitude = calculate_station_coordinates(row['Latitude'], row['Longitude'], station_index, total_stations)
                site_id = row['ID']

                # Insert station into the database
                station_query = "INSERT INTO Station (name, charge_level, connector_type, latitude, longitude, site_id, status) VALUES (%s, %s, %s, %s, %s, %s, %s)"
                station_values = (name, charge_level, connector_types, latitude, longitude, site_id, status)
                cursor.execute(station_query, station_values)

                # Increment station index
                station_index += 1

        # Commit after handling each site
        connection.commit()

    # Final commit for remaining rows
    connection.commit()
finally:
    # Close cursor and connection
    cursor.close()
    connection.close()
"""
# Out:
# '\ndef calculate_station_coordinates(base_lat, base_lon, station_index, total_stations):\n    # Calculate row and column in a square grid\n    grid_size = int(total_stations**0.5) + 1\n    row = (station_index - 1) // grid_size\n    col = (station_index - 1) % grid_size\n\n    # Calculate the offset\n    offset = 0.000022\n    new_lat = base_lat + (offset * row) - (offset * grid_size / 2)\n    new_lon = base_lon + (offset * col) - (offset * grid_size / 2)\n\n    return new_lat, new_lon\n\nstatuses = [\'Available\', \'Occupied\', \'Unavailable\', \'Faulted\', \'Offline\']\nweights = [0.6, 0.32, 0.04, 0.02, 0.02]\n\ntry:\n    # Create a cursor object\n    cursor = connection.cursor()\n\n    # Iterate through each row of the dataframe\n    for index, row in df.iterrows():\n        # Generate a random owner_id between 1 and 10\n        owner_id = random.randint(1, 10)\n        \n        # Extract the values from the row\n        ID = row[\'ID\']\n        Latitude = row[\'Latitude\']\n        Longitude = row[\'Longitude\']\n        Station_Name = row[\'Station Name\']\n        Street_Address = row[\'Street Address\']\n        ZIP = row[\'ZIP\']\n        City = row[\'City\']\n        State = row[\'State\']\n        \n        # Insert the values into the Site table\n        query = "INSERT INTO Site (id, owner_id, latitude, longitude, name, street_address, zip_code, city, state) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"\n        values = (ID, owner_id, Latitude, Longitude, Station_Name, Street_Address, ZIP, City, State)\n        \n        try:\n            cursor.execute(query, values)\n        except Error as e:\n            print(f"Error: {e}")\n        \n        # Commit in batches\n        if index % 100 == 0:\n            connection.commit()\n\n        # Calculate the total number of stations for this site\n        level1_count = int(row[\'EV Level1 EVSE Num\'] or 0)\n        level2_count = int(row[\'EV Level2 EVSE Num\'] or 0)\n        dc_fast_count = int(row[\'EV DC Fast Count\'] or 0)\n        total_stations = level1_count + level2_count + dc_fast_count\n\n        # Connector types mapping based on charge level\n        connector_types_map = {\n            1: [\'J1772\', \'NEMA515\', \'NEMA520\'],\n            2: [\'J1772\', \'TESLA\'],\n            3: [\'CHADEMO\', \'J1772COMBO\', \'TESLA\']\n        }\n\n        # Current site connector types\n        site_connector_types = row[\'EV Connector Types\'].split()\n\n        # Initialize station index\n        station_index = 1\n\n        # Assign a random status\n        status = random.choices(statuses, weights, k=1)[0]\n\n        # Generate stations\n        for level, count in [(1, level1_count), (2, level2_count), (3, dc_fast_count)]:\n            for _ in range(count):\n\n                # Assign a random status\n                status = random.choices(statuses, weights, k=1)[0]\n                \n                # Station details\n                name = f"{row[\'Station Name\']} {station_index}"\n                charge_level = level\n                connector_types = \' \'.join([ct for ct in connector_types_map[level] if ct in site_connector_types])\n                latitude, longitude = calculate_station_coordinates(row[\'Latitude\'], row[\'Longitude\'], station_index, total_stations)\n                site_id = row[\'ID\']\n\n                # Insert station into the database\n                station_query = "INSERT INTO Station (name, charge_level, connector_type, latitude, longitude, site_id, status) VALUES (%s, %s, %s, %s, %s, %s, %s)"\n                station_values = (name, charge_level, connector_types, latitude, longitude, site_id, status)\n                cursor.execute(station_query, station_values)\n\n                # Increment station index\n                station_index += 1\n\n        # Commit after handling each site\n        connection.commit()\n\n    # Final commit for remaining rows\n    connection.commit()\nfinally:\n    # Close cursor and connectio ...

# %% [markdown]
# ## Approach 2: Each row is a station, generate sites

# %%
def common_name(names):
    split_names = [name.lower().split() for name in names]
    common_prefix = os.path.commonprefix(split_names)
    return ' '.join(common_prefix).title()

# Extract unique site combinations and compute average latitude and longitude
unique_sites_df = df.groupby(['Street Address', 'City', 'State', 'ZIP']).agg({
    'Latitude': 'mean',
    'Longitude': 'mean',
    'Station Name': common_name
}).reset_index()
unique_sites_df.rename(columns={'Station Name': 'Name'}, inplace=True)

# %%
# Add sites to Site table and retrieve their IDs
try:
    cursor = connection.cursor()

    site_ids = {}
    site_count = 0 

    # Add sites to the Site table
    for _, site in unique_sites_df.iterrows():
        owner_id = random.randint(1, 10)  # Random owner_id for each site

        site_query = "INSERT INTO Site (owner_id, name, street_address, city, state, zip_code, latitude, longitude) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"
        site_values = (owner_id, site['Name'], site['Street Address'], site['City'], site['State'], site['ZIP'], site['Latitude'], site['Longitude'])
        cursor.execute(site_query, site_values)
        connection.commit()

        site_id = cursor.lastrowid
        site_key = f"{site['Street Address']}_{site['City']}_{site['State']}"
        site_ids[site_key] = site_id

        site_count += 1
        logging.info(f"Added site {site_count}: {site['Name']}")


except Error as e:
    logging.error(f"Error adding sites: {e}")
finally:
    cursor.close()
# Out:
# 2024-01-24 13:52:59,740 - INFO - Added site 1: Bob Mccosh Chevrolet Buick Gmc Cadillac
# 2024-01-24 13:52:59,859 - INFO - Added site 2: Norris Hot Springs
# 2024-01-24 13:52:59,979 - INFO - Added site 3: Carmel Plaza Garage - Tesla Destination
# 2024-01-24 13:53:00,102 - INFO - Added site 4: Shenandoah National Park - Skyland Resort - Tesla Destination
# 2024-01-24 13:53:00,226 - INFO - Added site 5: Hamilton Twnhll Patton Dcfc 01
# 2024-01-24 13:53:00,343 - INFO - Added site 6: Hamilton Twnhll Patton Dcfc 02
# 2024-01-24 13:53:00,464 - INFO - Added site 7: Mcca Bos Com
# 2024-01-24 13:53:00,588 - INFO - Added site 8: Mcca Bos Com
# 2024-01-24 13:53:00,709 - INFO - Added site 9: Ocean Key Resort And Spa - Tesla Destination
# 2024-01-24 13:53:00,845 - INFO - Added site 10: Ri Oer Hopkinton
# 2024-01-24 13:53:00,965 - INFO - Added site 11: Ri Oer Hopkinton Dcfc2
# 2024-01-24 13:53:01,084 - INFO - Added site 12: Garage At Po Sq Level 4-003Ab
# 2024-01-24 13:53:01,205 - INFO - Added site 13: Wmgld Quannapowitt #1
# 2024-01-24 13:53:01,325 - INFO - Added site 14: Wmgld Quannapowitt #2
# 2024-01-24 13:53:01,444 - INFO - Added site 15: Parker River Parker River
# 2024-01-24 13:53:01,564 - INFO - Added site 16: Warner Robins Public 1
# 2024-01-24 13:53:01,686 - INFO - Added site 17: The Ritz-Carlton, Bachelor Gulch - Tesla Destination
# 2024-01-24 13:53:01,807 - INFO - Added site 18: Greentree Eagle Greentree Eagle
# 2024-01-24 13:53:01,927 - INFO - Added site 19: Lewis & Clark College - Tesla Destination
# 2024-01-24 13:53:02,054 - INFO - Added site 20: Charlevoix Auto Chevrolet
# 2024-01-24 13:53:02,172 - INFO - Added site 21: Fort Knox
# 2024-01-24 13:53:02,298 - INFO - Added site 22: Fort Knox Obcrg#1
# 2024-01-24 13:53:02,423 - INFO - Added site 23: American Dream - Tesla Supercharger
# 2024-01-24 13:53:02,544 - INFO - Added site 24: Tree House Brewing Company, Western Mass - Tesla Destination
# 2024-01-24 13:53:02,664 - INFO - Added site 25: Huck'S - Tesla Supercharger
# 2024-01-24 13:53:02,784 - INFO - Added site 26: Wawa - Tesla Supercharger
# 2024-01-24 13:53:02,900 - INFO - Added site 27: Dunkin - Tesla Supercharger
# 2024-01-24 13:53:03,028 - INFO - Added site 28: Capital Gateway Station 5
# 2024-01-24 13:53:03,147 - INFO - Added site 29: Msc Garage 2Nd Floor Unit
# 2024-01-24 13:53:03,272 - INFO - Added site 30: County Of Marin W. Service Cent
# 2024-01-24 13:53:03,391 - INFO - Added site 31: Lake Worth Bch Golf Course
# 2024-01-24 13:53:03,515 - INFO - Added site 32: Aecc-Aeci Aecc Station 1
# 2024-01-24 13:53:03,631 - INFO - Added site 33: Fpl Evolution Embry Riddle
# 2024-01-24 13:53:03,750 - INFO - Added site 34: The Majestic Yosemite Hotel - Tesla Destination
# 2024-01-24 13:53:03,866 - INFO - Added site 35: 1 Ahwahnee Drive
# 2024-01-24 13:53:03,983 - INFO - Added site 36: Nara Parking Deck
# 2024-01-24 13:53:04,106 - INFO - Added site 37: Oakland International Airport -
# 2024-01-24 13:53:04,230 - INFO - Added site 38: Manchester-Boston Regional Airport
# 2024-01-24 13:53:04,347 - INFO - Added site 39: Savannah 1 Eastern Wharf
# 2024-01-24 13:53:04,468 - INFO - Added site 40: Reata Glen Health Center
# 2024-01-24 13:53:04,602 - INFO - Added site 41: Rmld Adi
# 2024-01-24 13:53:04,722 - INFO - Added site 42: The Inn On Biltmore Estate
# 2024-01-24 13:53:04,842 - INFO - Added site 43: Ppa Airport Ev Garage
# 2024-01-24 13:53:04,967 - INFO - Added site 44: Evergy @Stadiums
# 2024-01-24 13:53:05,089 - INFO - Added site 45: The Paddocks Of Saratoga
# 2024-01-24 13:53:05,208 - INFO - Added site 46: Acadia National Park - Winter Harbor Schoodic District
# 2024-01-24 13:53:05,327 - INFO - Added site 47: Ferguson Center Parking Deck
# 2024-01-24 13:53:05,448 - INFO - Added site 48: Station Carmel Sunset Center
# 2024-01-24 13:53:05,569 - INFO - Added site 49: Vermont State Employees Credit Union - West
# 2024-01-24 13:53:05,687 - INFO - Added site 50: Boardwalk Nissan
# 2024-01-24 13:53:05,809 - INFO - Added site 51: Courtyard Reno Downtown - Tesla Destination
# 2024-01-24 13:53:05,928 - INFO - Added site 52: Market 32 Ev Barney Rd
# 2024-01-24 13:53:06,053 - INFO - Added site 53: Bmp Ev Nfpa Ev
# 2024-01-24 13:53:06,173 - INFO - Added site 54: Baxter Dfg-G3-3Nw
# 2024-01-24 13:53:06,291 - INFO - Added site 55: Obur Station 3
# 2024-01-24 13:53:06,415 - INFO - Added site 56: The Elms The Elms
# 2024-01-24 13:53:06,539 - INFO - Added site 57: Bayfront Tower - P4 -
# 2024-01-24 13:53:06,661 - INFO - Added site 58: Laz1Beacon Beacon St Gw 1
# 2024-01-24 13:53:06,782 - INFO - Added site 59: One Beacon Garage - Tesla Destination
# 2024-01-24 13:53:06,907 - INFO - Added site 60: Point Reyes National Seashore - Bear Valley Visitor Center
# 2024-01-24 13:53:07,031 - INFO - Added site 61: Ikea Usa Brooklyn
# 2024-01-24 13:53:07,152 - INFO - Added site 62: Flks Campus Station
# 2024-01-24 13:53:07,275 - INFO - Added site 63: Bellis Fair
# 2024-01-24 13:53:07,410 - INFO - Added site 64: Hotel Bellwether - Tesla Destination
# 2024-01-24 13:53:07,535 - INFO - Added site 65: Boise State University - Lincoln Garage
# 2024-01-24 13:53:07,658 - INFO - Added site 66: Franklinwildcat Charger
# 2024-01-24 13:53:07,780 - INFO - Added site 67: Charles Hotel - Harvard Square
# 2024-01-24 13:53:07,906 - INFO - Added site 68: Big Canyon Country Club - Tesla Destination
# 2024-01-24 13:53:08,023 - INFO - Added site 69: Nbcsg Station
# 2024-01-24 13:53:08,156 - INFO - Added site 70: Blizzard Obw L1 01
# 2024-01-24 13:53:08,280 - INFO - Added site 71: One Blue Slip-Greenpoint - Tesla Destination
# 2024-01-24 13:53:08,409 - INFO - Added site 72: Ocean House - Tesla Destination
# 2024-01-24 13:53:08,528 - INFO - Added site 73: Borgata Hotel Casino & Spa - Tesla Destination
# 2024-01-24 13:53:08,653 - INFO - Added site 74: Boyne Mountain Resort - Tesla Destination
# 2024-01-24 13:53:08,774 - INFO - Added site 75: National Grid 1 Bridge Plaza
# 2024-01-24 13:53:08,901 - INFO - Added site 76: Obw Garage Obw Gar Ll
# 2024-01-24 13:53:09,018 - INFO - Added site 77: Wustl East End
# 2024-01-24 13:53:09,144 - INFO - Added site 78: Burns Mgt Sch Comm
# 2024-01-24 13:53:09,263 - INFO - Added site 79: Station 1 Marriott Burl
# 2024-01-24 13:53:09,388 - INFO - Added site 80: Robert Moses State Park Field 5
# 2024-01-24 13:53:09,512 - INFO - Added site 81: Tishman Speyer
# 2024-01-24 13:53:09,636 - INFO - Added site 82: Andrews Cadillac Company
# 2024-01-24 13:53:09,759 - INFO - Added site 83: Raley'S
# 2024-01-24 13:53:09,883 - INFO - Added site 84: Bcbst Ch5 P5 01 New Station 1
# 2024-01-24 13:53:10,008 - INFO - Added site 85: Safeway 0788 (Mill Valley, Ca)
# 2024-01-24 13:53:10,130 - INFO - Added site 86: Cityof Campbell Ccc Winchester
# 2024-01-24 13:53:10,252 - INFO - Added site 87: Csusm-Ps1
# 2024-01-24 13:53:10,374 - INFO - Added site 88: Massdot Sagamore Pr #1
# 2024-01-24 13:53:10,499 - INFO - Added site 89: Best Western Maple City Inn - Tesla Destination
# 2024-01-24 13:53:10,622 - INFO - Added site 90: Ri Energy
# 2024-01-24 13:53:10,747 - INFO - Added site 91: Pinehurst Country Club
# 2024-01-24 13:53:10,872 - INFO - Added site 92: The Wentworth Inn
# 2024-01-24 13:53:10,989 - INFO - Added site 93: Birch Hill Catering
# 2024-01-24 13:53:11,112 - INFO - Added site 94: Plainville Municipal Center
# 2024-01-24 13:53:11,238 - INFO - Added site 95: Ev Station At Post Office
# 2024-01-24 13:53:11,361 - INFO - Added site 96: Chaminade Resort & Spa - Tesla Destination
# 2024-01-24 13:53:11,483 - INFO - Added site 97: Phillipsacademy Andover Inn
# 2024-01-24 13:53:11,607 - INFO - Added site 98: The Platform
# 2024-01-24 13:53:11,731 - INFO - Added site 99: West Herr Auto E Syracuse Cp6K
# 2024-01-24 13:53:11,855 - INFO - Added site 100: Dch Station
# 2024-01-24 13:53:11,976 - INFO - Added site 101: Citizen’S Bank East Providence
# 2024-01-24 13:53:12,101 - INFO - Added site 102: One City Place Apartments
# 2024-01-24 13:53:12,225 - INFO - Added site 103:
# 2024-01-24 13:53:12,343 - INFO - Added site 104: Municipal Evse Cool Insuring
# 2024-01-24 13:53:12,468 - INFO - Added site 105: Irvine Civ Ctr
# 2024-01-24 13:53:12,591 - INFO - Added site 106: Snowbird Parking Structure, Level 2 - Tesla Destination
# 2024-01-24 13:53:12,715 - INFO - Added site 107: Scarsdale Golf Club
# 2024-01-24 13:53:12,836 - INFO - Added site 108: Pohanka Nissan - Stafford
# 2024-01-24 13:53:12,961 - INFO - Added site 109: Messiah College Messiah College
# 2024-01-24 13:53:13,080 - INFO - Added site 110: Pvccharging
# 2024-01-24 13:53:13,202 - INFO - Added site 111: Lot C Cougarplex
# 2024-01-24 13:53:13,322 - INFO - Added site 112: Greenfield Cc Greenfield Cc
# 2024-01-24 13:53:13,446 - INFO - Added site 113: Holy Cross Hogan Lot
# 2024-01-24 13:53:13,570 - INFO - Added site 114: Harbors
# 2024-01-24 13:53:13,716 - INFO - Added site 115: Bt Town Hall Bernards Twp1
# 2024-01-24 13:53:13,839 - INFO - Added site 116: Mclarty Nissan - Little Rock
# 2024-01-24 13:53:13,961 - INFO - Added site 117: Comfort Inn & Suites Butler Pa
# 2024-01-24 13:53:14,093 - INFO - Added site 118: Commonwealth Nissan
# 2024-01-24 13:53:14,216 - INFO - Added site 119: Facebook Oh Comm Circle
# 2024-01-24 13:53:14,334 - INFO - Added site 120: Deerfield Station2
# 2024-01-24 13:53:14,450 - INFO - Added site 121: Hosmer Sch Hosmer
# 2024-01-24 13:53:14,571 - INFO - Added site 122: M1 Concourse - Tesla Destination
# 2024-01-24 13:53:14,693 - INFO - Added site 123: National Great Rivers Research And Education Center
# 2024-01-24 13:53:14,808 - INFO - Added site 124: Milford Travel Plaza - Tesla Supercharger
# 2024-01-24 13:53:14,933 - INFO - Added site 125: Rochester Town Hall
# 2024-01-24 13:53:15,060 - INFO - Added site 126: Consumers Energy Co
# 2024-01-24 13:53:15,184 - INFO - Added site 127: Continental Corp
# 2024-01-24 13:53:15,306 - INFO - Added site 128: Pavilion
# 2024-01-24 13:53:15,427 - INFO - Added site 129: Lake Terrace Convention Center
# 2024-01-24 13:53:15,549 - INFO - Added site 130: Great Lakes Energy - Newaygo Service Center
# 2024-01-24 13:53:15,692 - INFO - Added site 131: Electric Cooperatives Of Arkansas - Tesla Destination
# 2024-01-24 13:53:15,815 - INFO - Added site 132: Walmart 4456 Somerdale
# 2024-01-24 13:53:15,939 - INFO - Added site 133: Rosewood Cordevalle - Tesla Destination
# 2024-01-24 13:53:16,063 - INFO - Added site 134: Tufts Cummings Mcgrath
# 2024-01-24 13:53:16,190 - INFO - Added site 135: Cbre 1Corporate Dr 1
# 2024-01-24 13:53:16,310 - INFO - Added site 136: Signature Flight Support Pdk - Tesla Destination
# 2024-01-24 13:53:16,434 - INFO - Added site 137: The Isle Apts Ev 1
# 2024-01-24 13:53:16,558 - INFO - Added site 138: Palmas Athletic Club -
# 2024-01-24 13:53:16,682 - INFO - Added site 139: Wspt20Vsp 1 Country View
# 2024-01-24 13:53:16,798 - INFO - Added site 140: Mccoart Bldg
# 2024-01-24 13:53:16,922 - INFO - Added site 141: Es1 Salida
# 2024-01-24 13:53:17,045 - INFO - Added site 142: Marlboroughma Court St
# 2024-01-24 13:53:17,168 - INFO - Added site 143: Ilani
# 2024-01-24 13:53:17,288 - INFO - Added site 144: Ilani 1B-1 Dual
# 2024-01-24 13:53:17,411 - INFO - Added site 145: Coyote Creek Golf Club - Tesla Destination
# 2024-01-24 13:53:17,534 - INFO - Added site 146: Hampton Inn Huntington/Barboursville - Tesla Destination
# 2024-01-24 13:53:17,651 - INFO - Added site 147: Sullivan Brothers Nissan
# 2024-01-24 13:53:17,769 - INFO - Added site 148: Highlawn Pavilion - Tesla Destination
# 2024-01-24 13:53:17,896 - INFO - Added site 149: Crossgates Mall
# 2024-01-24 13:53:18,018 - INFO - Added site 150: Crossgates Mall - Tesla Supercharger
# 2024-01-24 13:53:18,141 - INFO - Added site 151: Edg Park + Ride Edgartown
# 2024-01-24 13:53:18,267 - INFO - Added site 152: Town Hall 1 Town Hall 1
# 2024-01-24 13:53:18,392 - INFO - Added site 153: Gsa Building 48
# 2024-01-24 13:53:18,515 - INFO - Added site 154: Dtw Airport Mac Deck 8B1
# 2024-01-24 13:53:18,638 - INFO - Added site 155: Ulster County Dss
# 2024-01-24 13:53:18,761 - INFO - Added site 156: Seneca County Office Building
# 2024-01-24 13:53:18,890 - INFO - Added site 157: Dover Honda Station 1
# 2024-01-24 13:53:19,014 - INFO - Added site 158: Pier House Resort & Spa - Tesla Destination
# 2024-01-24 13:53:19,136 - INFO - Added site 159: Aaa North Penn - South Williamsport
# 2024-01-24 13:53:19,255 - INFO - Added site 160: Joyce Vineyards - Tesla Destination
# 2024-01-24 13:53:19,380 - INFO - Added site 161: Marriott Hotel - Underground Deck
# 2024-01-24 13:53:19,498 - INFO - Added site 162: One Lexington One
# 2024-01-24 13:53:19,614 - INFO - Added site 163: Mesa Arts Center
# 2024-01-24 13:53:19,740 - INFO - Added site 164: Nglenn Ev Stns Rec Center
# 2024-01-24 13:53:19,862 - INFO - Added site 165: Rhode Island Turnpike And Bridge Authority
# 2024-01-24 13:53:19,986 - INFO - Added site 166: Connecticut Welcome Center - Tesla Supercharger
# 2024-01-24 13:53:20,109 - INFO - Added site 167: City Scape East Garage
# 2024-01-24 13:53:20,235 - INFO - Added site 168: Espn Espn 11-1
# 2024-01-24 13:53:20,356 - INFO - Added site 169: Bvsd Broomfieldhigh1
# 2024-01-24 13:53:20,480 - INFO - Added site 170: 1 E 8Th St. Garage
# 2024-01-24 13:53:20,604 - INFO - Added site 171: Evergy @Westin
# 2024-01-24 13:53:20,724 - INFO - Added site 172: Summit Senior Life - Eastwyck
# 2024-01-24 13:53:20,848 - INFO - Added site 173: Elmer Street Lot
# 2024-01-24 13:53:20,975 - INFO - Added site 174: Ocean View
# 2024-01-24 13:53:21,096 - INFO - Added site 175: Espn Espn 11-2
# 2024-01-24 13:53:21,214 - INFO - Added site 176: Meta
# 2024-01-24 13:53:21,336 - INFO - Added site 177: Saugatuck Station – Lot 3
# 2024-01-24 13:53:21,458 - INFO - Added site 178: Beacon - Metro North Train Station
# 2024-01-24 13:53:21,581 - INFO - Added site 179: Ri Energy Roger Williams
# 2024-01-24 13:53:21,699 - INFO - Added site 180: National Grid Foxborough 99
# 2024-01-24 13:53:21,819 - INFO - Added site 181: Everglades National Park - Flamingo Visitor Center
# 2024-01-24 13:53:21,942 - INFO - Added site 182: 1 Flatiron Crossing
# 2024-01-24 13:53:22,074 - INFO - Added site 183: National Grid Comfort Inn
# 2024-01-24 13:53:22,191 - INFO - Added site 184: Saybrook Ford
# 2024-01-24 13:53:22,315 - INFO - Added site 185: 1Fordplace 1Fp Station 1
# 2024-01-24 13:53:22,432 - INFO - Added site 186: Esf Station
# 2024-01-24 13:53:22,555 - INFO - Added site 187: Esf Station 4
# 2024-01-24 13:53:22,676 - INFO - Added site 188: Esf Station
# 2024-01-24 13:53:22,804 - INFO - Added site 189: Savannah Harley-Davidson
# 2024-01-24 13:53:22,928 - INFO - Added site 190: Millennium Tower Boston -
# 2024-01-24 13:53:23,051 - INFO - Added site 191: Sandy Springsev City Springs
# 2024-01-24 13:53:23,174 - INFO - Added site 192: Westfield Garden State Plaza (Paramus, Nj)
# 2024-01-24 13:53:23,292 - INFO - Added site 193: Westfield Gsp Gsp Charger
# 2024-01-24 13:53:23,414 - INFO - Added site 194: Swansea Ev Char Admin Ev
# 2024-01-24 13:53:23,539 - INFO - Added site 195: 1 Garret Mountain Office Center
# 2024-01-24 13:53:23,664 - INFO - Added site 196: University Of California - Davis - Lot 55
# 2024-01-24 13:53:23,785 - INFO - Added site 197: Ramada Wyndham Station
# 2024-01-24 13:53:23,909 - INFO - Added site 198: 1 Generoso Pope Place
# 2024-01-24 13:53:24,036 - INFO - Added site 199: Regeneron
# 2024-01-24 13:53:24,161 - INFO - Added site 200: Gurney'S Resort, Newport - Tesla Destination
# 2024-01-24 13:53:24,288 - INFO - Added site 201: Si - Station 1 Station 1
# 2024-01-24 13:53:24,411 - INFO - Added site 202: Rincon_Public Ev Station
# 2024-01-24 13:53:24,538 - INFO - Added site 203: Calpoly Ps 131
# 2024-01-24 13:53:24,658 - INFO - Added site 204: Calpoly Grand Ev4
# 2024-01-24 13:53:24,777 - INFO - Added site 205: Calpoly Grand Ev3
# 2024-01-24 13:53:24,896 - INFO - Added site 206: Hyatt Grand Grand Cypress
# 2024-01-24 13:53:25,016 - INFO - Added site 207: Meta Mpk18-03
# 2024-01-24 13:53:25,138 - INFO - Added site 208: Meta
# 2024-01-24 13:53:25,260 - INFO - Added site 209: Meta
# 2024-01-24 13:53:25,377 - INFO - Added site 210: Meta
# 2024-01-24 13:53:25,501 - INFO - Added site 211: Meta
# 2024-01-24 13:53:25,625 - INFO - Added site 212: Meta
# 2024-01-24 13:53:25,749 - INFO - Added site 213: Meta
# 2024-01-24 13:53:25,870 - INFO - Added site 214: Meta
# 2024-01-24 13:53:25,994 - INFO - Added site 215: Meta Mpk14-04
# 2024-01-24 13:53:26,120 - INFO - Added site 216: Meta Mpk17-11
# 2024-01-24 13:53:26,237 - INFO - Added site 217: Meta Mpk17-01 Fc
# 2024-01-24 13:53:26,357 - INFO - Added site 218: Townofhalfmoon Justice 3
# 2024-01-24 13:53:26,488 - INFO - Added site 219: Hauke Park Hauke Park 1
# 2024-01-24 13:53:26,610 - INFO - Added site 220: Hamlin Beach State Park Camping
# 2024-01-24 13:53:26,732 - INFO - Added site 221: Seneca Harbor Park
# 2024-01-24 13:53:26,851 - INFO - Added site 222: Shelter Cove Harbour - Tesla Destination
# 2024-01-24 13:53:26,986 - INFO - Added site 223: Humboldt State University - Schatz Energy Research Center
# 2024-01-24 13:53:27,111 - INFO - Added site 224: Hsu
# 2024-01-24 13:53:27,237 - INFO - Added site 225: Hsu G12-2
# 2024-01-24 13:53:27,358 - INFO - Added site 226: Bne Master Harrison 2
# 2024-01-24 13:53:27,479 - INFO - Added site 227: University Of North Alabama - Parking Lot
# 2024-01-24 13:53:27,605 - INFO - Added site 228: Bge Mud Chase Lea 1
# 2024-01-24 13:53:27,728 - INFO - Added site 229: Target
# 2024-01-24 13:53:27,852 - INFO - Added site 230: National Grid Sustainability
# 2024-01-24 13:53:27,973 - INFO - Added site 231: Mitimco
# 2024-01-24 13:53:28,093 - INFO - Added site 232: Hepburn Library Of Norfolk
# 2024-01-24 13:53:28,212 - INFO - Added site 233: Pbmc Physicians Lot3
# 2024-01-24 13:53:28,335 - INFO - Added site 234: Hotel Mtk
# 2024-01-24 13:53:28,459 - INFO - Added site 235: Wally’S
# 2024-01-24 13:53:28,582 - INFO - Added site 236: Moody Gardens - Tesla Destination
# 2024-01-24 13:53:28,703 - INFO - Added site 237: Massena Hospital
# 2024-01-24 13:53:28,828 - INFO - Added site 238: Ikea Usa Stoughton
# 2024-01-24 13:53:28,952 - INFO - Added site 239: Town Hall 1 Independence Hill
# 2024-01-24 13:53:29,076 - INFO - Added site 240: Tob Chargers Ev Station
# 2024-01-24 13:53:29,198 - INFO - Added site 241: Pacific Palms Resort - Tesla Destination
# 2024-01-24 13:53:29,324 - INFO - Added site 242: Signal Mountain Lodge
# 2024-01-24 13:53:29,447 - INFO - Added site 243: Ip Garage Ip Station
# 2024-01-24 13:53:29,572 - INFO - Added site 244: Terminal Garage
# 2024-01-24 13:53:29,922 - INFO - Added site 245: Jerseycity Annex Kearney
# 2024-01-24 13:53:30,039 - INFO - Added site 246: Spwd Stewart Cc&M
# 2024-01-24 13:53:30,163 - INFO - Added site 247: Jlrchesterfield Wallbox Outside
# 2024-01-24 13:53:30,284 - INFO - Added site 248: Jlrchesterfield Station 2
# 2024-01-24 13:53:30,411 - INFO - Added site 249: Jlrchesterfield Station 01
# 2024-01-24 13:53:30,535 - INFO - Added site 250: Municipal Lot 2 Muni Lot 2 St1
# 2024-01-24 13:53:30,660 - INFO - Added site 251: Ouc Oia
# 2024-01-24 13:53:30,779 - INFO - Added site 252: Promedica Parking Garage
# 2024-01-24 13:53:30,906 - INFO - Added site 253: Jelly Belly
# 2024-01-24 13:53:31,031 - INFO - Added site 254: Braintree Town Hall 1
# 2024-01-24 13:53:31,156 - INFO - Added site 255: Marshall University - Corbly Hall
# 2024-01-24 13:53:31,290 - INFO - Added site 256: Johnson & Johnson Headquarters
# 2024-01-24 13:53:31,415 - INFO - Added site 257: Livewell Group Clubhouse
# 2024-01-24 13:53:31,538 - INFO - Added site 258: Long Beach Junipero
# 2024-01-24 13:53:31,663 - INFO - Added site 259: Amangiri - Tesla Destination
# 2024-01-24 13:53:31,795 - INFO - Added site 260: Market 32 Ev Malta Ev Charge
# 2024-01-24 13:53:31,916 - INFO - Added site 261: Utica City Hall City Of Utica
# 2024-01-24 13:53:32,037 - INFO - Added site 262: The Kensington At Halfmoon
# 2024-01-24 13:53:32,161 - INFO - Added site 263: Four Seasons Sensei
# 2024-01-24 13:53:32,284 - INFO - Added site 264: Kettering Health Piqua
# 2024-01-24 13:53:32,407 - INFO - Added site 265: Lmu Uhall P2
# 2024-01-24 13:53:32,536 - INFO - Added site 266: The Broadmoor - Tesla Destination
# 2024-01-24 13:53:32,656 - INFO - Added site 267: The Ritz Carlton Reynolds, Lake Oconee - Tesla Destination
# 2024-01-24 13:53:32,780 - INFO - Added site 268: Renaissance Reno Downtown Hotel & Spa
# 2024-01-24 13:53:32,899 - INFO - Added site 269: Grandeville At Malta Building
# 2024-01-24 13:53:33,022 - INFO - Added site 270: Moenkopi Legacy Inn & Suites - Tesla Destination
# 2024-01-24 13:53:33,145 - INFO - Added site 271:
# 2024-01-24 13:53:33,283 - INFO - Added site 272: City Of Millbrae - Library
# 2024-01-24 13:53:33,408 - INFO - Added site 273: Georgetown Town Hall
# 2024-01-24 13:53:33,535 - INFO - Added site 274: One Light Street
# 2024-01-24 13:53:33,663 - INFO - Added site 275: Parking Garage1 Parking Garage
# 2024-01-24 13:53:33,783 - INFO - Added site 276: State Street Financial Center Parking
# 2024-01-24 13:53:33,905 - INFO - Added site 277: The Hinckley Company - Tesla Destination
# 2024-01-24 13:53:34,022 - INFO - Added site 278: Locey Lane
# 2024-01-24 13:53:34,145 - INFO - Added site 279: Locks Plaza Lock Plaza
# 2024-01-24 13:53:34,269 - INFO - Added site 280: Rochester Institute Of Technology - Lot
# 2024-01-24 13:53:34,396 - INFO - Added site 281: Sag Harbor Long Wharf
# 2024-01-24 13:53:34,515 - INFO - Added site 282: National Grid Rockland
# 2024-01-24 13:53:34,636 - INFO - Added site 283: Msl
# 2024-01-24 13:53:34,761 - INFO - Added site 284: The Plaza Hotel And Casino - Tesla Destination
# 2024-01-24 13:53:34,884 - INFO - Added site 285: Rio Vista City Hall
# 2024-01-24 13:53:35,007 - INFO - Added site 286: Town Of Stafford - Town Hall
# 2024-01-24 13:53:35,137 - INFO - Added site 287: Stockton Inn - Tesla Destination
# 2024-01-24 13:53:35,266 - INFO - Added site 288: Four Seasons Resort At Manele Bay
# 2024-01-24 13:53:35,390 - INFO - Added site 289: Strong Museum Strong L1
# 2024-01-24 13:53:35,514 - INFO - Added site 290: White Plains
# 2024-01-24 13:53:35,640 - INFO - Added site 291: Michaelsgrp Michaels Group2
# 2024-01-24 13:53:35,759 - INFO - Added site 292: Michaelsgrp Michaels Group1
# 2024-01-24 13:53:35,883 - INFO - Added site 293: Manchester Grand Hyatt
# 2024-01-24 13:53:36,006 - INFO - Added site 294: The Lyme Inn - Tesla Destination
# 2024-01-24 13:53:36,130 - INFO - Added site 295: Towneplace11735 Towne Place
# 2024-01-24 13:53:36,252 - INFO - Added site 296: Willingboro Twp Willingboro Ps1
# 2024-01-24 13:53:36,376 - INFO - Added site 297: 1 Mather Business Center
# 2024-01-24 13:53:36,515 - INFO - Added site 298: Met Center Station 1
# 2024-01-24 13:53:36,643 - INFO - Added site 299: Wake Forest Baptist Health - Parking Deck C
# 2024-01-24 13:53:36,763 - INFO - Added site 300: Ed Phys Lot Smhc Ed
# 2024-01-24 13:53:36,888 - INFO - Added site 301:
# 2024-01-24 13:53:37,010 - INFO - Added site 302: Dh-Lebanon A-1
# 2024-01-24 13:53:37,134 - INFO - Added site 303: Omd Owner, Llc
# 2024-01-24 13:53:37,257 - INFO - Added site 304: Delamar West Hartford - Tesla Destination
# 2024-01-24 13:53:37,378 - INFO - Added site 305: Mboc Way Dc250 1
# 2024-01-24 13:53:37,502 - INFO - Added site 306: Meta Mpk20.3-07
# 2024-01-24 13:53:37,626 - INFO - Added site 307: Ontario Mills - Skechers
# 2024-01-24 13:53:37,748 - INFO - Added site 308: The Ritz-Carlton, Half Moon Bay + Golf Links - Tesla Destination
# 2024-01-24 13:53:37,874 - INFO - Added site 309: Mohegan Sun - Tesla Destination
# 2024-01-24 13:53:38,000 - INFO - Added site 310: Monarch Beach Resort - Tesla Destination
# 2024-01-24 13:53:38,119 - INFO - Added site 311: Montebello Village Hall 1
# 2024-01-24 13:53:38,238 - INFO - Added site 312: Public Parking Lot
# 2024-01-24 13:53:38,355 - INFO - Added site 313: Mt. Washington Auto Road - Tesla Destination
# 2024-01-24 13:53:38,479 - INFO - Added site 314: Mount Washington Auto Road
# 2024-01-24 13:53:38,603 - INFO - Added site 315: Shagbark Lumber And Farm Supply
# 2024-01-24 13:53:38,723 - INFO - Added site 316:
# 2024-01-24 13:53:38,847 - INFO - Added site 317: City Of Beacon Station 2
# 2024-01-24 13:53:38,969 - INFO - Added site 318: Museumofscience
# 2024-01-24 13:53:39,092 - INFO - Added site 319: Corning Museum Of Glass - Welcome Center
# 2024-01-24 13:53:39,216 - INFO - Added site 320: Golden Gate Park - Music Concourse Garage
# 2024-01-24 13:53:39,340 - INFO - Added site 321: Mustang Village Chargepoint 3
# 2024-01-24 13:53:39,467 - INFO - Added site 322: Nissan Of Lafayette
# 2024-01-24 13:53:39,592 - INFO - Added site 323: The Ritz-Carlton, Fort Lauderdale - Tesla Destination
# 2024-01-24 13:53:39,716 - INFO - Added site 324: Food Bank Station
# 2024-01-24 13:53:39,841 - INFO - Added site 325: Pupatella - Tesla Destination
# 2024-01-24 13:53:39,966 - INFO - Added site 326: Spirep Iron Works
# 2024-01-24 13:53:40,090 - INFO - Added site 327: Garden Garage
# 2024-01-24 13:53:40,218 - INFO - Added site 328: Enel X - Questa Visitor Center
# 2024-01-24 13:53:40,352 - INFO - Added site 329: Level P3 Station
# 2024-01-24 13:53:40,488 - INFO - Added site 330: Level P3 Station 1
# 2024-01-24 13:53:40,611 - INFO - Added site 331: Tag Complex Bluff Rd Tmp
# 2024-01-24 13:53:40,735 - INFO - Added site 332: Far View Lodge - Tesla Destination
# 2024-01-24 13:53:40,859 - INFO - Added site 333: Tioga State Forest - Pine Creek Rail Trail
# 2024-01-24 13:53:40,985 - INFO - Added site 334: Salem Mass Museum Place
# 2024-01-24 13:53:41,108 - INFO - Added site 335: Bar Harbor Inn & Spa
# 2024-01-24 13:53:41,231 - INFO - Added site 336: Nichols Landing Hampton Inn
# 2024-01-24 13:53:41,355 - INFO - Added site 337: Town Hall Of Niskayuna
# 2024-01-24 13:53:41,479 - INFO - Added site 338: Nissan North America
# 2024-01-24 13:53:41,600 - INFO - Added site 339: Red Hawk Deck Red Hawk Deck
# 2024-01-24 13:53:41,724 - INFO - Added site 340:
# 2024-01-24 13:53:41,841 - INFO - Added site 341: Plaza At Oceanside
# 2024-01-24 13:53:41,960 - INFO - Added site 342: Ba Plaza Ba Plaza
# 2024-01-24 13:53:42,083 - INFO - Added site 343: Boro Of Oxford 1St Flr Station
# 2024-01-24 13:53:42,210 - INFO - Added site 344: Town Of Medway Choate Park
# 2024-01-24 13:53:42,332 - INFO - Added site 345: Lexington Ma Depot Sq 1
# 2024-01-24 13:53:42,450 - INFO - Added site 346: Old Bridge Twp Municomplex
# 2024-01-24 13:53:42,572 - INFO - Added site 347: Carmel Valley Ranch - Tesla Destination
# 2024-01-24 13:53:42,696 - INFO - Added site 348: Cv Ranch Station
# 2024-01-24 13:53:42,819 - INFO - Added site 349: Ontario Mills Mall
# 2024-01-24 13:53:42,949 - INFO - Added site 350: Smld Town Hall
# 2024-01-24 13:53:43,069 - INFO - Added site 351: Simon - Jersey Shore Premium Outlets (Tinton Fall
# 2024-01-24 13:53:43,192 - INFO - Added site 352: Cebe River Park
# 2024-01-24 13:53:43,317 - INFO - Added site 353: Port Of San Diego - Hilton San Diego Bayfront
# 2024-01-24 13:53:43,435 - INFO - Added site 354: Tannersville Town Hall
# 2024-01-24 13:53:43,555 - INFO - Added site 355: Picotte Park Place 1
# 2024-01-24 13:53:43,682 - INFO - Added site 356: Irvine Co Ofc 1 Park Plaza
# 2024-01-24 13:53:43,806 - INFO - Added site 357: Hcab1 Station
# 2024-01-24 13:53:43,924 - INFO - Added site 358: Pefo Pdo1
# 2024-01-24 13:53:44,050 - INFO - Added site 359: Kia Of Sav Main Charger
# 2024-01-24 13:53:44,174 - INFO - Added site 360: Hna Main Hna Main
# 2024-01-24 13:53:44,300 - INFO - Added site 361: Wood-Ridge Station 3
# 2024-01-24 13:53:44,419 - INFO - Added site 362:
# 2024-01-24 13:53:44,544 - INFO - Added site 363: Turner Parking Ramp
# 2024-01-24 13:53:44,668 - INFO - Added site 364: Summit Senior Life - Saratoga
# 2024-01-24 13:53:44,792 - INFO - Added site 365: Cole Group English
# 2024-01-24 13:53:44,915 - INFO - Added site 366: Shutters On The Beach Hotel - Tesla Destination
# 2024-01-24 13:53:45,037 - INFO - Added site 367: Lewis Nissan
# 2024-01-24 13:53:45,157 - INFO - Added site 368: Mass Audubon Joppa Flats
# 2024-01-24 13:53:45,282 - INFO - Added site 369: Salem Mass Bertram
# 2024-01-24 13:53:45,406 - INFO - Added site 370: Prairie Meadows Racetrack And Casino - Tesla Destination
# 2024-01-24 13:53:45,531 - INFO - Added site 371: Jersey Shore Premium Outlet
# 2024-01-24 13:53:45,656 - INFO - Added site 372: Jersey Shore Premium Outlets - Tesla Supercharger
# 2024-01-24 13:53:45,775 - INFO - Added site 373: Wrentham Village Premium Outlets (Wrentham, Ma)
# 2024-01-24 13:53:45,896 - INFO - Added site 374: Vacaville Mob
# 2024-01-24 13:53:46,022 - INFO - Added site 375: Kaiser Vacaville
# 2024-01-24 13:53:46,146 - INFO - Added site 376: Ku Ku Office
# 2024-01-24 13:53:46,292 - INFO - Added site 377: Lake Phoenix
# 2024-01-24 13:53:46,416 - INFO - Added site 378: City Of Albany Station 2
# 2024-01-24 13:53:46,544 - INFO - Added site 379: City Of Albany Station 1
# 2024-01-24 13:53:46,669 - INFO - Added site 380: City Of Milford - Train Station Parking
# 2024-01-24 13:53:46,793 - INFO - Added site 381: Town Of Westport - Westport Metro North
# 2024-01-24 13:53:46,912 - INFO - Added site 382: City Of Methuen High School
# 2024-01-24 13:53:47,031 - INFO - Added site 383: Red Hawk Casino
# 2024-01-24 13:53:47,152 - INFO - Added site 384: Cisco Brewery
# 2024-01-24 13:53:47,277 - INFO - Added site 385: Ep Building
# 2024-01-24 13:53:47,397 - INFO - Added site 386: Spin Test Facility
# 2024-01-24 13:53:47,521 - INFO - Added site 387: Elm Ave
# 2024-01-24 13:53:47,643 - INFO - Added site 388: Pmvp-Cp1 Pmvpcps01
# 2024-01-24 13:53:47,779 - INFO - Added site 389: Ceb Bldg
# 2024-01-24 13:53:47,899 - INFO - Added site 390: Reserve - Club Reserve-Club
# 2024-01-24 13:53:48,023 - INFO - Added site 391: Westin Savannah Harbor Golf Resort & Spa - Tesla Destination
# 2024-01-24 13:53:48,143 - INFO - Added site 392: Willingboro Twp Willingboro Ps2
# 2024-01-24 13:53:48,270 - INFO - Added site 393: The Ritz-Carlton, Kapalua - Tesla Destination
# 2024-01-24 13:53:48,396 - INFO - Added site 394: Courtyard By Marriott Hamilton - Tesla Destination
# 2024-01-24 13:53:48,515 - INFO - Added site 395: Blossburg
# 2024-01-24 13:53:48,633 - INFO - Added site 396: Hawthorne-Hawthorne - Tesla Destination
# 2024-01-24 13:53:48,755 - INFO - Added site 397: Townofross
# 2024-01-24 13:53:48,875 - INFO - Added site 398: Northampton Roundhouse_Row1
# 2024-01-24 13:53:49,001 - INFO - Added site 399: Bethlehem Pa Commons Garage
# 2024-01-24 13:53:49,123 - INFO - Added site 400: Afp Ev Chargers Nongateway
# 2024-01-24 13:53:49,248 - INFO - Added site 401: Market 32 Ev Barney Rd
# 2024-01-24 13:53:49,371 - INFO - Added site 402: Creekside Commons Pocket Park
# 2024-01-24 13:53:49,517 - INFO - Added site 403: Hilton St. Louis At The Ballpark - Tesla Destination
# 2024-01-24 13:53:49,638 - INFO - Added site 404:
# 2024-01-24 13:53:49,762 - INFO - Added site 405: One South Wacke Osw Station #1
# 2024-01-24 13:53:49,881 - INFO - Added site 406: Mobile Convent Ctr 1
# 2024-01-24 13:53:50,001 - INFO - Added site 407: 531006 : Oregon Health & Science University
# 2024-01-24 13:53:50,121 - INFO - Added site 408: Bge-Maryland Zoo
# 2024-01-24 13:53:50,238 - INFO - Added site 409: Public Stations Central Park #1
# 2024-01-24 13:53:50,359 - INFO - Added site 410: Irvine Co Ofc 800 Scd 03
# 2024-01-24 13:53:50,483 - INFO - Added site 411: Sanctuary At Kiawah Island Golf Resort - Tesla Destination
# 2024-01-24 13:53:50,603 - INFO - Added site 412: Phipps Conservatory And Botanical Gardens
# 2024-01-24 13:53:50,728 - INFO - Added site 413: Bne Master Hillsborough
# 2024-01-24 13:53:50,852 - INFO - Added site 414: Seaport Garage
# 2024-01-24 13:53:50,971 - INFO - Added site 415: Seascape Beach Resort - Tesla Destination
# 2024-01-24 13:53:51,095 - INFO - Added site 416: Seminole Hard Rock Hotel & Casino - Tesla Destination
# 2024-01-24 13:53:51,229 - INFO - Added site 417: Seton Hill Elot Station 1
# 2024-01-24 13:53:51,366 - INFO - Added site 418: Purgatory Purgatory
# 2024-01-24 13:53:51,487 - INFO - Added site 419: Sky River Ev
# 2024-01-24 13:53:51,607 - INFO - Added site 420: Sky River Ev
# 2024-01-24 13:53:51,732 - INFO - Added site 421: Skytop Lodge - Tesla Destination
# 2024-01-24 13:53:51,851 - INFO - Added site 422: The Garrison And Highlands Country Club - Tesla Destination
# 2024-01-24 13:53:51,972 - INFO - Added site 423: Suny New Paltz Elting Gym
# 2024-01-24 13:53:52,095 - INFO - Added site 424: Sunrise Solars Apartments
# 2024-01-24 13:53:52,216 - INFO - Added site 425: Adelphi Univ Station
# 2024-01-24 13:53:52,334 - INFO - Added site 426: Applegreen Electric I-95 Madison Sb Service Plaza
# 2024-01-24 13:53:52,460 - INFO - Added site 427: Abessinio Llc Stadium
# 2024-01-24 13:53:52,580 - INFO - Added site 428: Metro Center Garage
# 2024-01-24 13:53:52,700 - INFO - Added site 429: Lot E
# 2024-01-24 13:53:52,820 - INFO - Added site 430: Macy'S
# 2024-01-24 13:53:52,941 - INFO - Added site 431: Woodman'S 44
# 2024-01-24 13:53:53,060 - INFO - Added site 432: Fishkill Sumone
# 2024-01-24 13:53:53,184 - INFO - Added site 433: The Summit
# 2024-01-24 13:53:53,310 - INFO - Added site 434: Sun Valley Resort - Tesla Destination
# 2024-01-24 13:53:53,428 - INFO - Added site 435: Bvsd Nederland E1
# 2024-01-24 13:53:53,552 - INFO - Added site 436: Best Western Sunridge Inn - Tesla Supercharger
# 2024-01-24 13:53:53,677 - INFO - Added site 437: Cedar Lakes Estate - Tesla Destination
# 2024-01-24 13:53:53,801 - INFO - Added site 438: Irvine Co Ofc Otp Bldg J
# 2024-01-24 13:53:53,922 - INFO - Added site 439: Garage 1
# 2024-01-24 13:53:54,052 - INFO - Added site 440: Nissan Stadium
# 2024-01-24 13:53:54,172 - INFO - Added site 441: Town Of Mp Tmp Station
# 2024-01-24 13:53:54,300 - INFO - Added site 442: Th 001
# 2024-01-24 13:53:54,422 - INFO - Added site 443: Town Of Brooksville Maine
# 2024-01-24 13:53:54,540 - INFO - Added site 444: Town Of Dyer - Town Hall
# 2024-01-24 13:53:54,670 - INFO - Added site 445: Cityofmurrieta
# 2024-01-24 13:53:54,790 - INFO - Added site 446: 7Spc Nasa Ussrc
# 2024-01-24 13:53:54,915 - INFO - Added site 447: Ccrta
# 2024-01-24 13:53:55,040 - INFO - Added site 448: Greater Hartford Transit District - Spruce
# 2024-01-24 13:53:55,168 - INFO - Added site 449: One University One University
# 2024-01-24 13:53:55,307 - INFO - Added site 450: Western Illinois University - Spencer Recreation Center
# 2024-01-24 13:53:55,429 - INFO - Added site 451: California State University - Stanislaus
# 2024-01-24 13:53:55,550 - INFO - Added site 452: California State University - Channel Islands
# 2024-01-24 13:53:55,670 - INFO - Added site 453: Unc Asheville P19
# 2024-01-24 13:53:55,791 - INFO - Added site 454: The Grand Station 2-0678
# 2024-01-24 13:53:55,912 - INFO - Added site 455: Four Seasons Vail - Tesla Destination
# 2024-01-24 13:53:56,036 - INFO - Added site 456: Municipal Bldg Public - B
# 2024-01-24 13:53:56,156 - INFO - Added site 457: Biden Ng/Rc
# 2024-01-24 13:53:56,277 - INFO - Added site 458: Vermella Union Union A-2
# 2024-01-24 13:53:56,397 - INFO - Added site 459: Vermella Union Station 2
# 2024-01-24 13:53:56,522 - INFO - Added site 460: Greece Town Hal Greece
# 2024-01-24 13:53:56,645 - INFO - Added site 461: Bridgewater Twp Station 2
# 2024-01-24 13:53:56,768 - INFO - Added site 462: Jamestown Bpu 1 W 2Nd St #1
# 2024-01-24 13:53:56,889 - INFO - Added site 463: Jamestown Bpu 1 W 2Nd St #2
# 2024-01-24 13:53:57,011 - INFO - Added site 464: Cp Ev Chadwick
# 2024-01-24 13:53:57,132 - INFO - Added site 465: Cityof Campbell Com Ctr H1-03
# 2024-01-24 13:53:57,259 - INFO - Added site 466: Free Charging Coldwater Ev2
# 2024-01-24 13:53:57,384 - INFO - Added site 467: Milan Village Village Charger
# 2024-01-24 13:53:57,508 - INFO - Added site 468: Boroughofparamu Paramus Pub St1
# 2024-01-24 13:53:57,630 - INFO - Added site 469: Gateway Center Newport
# 2024-01-24 13:53:57,746 - INFO - Added site 470: Mhm Wall Street
# 2024-01-24 13:53:57,864 - INFO - Added site 471: Chase Center Area C Zone 1-1
# 2024-01-24 13:53:57,989 - INFO - Added site 472: Tolth Town Hall 1
# 2024-01-24 13:53:58,109 - INFO - Added site 473: Dunwoodie Golf Course
# 2024-01-24 13:53:58,232 - INFO - Added site 474: The Frederick Motor Co - Ford
# 2024-01-24 13:53:58,354 - INFO - Added site 475: Connecticut Welcome Center - Tesla Supercharger
# 2024-01-24 13:53:58,478 - INFO - Added site 476: Macerich Flatiron Crossing (Broomfield, Co)
# 2024-01-24 13:53:58,600 - INFO - Added site 477: Maverick Corp
# 2024-01-24 13:53:58,724 - INFO - Added site 478: Maverick Mav Hq 1
# 2024-01-24 13:53:58,844 - INFO - Added site 479: Parkwood Village
# 2024-01-24 13:53:58,968 - INFO - Added site 480: Hartford Bmw Abb Outside
# 2024-01-24 13:53:59,089 - INFO - Added site 481: Mercercountynj Pcc Ps1
# 2024-01-24 13:53:59,216 - INFO - Added site 482: Proterra J1772_Gvl_Ac2
# 2024-01-24 13:53:59,336 - INFO - Added site 483: Pittsburgh Zoo
# 2024-01-24 13:53:59,456 - INFO - Added site 484: Embarc Palm Desert - Tesla Destination
# 2024-01-24 13:53:59,575 - INFO - Added site 485:
# 2024-01-24 13:53:59,704 - INFO - Added site 486: Rosenblum300 1 Winners
# 2024-01-24 13:53:59,824 - INFO - Added site 487: Winter Creek
# 2024-01-24 13:53:59,947 - INFO - Added site 488:
# 2024-01-24 13:54:00,070 - INFO - Added site 489: Los Angeles International Airport (Lax) - Lot
# 2024-01-24 13:54:00,190 - INFO - Added site 490: Wynfield Apartments
# 2024-01-24 13:54:00,312 - INFO - Added site 491: Miami Valley Hospital - Physician'S Lot
# 2024-01-24 13:54:00,436 - INFO - Added site 492: Clines Corners Travel Center
# 2024-01-24 13:54:00,556 - INFO - Added site 493: Yavapi Lodge At Grand Canyon - Tesla Destination
# 2024-01-24 13:54:00,680 - INFO - Added site 494: York Beach Mall
# 2024-01-24 13:54:00,805 - INFO - Added site 495: Zion National Park Lodge
# 2024-01-24 13:54:00,923 - INFO - Added site 496: Enel X - Little Rock Zoo
# 2024-01-24 13:54:01,040 - INFO - Added site 497: Burns Mgt Sch Comm Bldg 3
# 2024-01-24 13:54:01,163 - INFO - Added site 498: Burns Mgt Sch Comm Bldg 2
# 2024-01-24 13:54:01,283 - INFO - Added site 499: Cpp Clubhouse Station
# 2024-01-24 13:54:01,405 - INFO - Added site 500: Harvest Inn
# 2024-01-24 13:54:01,523 - INFO - Added site 501: Town Los Gatos Station 1
# 2024-01-24 13:54:01,644 - INFO - Added site 502: Town Los Gatos Station 2
# 2024-01-24 13:54:01,768 - INFO - Added site 503: Lpea Parking Station
# 2024-01-24 13:54:01,893 - INFO - Added site 504: Mpg 1-50 51St Ave - Tesla Destination
# 2024-01-24 13:54:02,012 - INFO - Added site 505: Hunters Point South Crossing
# 2024-01-24 13:54:02,136 - INFO - Added site 506: Pompton Lakes Towne Square Shopping Mall - Tesla Supercharger
# 2024-01-24 13:54:02,255 - INFO - Added site 507: Town Of Putnam Kennedy Dr Lot
# 2024-01-24 13:54:02,377 - INFO - Added site 508: Madison Service Plaza (Nb) - Tesla Supercharger
# 2024-01-24 13:54:02,504 - INFO - Added site 509: Madison Service Plaza (Sb) - Tesla Supercharger
# 2024-01-24 13:54:02,630 - INFO - Added site 510: Cok City Hall
# 2024-01-24 13:54:02,756 - INFO - Added site 511: Carta W11Th St @Broad
# 2024-01-24 13:54:02,881 - INFO - Added site 512: Knighton Garage
# 2024-01-24 13:54:03,002 - INFO - Added site 513: Ten10Thstreet Evse01
# 2024-01-24 13:54:03,138 - INFO - Added site 514: Mc Dt City Hall Mason City Hl 2
# 2024-01-24 13:54:03,258 - INFO - Added site 515: Darien 10 1St Street W
# 2024-01-24 13:54:03,377 - INFO - Added site 516: 10 Airline Dr
# 2024-01-24 13:54:03,501 - INFO - Added site 517: Alexander Nissan
# 2024-01-24 13:54:03,620 - INFO - Added site 518: Equity Office
# 2024-01-24 13:54:03,738 - INFO - Added site 519: Yale Ami
# 2024-01-24 13:54:03,860 - INFO - Added site 520: Obe Power Ten Aragon
# 2024-01-24 13:54:03,985 - INFO - Added site 521: Retreat At Arden Farms
# 2024-01-24 13:54:04,114 - INFO - Added site 522: Arnold St. Municipal Lot
# 2024-01-24 13:54:04,237 - INFO - Added site 523: Beverwyck Station 3
# 2024-01-24 13:54:04,364 - INFO - Added site 524: County Of Marin Exhibit Hall
# 2024-01-24 13:54:04,486 - INFO - Added site 525: Tfma Tfma
# 2024-01-24 13:54:04,606 - INFO - Added site 526: Bjc Thanks You Ct4021
# 2024-01-24 13:54:04,724 - INFO - Added site 527: Doubletree By Hilton Hotel Bloomington - Tesla Destination
# 2024-01-24 13:54:04,848 - INFO - Added site 528: Rumford Information Center Parking Lot
# 2024-01-24 13:54:04,965 - INFO - Added site 529: Yankee Doodle Garage
# 2024-01-24 13:54:05,088 - INFO - Added site 530: The Cambium
# 2024-01-24 13:54:05,215 - INFO - Added site 531: Camelot Court Station 1
# 2024-01-24 13:54:05,332 - INFO - Added site 532: Massdot Sagamore Pr #5
# 2024-01-24 13:54:05,456 - INFO - Added site 533: Nyc Fleet
# 2024-01-24 13:54:05,576 - INFO - Added site 534: Mantown01944
# 2024-01-24 13:54:05,704 - INFO - Added site 535: Claflin Street Lot
# 2024-01-24 13:54:05,826 - INFO - Added site 536: Folsom Lake College
# 2024-01-24 13:54:05,948 - INFO - Added site 537: Manhattan Parking Group
# 2024-01-24 13:54:06,074 - INFO - Added site 538: City Of Gr Mgr Gallery Place
# 2024-01-24 13:54:06,200 - INFO - Added site 539: Cobscook Institute
# 2024-01-24 13:54:06,329 - INFO - Added site 540: Plymouth Cordage Park
# 2024-01-24 13:54:06,448 - INFO - Added site 541: Deering Street Parking Lot
# 2024-01-24 13:54:06,570 - INFO - Added site 542: Aer Aec Ship Dist
# 2024-01-24 13:54:06,686 - INFO - Added site 543: Mpg 10 E 102Nd Street - Tesla Destination
# 2024-01-24 13:54:06,819 - INFO - Added site 544:
# 2024-01-24 13:54:06,940 - INFO - Added site 545: Icon Parking 1056 5Th Avenue - Tesla Destination
# 2024-01-24 13:54:07,063 - INFO - Added site 546: Alderbrook Resort & Spa - Tesla Destination
# 2024-01-24 13:54:07,188 - INFO - Added site 547: The Roundhouse
# 2024-01-24 13:54:07,306 - INFO - Added site 548: Walmart 5168 - Richfield, Ut
# 2024-01-24 13:54:07,432 - INFO - Added site 549: Cole Group Highland 2
# 2024-01-24 13:54:07,553 - INFO - Added site 550: Education First Hult House
# 2024-01-24 13:54:07,670 - INFO - Added site 551: Ulysses Town Ulysses
# 2024-01-24 13:54:07,792 - INFO - Added site 552: Fan Pier E Station
# 2024-01-24 13:54:07,912 - INFO - Added site 553: Fenton Ev Charging
# 2024-01-24 13:54:08,033 - INFO - Added site 554: Rochester Ny Sisters City 2
# 2024-01-24 13:54:08,158 - INFO - Added site 555: Ri Energy Fort Adams
# 2024-01-24 13:54:08,278 - INFO - Added site 556: Apex
# 2024-01-24 13:54:08,410 - INFO - Added site 557: Entergy No Lvl2 Cty Pk Shelter2
# 2024-01-24 13:54:08,534 - INFO - Added site 558: Entergy No Lvl2 Cty Pk Shelter1
# 2024-01-24 13:54:08,651 - INFO - Added site 559: 10 G Street, Ne
# 2024-01-24 13:54:08,768 - INFO - Added site 560: Masparc Gainsborough
# 2024-01-24 13:54:08,884 - INFO - Added site 561: Doubletree By Hilton Hattiesburg - Tesla Destination
# 2024-01-24 13:54:09,008 - INFO - Added site 562: Price Chopper
# 2024-01-24 13:54:09,128 - INFO - Added site 563: Emerald Grande At Harborwalk Village - Tesla Destination
# 2024-01-24 13:54:09,249 - INFO - Added site 564: 10 Higgins Farm Rd
# 2024-01-24 13:54:09,368 - INFO - Added site 565: Danvers Electri Hobart 1
# 2024-01-24 13:54:09,488 - INFO - Added site 566: Hampton Inn & Suites Carson City - Tesla Destination
# 2024-01-24 13:54:09,607 - INFO - Added site 567: The Westin Copley Place - Tesla Destination
# 2024-01-24 13:54:09,729 - INFO - Added site 568: Bmw Motor Werks Mw Outside
# 2024-01-24 13:54:09,849 - INFO - Added site 569: 10 Independence Broad 10.Ind
# 2024-01-24 13:54:10,004 - INFO - Added site 570: Habitat Education Center And Wildlife Sanctuary
# 2024-01-24 13:54:10,124 - INFO - Added site 571: Bne Master Fairfield
# 2024-01-24 13:54:10,247 - INFO - Added site 572: Gavin Park
# 2024-01-24 13:54:10,380 - INFO - Added site 573: Lincoln Place Station 1
# 2024-01-24 13:54:10,501 - INFO - Added site 574: Stablegate Farm & Vineyard
# 2024-01-24 13:54:10,619 - INFO - Added site 575: The Jewish Home At Rockleigh
# 2024-01-24 13:54:10,740 - INFO - Added site 576: Firaxis Games
# 2024-01-24 13:54:10,869 - INFO - Added site 577: Clarkstown Toc
# 2024-01-24 13:54:10,997 - INFO - Added site 578: Pah Main
# 2024-01-24 13:54:11,114 - INFO - Added site 579: New Horizon School And Community Center
# 2024-01-24 13:54:11,247 - INFO - Added site 580: 10 Marine Way
# 2024-01-24 13:54:11,369 - INFO - Added site 581: Johnston Ferri
# 2024-01-24 13:54:11,489 - INFO - Added site 582: Mick
# 2024-01-24 13:54:11,616 - INFO - Added site 583: U Of R Aoc
# 2024-01-24 13:54:11,742 - INFO - Added site 584: Venditio Llc
# 2024-01-24 13:54:11,864 - INFO - Added site 585: Newark Train Station
# 2024-01-24 13:54:11,984 - INFO - Added site 586: Mdot Fairfield Tc
# 2024-01-24 13:54:12,104 - INFO - Added site 587: Bedford-Evs Town Hall 2021
# 2024-01-24 13:54:12,228 - INFO - Added site 588: Hamilton College-Campus Safety
# 2024-01-24 13:54:12,351 - INFO - Added site 589: City Of Zeeland North Parking
# 2024-01-24 13:54:12,477 - INFO - Added site 590: Liberty Empire Mssu
# 2024-01-24 13:54:12,619 - INFO - Added site 591: Mill Street Lot - Tesla Destination
# 2024-01-24 13:54:12,739 - INFO - Added site 592: Wharton Cha Urban Renewal
# 2024-01-24 13:54:12,852 - INFO - Added site 593: 10 N Martingale Wpoc 10 Garage
# 2024-01-24 13:54:12,978 - INFO - Added site 594: The Oxford Hotel - Tesla Destination
# 2024-01-24 13:54:13,103 - INFO - Added site 595: New King Holding Llc
# 2024-01-24 13:54:13,226 - INFO - Added site 596: The Giant Company #6117
# 2024-01-24 13:54:13,348 - INFO - Added site 597: Woodbridge Town Library
# 2024-01-24 13:54:13,475 - INFO - Added site 598: Middleborough Town Hall Lot
# 2024-01-24 13:54:13,602 - INFO - Added site 599: Barnard Way Hoa Station
# 2024-01-24 13:54:13,723 - INFO - Added site 600: Manitousprings Hiawatha Ty2E
# 2024-01-24 13:54:13,849 - INFO - Added site 601: Lia Nissan - Enfield
# 2024-01-24 13:54:13,971 - INFO - Added site 602: 10 Park Plaza 10 Pug #1
# 2024-01-24 13:54:14,092 - INFO - Added site 603: Uc Santabarbara 10 Parking :
# 2024-01-24 13:54:14,216 - INFO - Added site 604: Big Y Foods Lee #37
# 2024-01-24 13:54:14,340 - INFO - Added site 605: Big Y Supermarket - Tesla Supercharger
# 2024-01-24 13:54:14,471 - INFO - Added site 606: Beverly 10 Pond Street
# 2024-01-24 13:54:14,596 - INFO - Added site 607: Portofino Island Resort -
# 2024-01-24 13:54:14,714 - INFO - Added site 608: Nemepa Nemepa Customer
# 2024-01-24 13:54:14,836 - INFO - Added site 609: Montage Health - Rr 10 Ragsdale
# 2024-01-24 13:54:14,958 - INFO - Added site 610: 1 Waterline
# 2024-01-24 13:54:15,080 - INFO - Added site 611: Riverton Commons Shopping Center - Tesla Destination
# 2024-01-24 13:54:15,202 - INFO - Added site 612: 10 Riverton Commons Drive
# 2024-01-24 13:54:15,321 - INFO - Added site 613: Hotel Domestique - Tesla Destination
# 2024-01-24 13:54:15,444 - INFO - Added site 614: Rosedale Center Station
# 2024-01-24 13:54:15,567 - INFO - Added site 615: Carytown Parking Lot
# 2024-01-24 13:54:15,692 - INFO - Added site 616: Town Of Mansfield - Community Center
# 2024-01-24 13:54:15,815 - INFO - Added site 617: Swtch Energy
# 2024-01-24 13:54:15,940 - INFO - Added site 618: Lake Worth Bch Beach Complex
# 2024-01-24 13:54:16,064 - INFO - Added site 619: The Davenport Hotel - Tesla Destination
# 2024-01-24 13:54:16,186 - INFO - Added site 620: 10 St James Parking Garage
# 2024-01-24 13:54:16,314 - INFO - Added site 621: Arlington Ma Schoulercourt
# 2024-01-24 13:54:16,438 - INFO - Added site 622: Cazenovia College
# 2024-01-24 13:54:16,561 - INFO - Added site 623: Upper Lofts
# 2024-01-24 13:54:16,686 - INFO - Added site 624: Suny New Paltz Wallkill 3
# 2024-01-24 13:54:16,804 - INFO - Added site 625: Fairfield Inn And Suites Savannah Airport - Tesla Destination
# 2024-01-24 13:54:16,932 - INFO - Added site 626: Town Of Maynard Vets Park
# 2024-01-24 13:54:17,054 - INFO - Added site 627: Marriott'S Surfwatch - Tesla Destination
# 2024-01-24 13:54:17,176 - INFO - Added site 628: Avondale Estates
# 2024-01-24 13:54:17,318 - INFO - Added site 629: City Of Boston Muni Lot 8
# 2024-01-24 13:54:17,445 - INFO - Added site 630: 10 Tara Blvd
# 2024-01-24 13:54:17,568 - INFO - Added site 631: Fairbanks Museu Station 1
# 2024-01-24 13:54:17,685 - INFO - Added site 632: Washington Plaza Hotel - Tesla Destination
# 2024-01-24 13:54:17,811 - INFO - Added site 633: Hampton Inn - Albany
# 2024-01-24 13:54:17,936 - INFO - Added site 634: 10Ucp Prkg Lvl 5 -
# 2024-01-24 13:54:18,062 - INFO - Added site 635: Gaithersburg
# 2024-01-24 13:54:18,189 - INFO - Added site 636: Mom'S Organic Market - Gaithersburg
# 2024-01-24 13:54:18,310 - INFO - Added site 637: Ipark 10 West 15Th - Tesla Destination
# 2024-01-24 13:54:18,431 - INFO - Added site 638: Autel - Red Roof Plus+
# 2024-01-24 13:54:18,565 - INFO - Added site 639: Ggmc Parking 10 W 66Th St Garage - Tesla Destination
# 2024-01-24 13:54:18,686 - INFO - Added site 640: Lawson Parking Ramp
# 2024-01-24 13:54:18,804 - INFO - Added site 641: Epb Parking Garage
# 2024-01-24 13:54:18,940 - INFO - Added site 642: Mtower 139 Garage
# 2024-01-24 13:54:19,064 - INFO - Added site 643: Cascade Parking Deck
# ...
# 2024-01-24 14:51:36,627 - INFO - Added site 29288: Entergy No Lvl2 Press Drive 1
# 2024-01-24 14:51:36,747 - INFO - Added site 29289: Comfort Inn & Suites
# 2024-01-24 14:51:36,872 - INFO - Added site 29290: Hcp San Diego 6195 Lusk - 2
# 2024-01-24 14:51:36,988 - INFO - Added site 29291: 5718 Westheiner
# 2024-01-24 14:51:37,105 - INFO - Added site 29292: Old Town Square Station
# 2024-01-24 14:51:37,221 - INFO - Added site 29293: Colony Palms Hotel - Tesla Destination
# 2024-01-24 14:51:37,340 - INFO - Added site 29294: St Francisville Inn & Hotel
# 2024-01-24 14:51:37,457 - INFO - Added site 29295: Bmw Of Fremont Station Sa01
# 2024-01-24 14:51:37,583 - INFO - Added site 29296: Eastsky Terano
# 2024-01-24 14:51:37,701 - INFO - Added site 29297: The Civic At Frisco Square, Llc
# 2024-01-24 14:51:37,820 - INFO - Added site 29298: Landsford Inn
# 2024-01-24 14:51:37,936 - INFO - Added site 29299: Evergy @Menorh
# 2024-01-24 14:51:38,059 - INFO - Added site 29300: H-D Frederick Dcfast Hog
# 2024-01-24 14:51:38,177 - INFO - Added site 29301: Yucca Valley, Ca - Tesla Supercharger
# 2024-01-24 14:51:38,296 - INFO - Added site 29302: Fairfield Inn And Suites Jackson - Tesla Destination
# 2024-01-24 14:51:38,416 - INFO - Added site 29303: Aptiv
# 2024-01-24 14:51:38,536 - INFO - Added site 29304: Jbg Smith Burke Centre (Burke, Va)
# 2024-01-24 14:51:38,657 - INFO - Added site 29305: Regency Twin Oaks Sc (Agoura Hills, Ca)
# 2024-01-24 14:51:38,777 - INFO - Added site 29306: Town Of Yucca Valley- Branch Library
# 2024-01-24 14:51:38,904 - INFO - Added site 29307: Galveston Jc Station 1
# 2024-01-24 14:51:39,021 - INFO - Added site 29308: 5729 Vineland Ave
# 2024-01-24 14:51:39,138 - INFO - Added site 29309: Lau Hala Shops Station
# 2024-01-24 14:51:39,257 - INFO - Added site 29310: Orange Stations Northside Ev2
# 2024-01-24 14:51:39,377 - INFO - Added site 29311: Stella Car
# 2024-01-24 14:51:39,494 - INFO - Added site 29312: Orange Stations Northside Ev1
# 2024-01-24 14:51:39,611 - INFO - Added site 29313: Shangri-La Resort - Tesla Destination
# 2024-01-24 14:51:39,738 - INFO - Added site 29314: Nissan Of Opelousas
# 2024-01-24 14:51:39,856 - INFO - Added site 29315: Te Connectivity-Hemet - Tesla Destination
# 2024-01-24 14:51:39,977 - INFO - Added site 29316: Wawa - Tesla Supercharger
# 2024-01-24 14:51:40,096 - INFO - Added site 29317: Evergy @Menorh
# 2024-01-24 14:51:40,215 - INFO - Added site 29318: City Of New Haven - Sherman Tyler Lot
# 2024-01-24 14:51:40,332 - INFO - Added site 29319: Township Of Maplewood
# 2024-01-24 14:51:40,454 - INFO - Added site 29320: Three Rivers Community College
# 2024-01-24 14:51:40,575 - INFO - Added site 29321: 574 W 10Th St
# 2024-01-24 14:51:40,690 - INFO - Added site 29322: Ku Ukcornerstoneg1
# 2024-01-24 14:51:40,809 - INFO - Added site 29323: Hospital Sjhmc_6 Av 5Fl
# 2024-01-24 14:51:40,926 - INFO - Added site 29324: Front Lot Cpe250 #1
# 2024-01-24 14:51:41,040 - INFO - Added site 29325: Merriam Marketplace
# 2024-01-24 14:51:41,159 - INFO - Added site 29326: Baton Rouge South Lot
# 2024-01-24 14:51:41,277 - INFO - Added site 29327: Valley Water
# 2024-01-24 14:51:41,397 - INFO - Added site 29328: Quicklees22
# 2024-01-24 14:51:41,513 - INFO - Added site 29329: 7Charge - Sarasota
# 2024-01-24 14:51:41,633 - INFO - Added site 29330: Tco Stillwater Tco Stillwater
# 2024-01-24 14:51:41,755 - INFO - Added site 29331: Lkt South 3
# 2024-01-24 14:51:41,873 - INFO - Added site 29332:
# 2024-01-24 14:51:41,991 - INFO - Added site 29333: Wedgewood Lodge Wedgewood 1 & 2
# 2024-01-24 14:51:42,113 - INFO - Added site 29334: County Sonoma Gsd Bos
# 2024-01-24 14:51:42,232 - INFO - Added site 29335: Bellevue Place Bell Place
# 2024-01-24 14:51:42,349 - INFO - Added site 29336: Lkt
# 2024-01-24 14:51:42,486 - INFO - Added site 29337: University Mall Shopping Center/University Place - Tesla Destination
# 2024-01-24 14:51:42,605 - INFO - Added site 29338: The Pump House Restaurant - Tesla Destination
# 2024-01-24 14:51:42,728 - INFO - Added site 29339: Plug In Erie Coal Creek Park
# 2024-01-24 14:51:42,845 - INFO - Added site 29340: Chico Nissan
# 2024-01-24 14:51:42,963 - INFO - Added site 29341: Lakeshore Ev Station
# 2024-01-24 14:51:43,085 - INFO - Added site 29342: Middle Country Selden
# 2024-01-24 14:51:43,202 - INFO - Added site 29343: Utah State University - Life Sciences
# 2024-01-24 14:51:43,319 - INFO - Added site 29344: Carmel Redmills Realty
# 2024-01-24 14:51:43,436 - INFO - Added site 29345: 575 State Hwy 46 South
# 2024-01-24 14:51:43,554 - INFO - Added site 29346: Gov Annex Countyofanson
# 2024-01-24 14:51:43,673 - INFO - Added site 29347: Fremont High School
# 2024-01-24 14:51:43,792 - INFO - Added site 29348: Parkit 575 Washington - Tesla Destination
# 2024-01-24 14:51:43,909 - INFO - Added site 29349: 575 West 575 West
# 2024-01-24 14:51:44,028 - INFO - Added site 29350: Town Of Fraser Lions Ponds
# 2024-01-24 14:51:44,146 - INFO - Added site 29351: Holiday Inn Guin - Tesla Supercharger
# 2024-01-24 14:51:44,264 - INFO - Added site 29352: Valley Water Station
# 2024-01-24 14:51:44,383 - INFO - Added site 29353: Home2 Suites By Hilton Nampa - Tesla Destination
# 2024-01-24 14:51:44,505 - INFO - Added site 29354: The Alaire
# 2024-01-24 14:51:44,624 - INFO - Added site 29355: Johnston Hy-Vee
# 2024-01-24 14:51:44,743 - INFO - Added site 29356: Nissani Brothers Nissan
# 2024-01-24 14:51:44,863 - INFO - Added site 29357: Save Mart 651 (Fresno, Ca)
# 2024-01-24 14:51:44,980 - INFO - Added site 29358: Harmswood Office Center
# 2024-01-24 14:51:45,098 - INFO - Added site 29359: Continental Nissan
# 2024-01-24 14:51:45,216 - INFO - Added site 29360: Hjaia Hjaia Fs 32
# 2024-01-24 14:51:45,335 - INFO - Added site 29361: Killington Ski Resort (Skyeship) - Tesla Destination
# 2024-01-24 14:51:45,455 - INFO - Added site 29362: State Farm
# 2024-01-24 14:51:45,574 - INFO - Added site 29363: Circle K - Tesla Supercharger
# 2024-01-24 14:51:45,691 - INFO - Added site 29364: Loop - Union Bank
# 2024-01-24 14:51:45,809 - INFO - Added site 29365: Autonation Chevrolet Greenacres
# 2024-01-24 14:51:45,946 - INFO - Added site 29366: Wild Dunes Resort, A Destination Hotel - Tesla Destination
# 2024-01-24 14:51:46,064 - INFO - Added site 29367: Star Nissan
# 2024-01-24 14:51:46,185 - INFO - Added site 29368: 5757 Wilshire Ev Station
# 2024-01-24 14:51:46,302 - INFO - Added site 29369: Mufg Union Bank
# 2024-01-24 14:51:46,420 - INFO - Added site 29370: Target - Tesla Supercharger
# 2024-01-24 14:51:46,540 - INFO - Added site 29371: 577 Baltic Street - Adam America Real Estate - Tesla Destination
# 2024-01-24 14:51:46,658 - INFO - Added site 29372: Hamilton Twnhll Townhall 1
# 2024-01-24 14:51:46,792 - INFO - Added site 29373: Holland Bpw 621 Hastings Av
# 2024-01-24 14:51:46,909 - INFO - Added site 29374: City Of Fresno Inspirparkchg1
# 2024-01-24 14:51:47,029 - INFO - Added site 29375: Pendleton Park Apartments
# 2024-01-24 14:51:47,145 - INFO - Added site 29376: 5774 Clemson St
# 2024-01-24 14:51:47,266 - INFO - Added site 29377: Bandon Dunes Golf Resort - Tesla Destination
# 2024-01-24 14:51:47,384 - INFO - Added site 29378: Boulder Income Partners
# 2024-01-24 14:51:47,505 - INFO - Added site 29379: Loomis Station (Historia Train Station)
# 2024-01-24 14:51:47,622 - INFO - Added site 29380: Heinrich Chevrolet
# 2024-01-24 14:51:47,742 - INFO - Added site 29381: Jlr Dublin Dc Fast 01
# 2024-01-24 14:51:47,861 - INFO - Added site 29382: Springfield Route 66 Koa
# 2024-01-24 14:51:47,983 - INFO - Added site 29383: Mayo Clinic Mayo Clinic
# 2024-01-24 14:51:48,099 - INFO - Added site 29384: Niagara Power Vista
# 2024-01-24 14:51:48,215 - INFO - Added site 29385: Aviation Mall - Tesla Supercharger
# 2024-01-24 14:51:48,335 - INFO - Added site 29386: St. Ed'S Garage Station1
# 2024-01-24 14:51:48,461 - INFO - Added site 29387: Doubletree At The Entrance To Universal Orlando - Tesla Destination
# 2024-01-24 14:51:48,579 - INFO - Added site 29388: Shanty Creek Station 1
# 2024-01-24 14:51:48,698 - INFO - Added site 29389: Walden Park Shopping Center - Tesla Supercharger
# 2024-01-24 14:51:48,818 - INFO - Added site 29390: Uo-1 U01
# 2024-01-24 14:51:48,930 - INFO - Added site 29391: Uo-1 Ascu1
# 2024-01-24 14:51:49,050 - INFO - Added site 29392: Holiday Inn Express Mentor - Tesla Destination
# 2024-01-24 14:51:49,170 - INFO - Added site 29393: Oberlin Oberlin -
# 2024-01-24 14:51:49,286 - INFO - Added site 29394: Subway
# 2024-01-24 14:51:49,406 - INFO - Added site 29395: Ambema Corp. Station 1.1
# 2024-01-24 14:51:49,523 - INFO - Added site 29396: Fc1225 Latham Farms
# 2024-01-24 14:51:49,642 - INFO - Added site 29397: Ladwp - West 9Th Street
# 2024-01-24 14:51:49,757 - INFO - Added site 29398: Powell Street Plaza - Tesla Supercharger
# 2024-01-24 14:51:49,875 - INFO - Added site 29399: Castellani Art Museum - Niagara University
# 2024-01-24 14:51:49,991 - INFO - Added site 29400: Modern Nissan
# 2024-01-24 14:51:50,109 - INFO - Added site 29401: Oridge Station
# 2024-01-24 14:51:50,226 - INFO - Added site 29402: Bayside Bowl Bbp Station 1
# 2024-01-24 14:51:50,340 - INFO - Added site 29403: Universitymotor
# 2024-01-24 14:51:50,458 - INFO - Added site 29404: Waban Lot Calvin Park Lot
# 2024-01-24 14:51:50,576 - INFO - Added site 29405: Town Hall R.E. Shaw
# 2024-01-24 14:51:50,698 - INFO - Added site 29406: Cp Ev Gardner St
# 2024-01-24 14:51:50,817 - INFO - Added site 29407: Amys Drive Thru Station 1
# 2024-01-24 14:51:50,947 - INFO - Added site 29408: Highland Park Village - Tesla Destination
# 2024-01-24 14:51:51,064 - INFO - Added site 29409: Concord Light Keyes Rd Lot
# 2024-01-24 14:51:51,181 - INFO - Added site 29410: Maui Lani Shopping Center
# 2024-01-24 14:51:51,311 - INFO - Added site 29411: Cityof Campbell 1St & Civic
# 2024-01-24 14:51:51,427 - INFO - Added site 29412: Clarion Inn & Suites Hurricane Zion Park Area
# 2024-01-24 14:51:51,545 - INFO - Added site 29413: Audi Stratham
# 2024-01-24 14:51:51,664 - INFO - Added site 29414: Common-Roots Common Roots
# 2024-01-24 14:51:51,781 - INFO - Added site 29415: Brownevstations Brw
# 2024-01-24 14:51:51,900 - INFO - Added site 29416: Standard Parking 58 W 58Th Street - Tesla Destination
# 2024-01-24 14:51:52,017 - INFO - Added site 29417: Harbor Light Inn, A Select Registry Property - Tesla Destination
# 2024-01-24 14:51:52,146 - INFO - Added site 29418: Central Parking - 58 West 58Th St
# 2024-01-24 14:51:52,262 - INFO - Added site 29419: Falmouth Elementary School
# 2024-01-24 14:51:52,400 - INFO - Added site 29420: Calistoga Ranch - Tesla Destination
# 2024-01-24 14:51:52,519 - INFO - Added site 29421: Rmld Read Haven Sta1
# 2024-01-24 14:51:52,639 - INFO - Added site 29422: Bge - 580 Taylor Ave
# 2024-01-24 14:51:52,761 - INFO - Added site 29423: Wawa - Tesla Supercharger
# 2024-01-24 14:51:52,880 - INFO - Added site 29424: Wawa - Tesla Supercharger
# 2024-01-24 14:51:52,999 - INFO - Added site 29425: Upr Mont Plaza Up Mont Plaza
# 2024-01-24 14:51:53,125 - INFO - Added site 29426: Tombstone Grand Hotel - Tesla Destination
# 2024-01-24 14:51:53,244 - INFO - Added site 29427: Towneplace Suites - Clovis
# 2024-01-24 14:51:53,372 - INFO - Added site 29428: Winter Park Resort - B Lot
# 2024-01-24 14:51:53,491 - INFO - Added site 29429: Skyview Apartme Skyview
# 2024-01-24 14:51:53,611 - INFO - Added site 29430: Gencore
# 2024-01-24 14:51:53,729 - INFO - Added site 29431: Lewis & Clark
# 2024-01-24 14:51:53,850 - INFO - Added site 29432: Bayshore Town Center - Tesla Supercharger
# 2024-01-24 14:51:53,966 - INFO - Added site 29433: Five Oaks
# 2024-01-24 14:51:54,082 - INFO - Added site 29434: Hamilton Marketplace 01
# 2024-01-24 14:51:54,209 - INFO - Added site 29435: Northgate Mall
# 2024-01-24 14:51:54,329 - INFO - Added site 29436: Kum & Go #570
# 2024-01-24 14:51:54,451 - INFO - Added site 29437: Target T2022 - Davie, Fl
# 2024-01-24 14:51:54,569 - INFO - Added site 29438: South Miami Community Cente
# 2024-01-24 14:51:54,687 - INFO - Added site 29439: Hyatt House Emeryville/San Francisco Bay Area - Tesla Destination
# 2024-01-24 14:51:54,803 - INFO - Added site 29440: Il Tollway Hinsdale Sb
# 2024-01-24 14:51:54,926 - INFO - Added site 29441: Hard Rock Hotel At Universal Orlando - Tesla Destination
# 2024-01-24 14:51:55,053 - INFO - Added site 29442: Autonation Nissan - Las Vegas
# 2024-01-24 14:51:55,169 - INFO - Added site 29443: Bge - Borgerding Dc - Mcs
# 2024-01-24 14:51:55,286 - INFO - Added site 29444: Bon Secours St. Mary’S Hospital - Parking Deck
# 2024-01-24 14:51:55,406 - INFO - Added site 29445: 5801 Champion Rd
# 2024-01-24 14:51:55,522 - INFO - Added site 29446: Fpl Evolution
# 2024-01-24 14:51:55,640 - INFO - Added site 29447: Lps North Star Hs
# 2024-01-24 14:51:55,759 - INFO - Added site 29448: National Grid Covanta Energy
# 2024-01-24 14:51:55,880 - INFO - Added site 29449: Mount Washington Campus
# 2024-01-24 14:51:55,994 - INFO - Added site 29450: Legacy Town Center - Cbre Parking Garage
# 2024-01-24 14:51:56,115 - INFO - Added site 29451: Ffis Ffis 1
# 2024-01-24 14:51:56,233 - INFO - Added site 29452: Evergy @Jewish
# 2024-01-24 14:51:56,353 - INFO - Added site 29453: Stewart'S Shops - Tesla Supercharger
# 2024-01-24 14:51:56,470 - INFO - Added site 29454: Adelaida Cellars - Tesla Destination
# 2024-01-24 14:51:56,591 - INFO - Added site 29455: Oracle Pls
# 2024-01-24 14:51:56,709 - INFO - Added site 29456: The Mason Sugarloaf Apartments
# 2024-01-24 14:51:56,828 - INFO - Added site 29457: Carlsbad, Ca - Van Allen Way - Tesla Supercharger
# 2024-01-24 14:51:56,943 - INFO - Added site 29458: Austin Hq Mckinney Falls
# 2024-01-24 14:51:57,067 - INFO - Added site 29459: Fort Wayne Mays - E Cent
# 2024-01-24 14:51:57,187 - INFO - Added site 29460: Mollys Station 1
# 2024-01-24 14:51:57,304 - INFO - Added site 29461:
# 2024-01-24 14:51:57,427 - INFO - Added site 29462: Bella Vista Bed & Breakfast Inc. - Tesla Destination
# 2024-01-24 14:51:57,547 - INFO - Added site 29463: Cntyofriverside San Jac An1
# 2024-01-24 14:51:57,662 - INFO - Added site 29464: Best Western Paint Pony Lodge
# 2024-01-24 14:51:57,777 - INFO - Added site 29465: Box Elder Station 1
# 2024-01-24 14:51:57,906 - INFO - Added site 29466: Blvd Downing
# 2024-01-24 14:51:58,022 - INFO - Added site 29467: 5810 Woodman Ave
# 2024-01-24 14:51:58,147 - INFO - Added site 29468: Wyndham Garden North Bw Parkway
# 2024-01-24 14:51:58,262 - INFO - Added site 29469: Vorderman Vw Public Access
# 2024-01-24 14:51:58,377 - INFO - Added site 29470: Pepco - Spaulding Library
# 2024-01-24 14:51:58,493 - INFO - Added site 29471: The Timbrook Guesthouse - Tesla Destination
# 2024-01-24 14:51:58,611 - INFO - Added site 29472: Econo Lodge Inn & Suites
# 2024-01-24 14:51:58,729 - INFO - Added site 29473: Econo Lodge Inn & Suites-1
# 2024-01-24 14:51:58,842 - INFO - Added site 29474: Tynan'S Nissan
# 2024-01-24 14:51:58,957 - INFO - Added site 29475: Riggs Plaza
# 2024-01-24 14:51:59,079 - INFO - Added site 29476: Casa Ford
# 2024-01-24 14:51:59,197 - INFO - Added site 29477: Bill Currie Ford
# 2024-01-24 14:51:59,315 - INFO - Added site 29478: Oracle Pls 5803 Owens
# 2024-01-24 14:51:59,433 - INFO - Added site 29479: Bob'S Ev 1 Station 01
# 2024-01-24 14:51:59,554 - INFO - Added site 29480: To Morrisville Csp 1
# 2024-01-24 14:51:59,670 - INFO - Added site 29481: To Morrisville Csp 2
# 2024-01-24 14:51:59,787 - INFO - Added site 29482: Old Town Square Station 44-45
# 2024-01-24 14:51:59,906 - INFO - Added site 29483: University Park - Stockton Pace
# 2024-01-24 14:52:00,029 - INFO - Added site 29484: Tredyffrin Public Library
# 2024-01-24 14:52:00,151 - INFO - Added site 29485: 582 W 6Th St
# 2024-01-24 14:52:00,275 - INFO - Added site 29486: Hy Vee Rpc
# 2024-01-24 14:52:00,392 - INFO - Added site 29487: Howling Cow Café
# 2024-01-24 14:52:00,519 - INFO - Added site 29488: Mccarran Marketplace - Tesla Supercharger
# 2024-01-24 14:52:00,649 - INFO - Added site 29489: Evergy
# 2024-01-24 14:52:00,778 - INFO - Added site 29490: Jeff Wyler Nissan - Fairfield
# 2024-01-24 14:52:00,894 - INFO - Added site 29491: Evsp Walgreens Store 6903
# 2024-01-24 14:52:01,021 - INFO - Added site 29492: South Miami Smpg
# 2024-01-24 14:52:01,139 - INFO - Added site 29493: Target Corp Antioch
# 2024-01-24 14:52:01,255 - INFO - Added site 29494: Target Corp San Jose

# %%
statuses = ['Available', 'Occupied', 'Unavailable', 'Faulted', 'Offline']
weights = [0.6, 0.32, 0.04, 0.02, 0.02]

try:
    cursor = connection.cursor()

    # Initialize a counter variable
    counter = 0

    for index, row in df.iterrows():
        Latitude = row['Latitude']
        Longitude = row['Longitude']
        Station_Name = row['Station Name']
        Connector_Type = row['EV Connector Types']
    
        # Use the correct column names, with spaces
        site_key = f"{row['Street Address']}_{row['City']}_{row['State']}"
        site_id = site_ids.get(site_key)
    
        # Assign a random status
        status = random.choices(statuses, weights, k=1)[0]
    
        # Convert EVSE Num values to integers, handling non-numeric cases
        try:
            ev_level1 = int(row['EV Level1 EVSE Num'])
        except ValueError:
            ev_level1 = 0

        try:
            ev_level2 = int(row['EV Level2 EVSE Num'])
        except ValueError:
            ev_level2 = 0

        try:
            ev_dc_fast = int(row['EV DC Fast Count'])
        except ValueError:
            ev_dc_fast = 0

        # Determine charge_level
        if ev_level1 > 0:
            charge_level = 1
        elif ev_level2 > 0:
            charge_level = 2
        elif ev_dc_fast > 0:
            charge_level = 3
        else:
            charge_level = 0
    
        # Insert station into the database
        station_query = "INSERT INTO Station (latitude, longitude, name, site_id, status, charge_level, connector_type) VALUES (%s, %s, %s, %s, %s, %s, %s)"
        station_values = (Latitude, Longitude, Station_Name, site_id, status, charge_level, Connector_Type)
        cursor.execute(station_query, station_values)
    
        counter += 1
        if counter % 100 == 0:
            logging.info(f"Added {counter} stations")
            connection.commit()
    
    # Commit any remaining rows
    connection.commit()
    logging.info(f"Total stations added: {counter}")

except Error as e:
    logging.error(f"Error adding stations: {e}")
finally:
    cursor.close()
    connection.close()
# Out:
# 2024-01-24 15:31:38,298 - INFO - Added 21600 stations
# 2024-01-24 15:31:44,253 - INFO - Added 21700 stations
# 2024-01-24 15:31:50,161 - INFO - Added 21800 stations
# 2024-01-24 15:31:56,214 - INFO - Added 21900 stations
# 2024-01-24 15:32:02,099 - INFO - Added 22000 stations
# 2024-01-24 15:32:07,953 - INFO - Added 22100 stations
# 2024-01-24 15:32:13,788 - INFO - Added 22200 stations
# 2024-01-24 15:32:19,693 - INFO - Added 22300 stations
# 2024-01-24 15:32:25,531 - INFO - Added 22400 stations
# 2024-01-24 15:32:31,396 - INFO - Added 22500 stations
# 2024-01-24 15:32:37,297 - INFO - Added 22600 stations
# 2024-01-24 15:32:43,195 - INFO - Added 22700 stations
# 2024-01-24 15:32:49,032 - INFO - Added 22800 stations
# 2024-01-24 15:32:54,928 - INFO - Added 22900 stations
# 2024-01-24 15:33:00,816 - INFO - Added 23000 stations
# 2024-01-24 15:33:06,725 - INFO - Added 23100 stations
# 2024-01-24 15:33:12,593 - INFO - Added 23200 stations
# 2024-01-24 15:33:18,477 - INFO - Added 23300 stations
# 2024-01-24 15:33:24,410 - INFO - Added 23400 stations
# 2024-01-24 15:33:30,239 - INFO - Added 23500 stations
# 2024-01-24 15:33:36,103 - INFO - Added 23600 stations
# 2024-01-24 15:33:41,932 - INFO - Added 23700 stations
# 2024-01-24 15:33:47,813 - INFO - Added 23800 stations
# 2024-01-24 15:33:53,662 - INFO - Added 23900 stations
# 2024-01-24 15:33:59,470 - INFO - Added 24000 stations
# 2024-01-24 15:34:05,314 - INFO - Added 24100 stations
# 2024-01-24 15:34:11,142 - INFO - Added 24200 stations
# 2024-01-24 15:34:17,015 - INFO - Added 24300 stations
# 2024-01-24 15:34:22,860 - INFO - Added 24400 stations
# 2024-01-24 15:34:28,707 - INFO - Added 24500 stations
# 2024-01-24 15:34:34,585 - INFO - Added 24600 stations
# 2024-01-24 15:34:40,461 - INFO - Added 24700 stations
# 2024-01-24 15:34:46,310 - INFO - Added 24800 stations
# 2024-01-24 15:34:52,159 - INFO - Added 24900 stations
# 2024-01-24 15:34:57,931 - INFO - Added 25000 stations
# 2024-01-24 15:35:03,814 - INFO - Added 25100 stations
# 2024-01-24 15:35:09,666 - INFO - Added 25200 stations
# 2024-01-24 15:35:15,577 - INFO - Added 25300 stations
# 2024-01-24 15:35:21,390 - INFO - Added 25400 stations
# 2024-01-24 15:35:27,212 - INFO - Added 25500 stations
# 2024-01-24 15:35:33,037 - INFO - Added 25600 stations
# 2024-01-24 15:35:38,966 - INFO - Added 25700 stations
# 2024-01-24 15:35:44,833 - INFO - Added 25800 stations
# 2024-01-24 15:35:50,733 - INFO - Added 25900 stations
# 2024-01-24 15:35:56,666 - INFO - Added 26000 stations
# 2024-01-24 15:36:02,586 - INFO - Added 26100 stations
# 2024-01-24 15:36:08,562 - INFO - Added 26200 stations
# 2024-01-24 15:36:14,509 - INFO - Added 26300 stations
# 2024-01-24 15:36:20,442 - INFO - Added 26400 stations
# 2024-01-24 15:36:26,302 - INFO - Added 26500 stations
# 2024-01-24 15:36:32,208 - INFO - Added 26600 stations
# 2024-01-24 15:36:38,142 - INFO - Added 26700 stations
# 2024-01-24 15:36:44,038 - INFO - Added 26800 stations
# 2024-01-24 15:36:49,934 - INFO - Added 26900 stations
# 2024-01-24 15:36:55,832 - INFO - Added 27000 stations
# 2024-01-24 15:37:01,712 - INFO - Added 27100 stations
# 2024-01-24 15:37:07,616 - INFO - Added 27200 stations
# 2024-01-24 15:37:13,458 - INFO - Added 27300 stations
# 2024-01-24 15:37:19,455 - INFO - Added 27400 stations
# 2024-01-24 15:37:25,304 - INFO - Added 27500 stations
# 2024-01-24 15:37:31,175 - INFO - Added 27600 stations
# 2024-01-24 15:37:37,009 - INFO - Added 27700 stations
# 2024-01-24 15:37:42,891 - INFO - Added 27800 stations
# 2024-01-24 15:37:48,788 - INFO - Added 27900 stations
# 2024-01-24 15:37:54,682 - INFO - Added 28000 stations
# 2024-01-24 15:38:00,580 - INFO - Added 28100 stations
# 2024-01-24 15:38:06,429 - INFO - Added 28200 stations
# 2024-01-24 15:38:12,254 - INFO - Added 28300 stations
# 2024-01-24 15:38:18,126 - INFO - Added 28400 stations
# 2024-01-24 15:38:23,983 - INFO - Added 28500 stations
# 2024-01-24 15:38:29,845 - INFO - Added 28600 stations
# 2024-01-24 15:38:35,678 - INFO - Added 28700 stations
# 2024-01-24 15:38:41,446 - INFO - Added 28800 stations
# 2024-01-24 15:38:47,262 - INFO - Added 28900 stations
# 2024-01-24 15:38:53,148 - INFO - Added 29000 stations
# 2024-01-24 15:38:59,002 - INFO - Added 29100 stations
# 2024-01-24 15:39:04,922 - INFO - Added 29200 stations
# 2024-01-24 15:39:10,837 - INFO - Added 29300 stations
# 2024-01-24 15:39:16,699 - INFO - Added 29400 stations
# 2024-01-24 15:39:22,533 - INFO - Added 29500 stations
# 2024-01-24 15:39:28,459 - INFO - Added 29600 stations
# 2024-01-24 15:39:34,382 - INFO - Added 29700 stations
# 2024-01-24 15:39:40,271 - INFO - Added 29800 stations
# 2024-01-24 15:39:46,103 - INFO - Added 29900 stations
# 2024-01-24 15:39:51,960 - INFO - Added 30000 stations
# 2024-01-24 15:39:57,863 - INFO - Added 30100 stations
# 2024-01-24 15:40:03,829 - INFO - Added 30200 stations
# 2024-01-24 15:40:09,682 - INFO - Added 30300 stations
# 2024-01-24 15:40:15,590 - INFO - Added 30400 stations
# 2024-01-24 15:40:21,445 - INFO - Added 30500 stations
# 2024-01-24 15:40:27,374 - INFO - Added 30600 stations
# 2024-01-24 15:40:33,300 - INFO - Added 30700 stations
# 2024-01-24 15:40:39,163 - INFO - Added 30800 stations
# 2024-01-24 15:40:45,047 - INFO - Added 30900 stations
# 2024-01-24 15:40:50,949 - INFO - Added 31000 stations
# 2024-01-24 15:40:56,806 - INFO - Added 31100 stations
# 2024-01-24 15:41:02,648 - INFO - Added 31200 stations
# 2024-01-24 15:41:08,545 - INFO - Added 31300 stations
# 2024-01-24 15:41:14,381 - INFO - Added 31400 stations
# 2024-01-24 15:41:20,245 - INFO - Added 31500 stations
# 2024-01-24 15:41:26,151 - INFO - Added 31600 stations
# 2024-01-24 15:41:32,113 - INFO - Added 31700 stations
# 2024-01-24 15:41:38,001 - INFO - Added 31800 stations
# 2024-01-24 15:41:43,896 - INFO - Added 31900 stations
# 2024-01-24 15:41:49,762 - INFO - Added 32000 stations
# 2024-01-24 15:41:55,668 - INFO - Added 32100 stations
# 2024-01-24 15:42:01,513 - INFO - Added 32200 stations
# 2024-01-24 15:42:07,418 - INFO - Added 32300 stations
# 2024-01-24 15:42:13,193 - INFO - Added 32400 stations
# 2024-01-24 15:42:18,993 - INFO - Added 32500 stations
# 2024-01-24 15:42:24,909 - INFO - Added 32600 stations
# 2024-01-24 15:42:30,762 - INFO - Added 32700 stations
# 2024-01-24 15:42:36,645 - INFO - Added 32800 stations
# 2024-01-24 15:42:42,563 - INFO - Added 32900 stations
# 2024-01-24 15:42:48,420 - INFO - Added 33000 stations
# 2024-01-24 15:42:54,292 - INFO - Added 33100 stations
# 2024-01-24 15:43:00,181 - INFO - Added 33200 stations
# 2024-01-24 15:43:05,960 - INFO - Added 33300 stations
# 2024-01-24 15:43:11,826 - INFO - Added 33400 stations
# 2024-01-24 15:43:17,751 - INFO - Added 33500 stations
# 2024-01-24 15:43:23,572 - INFO - Added 33600 stations
# 2024-01-24 15:43:29,383 - INFO - Added 33700 stations
# 2024-01-24 15:43:35,309 - INFO - Added 33800 stations
# 2024-01-24 15:43:41,179 - INFO - Added 33900 stations
# 2024-01-24 15:43:47,063 - INFO - Added 34000 stations
# 2024-01-24 15:43:52,895 - INFO - Added 34100 stations
# 2024-01-24 15:43:58,775 - INFO - Added 34200 stations
# 2024-01-24 15:44:04,583 - INFO - Added 34300 stations
# 2024-01-24 15:44:10,402 - INFO - Added 34400 stations
# 2024-01-24 15:44:16,259 - INFO - Added 34500 stations
# 2024-01-24 15:44:22,230 - INFO - Added 34600 stations
# 2024-01-24 15:44:28,121 - INFO - Added 34700 stations
# 2024-01-24 15:44:33,894 - INFO - Added 34800 stations
# 2024-01-24 15:44:39,713 - INFO - Added 34900 stations
# 2024-01-24 15:44:45,607 - INFO - Added 35000 stations
# 2024-01-24 15:44:51,473 - INFO - Added 35100 stations
# 2024-01-24 15:44:57,338 - INFO - Added 35200 stations
# 2024-01-24 15:45:03,306 - INFO - Added 35300 stations
# 2024-01-24 15:45:09,206 - INFO - Added 35400 stations
# 2024-01-24 15:45:15,107 - INFO - Added 35500 stations
# 2024-01-24 15:45:20,937 - INFO - Added 35600 stations
# 2024-01-24 15:45:26,830 - INFO - Added 35700 stations
# 2024-01-24 15:45:32,680 - INFO - Added 35800 stations
# 2024-01-24 15:45:38,527 - INFO - Added 35900 stations
# 2024-01-24 15:45:44,453 - INFO - Added 36000 stations
# 2024-01-24 15:45:50,317 - INFO - Added 36100 stations
# 2024-01-24 15:45:56,200 - INFO - Added 36200 stations
# 2024-01-24 15:46:02,073 - INFO - Added 36300 stations
# 2024-01-24 15:46:07,958 - INFO - Added 36400 stations
# 2024-01-24 15:46:13,887 - INFO - Added 36500 stations
# 2024-01-24 15:46:19,770 - INFO - Added 36600 stations
# 2024-01-24 15:46:25,681 - INFO - Added 36700 stations
# 2024-01-24 15:46:31,602 - INFO - Added 36800 stations
# 2024-01-24 15:46:37,486 - INFO - Added 36900 stations
# 2024-01-24 15:46:43,371 - INFO - Added 37000 stations
# 2024-01-24 15:46:49,275 - INFO - Added 37100 stations
# 2024-01-24 15:46:55,099 - INFO - Added 37200 stations
# 2024-01-24 15:47:00,921 - INFO - Added 37300 stations
# 2024-01-24 15:47:06,803 - INFO - Added 37400 stations
# 2024-01-24 15:47:12,686 - INFO - Added 37500 stations
# 2024-01-24 15:47:18,539 - INFO - Added 37600 stations
# 2024-01-24 15:47:24,354 - INFO - Added 37700 stations
# 2024-01-24 15:47:30,214 - INFO - Added 37800 stations
# 2024-01-24 15:47:36,056 - INFO - Added 37900 stations
# 2024-01-24 15:47:41,948 - INFO - Added 38000 stations
# 2024-01-24 15:47:47,802 - INFO - Added 38100 stations
# 2024-01-24 15:47:53,702 - INFO - Added 38200 stations
# 2024-01-24 15:47:59,545 - INFO - Added 38300 stations
# 2024-01-24 15:48:05,416 - INFO - Added 38400 stations
# 2024-01-24 15:48:11,339 - INFO - Added 38500 stations
# 2024-01-24 15:48:17,293 - INFO - Added 38600 stations
# 2024-01-24 15:48:23,235 - INFO - Added 38700 stations
# 2024-01-24 15:48:29,125 - INFO - Added 38800 stations
# 2024-01-24 15:48:34,955 - INFO - Added 38900 stations
# 2024-01-24 15:48:40,811 - INFO - Added 39000 stations
# 2024-01-24 15:48:46,724 - INFO - Added 39100 stations
# 2024-01-24 15:48:52,581 - INFO - Added 39200 stations
# 2024-01-24 15:48:58,522 - INFO - Added 39300 stations
# 2024-01-24 15:49:04,407 - INFO - Added 39400 stations
# 2024-01-24 15:49:10,319 - INFO - Added 39500 stations
# 2024-01-24 15:49:16,247 - INFO - Added 39600 stations
# 2024-01-24 15:49:22,168 - INFO - Added 39700 stations
# 2024-01-24 15:49:28,028 - INFO - Added 39800 stations
# 2024-01-24 15:49:33,919 - INFO - Added 39900 stations
# 2024-01-24 15:49:39,754 - INFO - Added 40000 stations
# 2024-01-24 15:49:45,670 - INFO - Added 40100 stations
# 2024-01-24 15:49:51,511 - INFO - Added 40200 stations
# 2024-01-24 15:49:57,350 - INFO - Added 40300 stations
# 2024-01-24 15:50:03,215 - INFO - Added 40400 stations
# 2024-01-24 15:50:09,149 - INFO - Added 40500 stations
# 2024-01-24 15:50:15,055 - INFO - Added 40600 stations
# 2024-01-24 15:50:20,920 - INFO - Added 40700 stations
# 2024-01-24 15:50:26,787 - INFO - Added 40800 stations
# 2024-01-24 15:50:32,668 - INFO - Added 40900 stations
# 2024-01-24 15:50:38,563 - INFO - Added 41000 stations
# 2024-01-24 15:50:44,430 - INFO - Added 41100 stations
# 2024-01-24 15:50:50,321 - INFO - Added 41200 stations
# 2024-01-24 15:50:56,222 - INFO - Added 41300 stations
# 2024-01-24 15:51:02,118 - INFO - Added 41400 stations
# 2024-01-24 15:51:08,038 - INFO - Added 41500 stations
# 2024-01-24 15:51:13,902 - INFO - Added 41600 stations
# 2024-01-24 15:51:19,809 - INFO - Added 41700 stations
# 2024-01-24 15:51:25,703 - INFO - Added 41800 stations
# 2024-01-24 15:51:31,550 - INFO - Added 41900 stations
# 2024-01-24 15:51:37,418 - INFO - Added 42000 stations
# 2024-01-24 15:51:43,324 - INFO - Added 42100 stations
# 2024-01-24 15:51:49,232 - INFO - Added 42200 stations
# 2024-01-24 15:51:55,113 - INFO - Added 42300 stations
# 2024-01-24 15:52:00,946 - INFO - Added 42400 stations
# 2024-01-24 15:52:06,872 - INFO - Added 42500 stations
# 2024-01-24 15:52:12,796 - INFO - Added 42600 stations
# 2024-01-24 15:52:18,708 - INFO - Added 42700 stations
# 2024-01-24 15:52:24,654 - INFO - Added 42800 stations
# 2024-01-24 15:52:30,548 - INFO - Added 42900 stations
# 2024-01-24 15:52:36,533 - INFO - Added 43000 stations
# 2024-01-24 15:52:42,427 - INFO - Added 43100 stations
# 2024-01-24 15:52:48,319 - INFO - Added 43200 stations
# 2024-01-24 15:52:54,254 - INFO - Added 43300 stations
# 2024-01-24 15:53:00,145 - INFO - Added 43400 stations
# 2024-01-24 15:53:06,019 - INFO - Added 43500 stations
# 2024-01-24 15:53:11,906 - INFO - Added 43600 stations
# 2024-01-24 15:53:17,823 - INFO - Added 43700 stations
# 2024-01-24 15:53:23,670 - INFO - Added 43800 stations
# 2024-01-24 15:53:29,471 - INFO - Added 43900 stations
# 2024-01-24 15:53:35,321 - INFO - Added 44000 stations
# 2024-01-24 15:53:41,176 - INFO - Added 44100 stations
# 2024-01-24 15:53:47,110 - INFO - Added 44200 stations
# 2024-01-24 15:53:53,024 - INFO - Added 44300 stations
# 2024-01-24 15:53:58,879 - INFO - Added 44400 stations
# 2024-01-24 15:54:04,798 - INFO - Added 44500 stations
# 2024-01-24 15:54:10,619 - INFO - Added 44600 stations
# 2024-01-24 15:54:16,479 - INFO - Added 44700 stations
# 2024-01-24 15:54:22,382 - INFO - Added 44800 stations
# 2024-01-24 15:54:28,325 - INFO - Added 44900 stations
# 2024-01-24 15:54:34,227 - INFO - Added 45000 stations
# 2024-01-24 15:54:40,138 - INFO - Added 45100 stations
# 2024-01-24 15:54:46,050 - INFO - Added 45200 stations
# 2024-01-24 15:54:51,953 - INFO - Added 45300 stations
# 2024-01-24 15:54:57,846 - INFO - Added 45400 stations
# 2024-01-24 15:55:03,718 - INFO - Added 45500 stations
# 2024-01-24 15:55:09,574 - INFO - Added 45600 stations
# 2024-01-24 15:55:15,495 - INFO - Added 45700 stations
# 2024-01-24 15:55:21,378 - INFO - Added 45800 stations
# 2024-01-24 15:55:27,240 - INFO - Added 45900 stations
# 2024-01-24 15:55:33,078 - INFO - Added 46000 stations
# 2024-01-24 15:55:38,925 - INFO - Added 46100 stations
# 2024-01-24 15:55:44,812 - INFO - Added 46200 stations
# 2024-01-24 15:55:50,736 - INFO - Added 46300 stations
# 2024-01-24 15:55:56,689 - INFO - Added 46400 stations
# 2024-01-24 15:56:02,554 - INFO - Added 46500 stations
# 2024-01-24 15:56:08,481 - INFO - Added 46600 stations
# 2024-01-24 15:56:14,413 - INFO - Added 46700 stations
# 2024-01-24 15:56:20,350 - INFO - Added 46800 stations
# 2024-01-24 15:56:26,204 - INFO - Added 46900 stations
# 2024-01-24 15:56:31,993 - INFO - Added 47000 stations
# 2024-01-24 15:56:37,721 - INFO - Added 47100 stations
# 2024-01-24 15:56:43,553 - INFO - Added 47200 stations
# 2024-01-24 15:56:49,345 - INFO - Added 47300 stations
# 2024-01-24 15:56:55,162 - INFO - Added 47400 stations
# 2024-01-24 15:57:01,061 - INFO - Added 47500 stations
# 2024-01-24 15:57:06,938 - INFO - Added 47600 stations
# 2024-01-24 15:57:12,830 - INFO - Added 47700 stations
# 2024-01-24 15:57:18,701 - INFO - Added 47800 stations
# 2024-01-24 15:57:24,593 - INFO - Added 47900 stations
# 2024-01-24 15:57:30,492 - INFO - Added 48000 stations
# 2024-01-24 15:57:36,372 - INFO - Added 48100 stations
# 2024-01-24 15:57:42,263 - INFO - Added 48200 stations
# 2024-01-24 15:57:48,129 - INFO - Added 48300 stations
# 2024-01-24 15:57:54,001 - INFO - Added 48400 stations
# 2024-01-24 15:57:59,869 - INFO - Added 48500 stations
# 2024-01-24 15:58:05,754 - INFO - Added 48600 stations
# 2024-01-24 15:58:11,659 - INFO - Added 48700 stations
# 2024-01-24 15:58:17,535 - INFO - Added 48800 stations
# 2024-01-24 15:58:23,427 - INFO - Added 48900 stations
# 2024-01-24 15:58:29,337 - INFO - Added 49000 stations
# 2024-01-24 15:58:35,299 - INFO - Added 49100 stations
# 2024-01-24 15:58:41,142 - INFO - Added 49200 stations
# 2024-01-24 15:58:46,982 - INFO - Added 49300 stations
# 2024-01-24 15:58:52,870 - INFO - Added 49400 stations
# 2024-01-24 15:58:58,714 - INFO - Added 49500 stations
# 2024-01-24 15:59:04,562 - INFO - Added 49600 stations
# 2024-01-24 15:59:10,396 - INFO - Added 49700 stations
# 2024-01-24 15:59:16,256 - INFO - Added 49800 stations
# 2024-01-24 15:59:22,198 - INFO - Added 49900 stations
# 2024-01-24 15:59:28,034 - INFO - Added 50000 stations
# 2024-01-24 15:59:33,853 - INFO - Added 50100 stations
# 2024-01-24 15:59:39,722 - INFO - Added 50200 stations
# 2024-01-24 15:59:45,581 - INFO - Added 50300 stations
# 2024-01-24 15:59:51,447 - INFO - Added 50400 stations
# 2024-01-24 15:59:57,359 - INFO - Added 50500 stations
# 2024-01-24 16:00:03,239 - INFO - Added 50600 stations
# 2024-01-24 16:00:09,227 - INFO - Added 50700 stations
# 2024-01-24 16:00:15,155 - INFO - Added 50800 stations
# 2024-01-24 16:00:21,128 - INFO - Added 50900 stations
# 2024-01-24 16:00:27,099 - INFO - Added 51000 stations
# 2024-01-24 16:00:33,021 - INFO - Added 51100 stations
# 2024-01-24 16:00:38,950 - INFO - Added 51200 stations
# 2024-01-24 16:00:44,866 - INFO - Added 51300 stations
# 2024-01-24 16:00:50,749 - INFO - Added 51400 stations
# 2024-01-24 16:00:56,576 - INFO - Added 51500 stations
# 2024-01-24 16:01:02,469 - INFO - Added 51600 stations
# 2024-01-24 16:01:08,356 - INFO - Added 51700 stations
# 2024-01-24 16:01:14,280 - INFO - Added 51800 stations
# 2024-01-24 16:01:20,149 - INFO - Added 51900 stations
# 2024-01-24 16:01:26,124 - INFO - Added 52000 stations
# 2024-01-24 16:01:31,969 - INFO - Added 52100 stations
# 2024-01-24 16:01:37,844 - INFO - Added 52200 stations
# 2024-01-24 16:01:43,728 - INFO - Added 52300 stations
# 2024-01-24 16:01:49,609 - INFO - Added 52400 stations
# 2024-01-24 16:01:55,460 - INFO - Added 52500 stations
# 2024-01-24 16:02:01,361 - INFO - Added 52600 stations
# 2024-01-24 16:02:07,264 - INFO - Added 52700 stations
# 2024-01-24 16:02:13,087 - INFO - Added 52800 stations
# 2024-01-24 16:02:19,000 - INFO - Added 52900 stations
# 2024-01-24 16:02:24,878 - INFO - Added 53000 stations
# 2024-01-24 16:02:30,791 - INFO - Added 53100 stations
# 2024-01-24 16:02:36,661 - INFO - Added 53200 stations
# 2024-01-24 16:02:42,500 - INFO - Added 53300 stations
# 2024-01-24 16:02:48,370 - INFO - Added 53400 stations
# 2024-01-24 16:02:54,234 - INFO - Added 53500 stations
# 2024-01-24 16:03:00,059 - INFO - Added 53600 stations
# 2024-01-24 16:03:05,931 - INFO - Added 53700 stations
# 2024-01-24 16:03:11,813 - INFO - Added 53800 stations
# 2024-01-24 16:03:17,702 - INFO - Added 53900 stations
# 2024-01-24 16:03:23,540 - INFO - Added 54000 stations
# 2024-01-24 16:03:29,376 - INFO - Added 54100 stations
# 2024-01-24 16:03:35,257 - INFO - Added 54200 stations
# 2024-01-24 16:03:41,186 - INFO - Added 54300 stations
# 2024-01-24 16:03:47,089 - INFO - Added 54400 stations
# 2024-01-24 16:03:53,027 - INFO - Added 54500 stations
# 2024-01-24 16:03:58,915 - INFO - Added 54600 stations
# 2024-01-24 16:04:04,859 - INFO - Added 54700 stations
# 2024-01-24 16:04:10,756 - INFO - Added 54800 stations
# 2024-01-24 16:04:16,759 - INFO - Added 54900 stations
# 2024-01-24 16:04:22,646 - INFO - Added 55000 stations
# 2024-01-24 16:04:28,500 - INFO - Added 55100 stations
# 2024-01-24 16:04:34,435 - INFO - Added 55200 stations
# 2024-01-24 16:04:40,465 - INFO - Added 55300 stations
# 2024-01-24 16:04:46,280 - INFO - Added 55400 stations
# 2024-01-24 16:04:52,248 - INFO - Added 55500 stations
# 2024-01-24 16:04:58,190 - INFO - Added 55600 stations
# 2024-01-24 16:04:58,556 - INFO - Total stations added: 55604

# %%
print(df.columns)
