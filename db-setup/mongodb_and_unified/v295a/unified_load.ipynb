# %%
import pymongo
import pandas as pd
import os
from datetime import datetime, timedelta
from dotenv import load_dotenv

import pymongo.errors as mongo_errors

import certifi

import mysql.connector
from mysql.connector import Error
import random

from itertools import count

import numpy as np
import time

# %% [markdown]
# # DB Connections & Setup

# %%
# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %% [markdown]
# ## SQL

# %%
# Get the connection parameters from environment variables
host = os.getenv("DB_HOST")
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
database = os.getenv("DB_DATABASE")

# Create a connection to the MySQL database
sql_connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database
)

# %%
# Test connection
# Create a cursor object using the cursor() method
cursor = sql_connection.cursor()

# Execute the SQL query to retrieve table information
cursor.execute("SHOW TABLES")

# Fetch all the rows in a list of lists.
tables = cursor.fetchall()

# Output the list of tables to confirm the connection
for table in tables:
    print(table)
# Out:
# ('Driver',)
# ('EVSE',)
# ('RFID_map',)
# ('Site',)
# ('Staff',)
# ('Station',)
# ('Station_Owner',)
# ('User',)
# ('evses_joined',)
# ('stations_joined',)

# %%
# Close the connection
'''
cursor.close()
sql_connection.close()
'''
# Out:
# '\ncursor.close()\nsql_connection.close()\n'

# %% [markdown]
# ## Mongo

# %%
# Create the connection URI
#connection_uri = f"mongodb://{username}:{password}@{host}:{port}/{database_name}"
ca = certifi.where()
connection_uri = os.environ['MONGO_URL'] + '&tlsCAFile=' + ca

print(connection_uri)

# Connect to MongoDB
client = pymongo.MongoClient(connection_uri)

# Access the specific database
mongo_db = client['sparkplug']
# Out:
# mongodb+srv://sparkplug:5jkS0ew4zVnACstU@sparkplug.i7nlrbn.mongodb.net/?retryWrites=true&w=majority&tlsCAFile=/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/certifi/cacert.pem

# %%
# Test connection

try:
    # Attempt to retrieve the server status
    server_status = client.server_info()
    print("Connected to MongoDB server:", server_status)
except mongo_errors.ConnectionFailure as e:
    print("Connection Failure: ", e)
except mongo_errors.ConfigurationError as e:
    print("Configuration Error: ", e)
except mongo_errors.PyMongoError as e:
    print("PyMongo Error: ", e)
except Exception as e:
    print("An error occurred: ", e)
# Out:
# Connected to MongoDB server: {'version': '7.0.11', 'gitVersion': 'f451220f0df2b9dfe073f1521837f8ec5c208a8c', 'modules': ['enterprise'], 'allocator': 'tcmalloc', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [7, 0, 11, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1717869796, 7), 'signature': {'hash': b'$\x06)P\xb1\xb1\x83\xff\xd5V\x9e\xff\xf0\x8a\xa7\xfb\xb1\xf9\xc1)', 'keyId': 7314697452504743938}}, 'operationTime': Timestamp(1717869796, 7)}

# %% [markdown]
# # Process Transactions Data

# %% [markdown]
# ## Read File

# %%
# Read the CSV file into a dataframe
transactions_file_path = 'data/new_group5_chargingstation_addresses_unified - chargingstations.csv'
t_df = pd.read_csv(transactions_file_path)

# Handle missing values (NaN) in the dataframe
t_df = t_df.fillna('')

# Print the dataframe
print(t_df.size)
for column in t_df.columns.tolist():
    print(column)
# Out:
# 4150496
# ZipCode
# Charging Station
# Address
# City
# State
# Latitude
# Longitude
# Start Date
# End Date
# Total Duration
# Charging Time
# Charging Port Type
# Charging Ports
# Plug Type
# Energy Consumed
# Charges

# %% [markdown]
# ## Fix broken dates

# %%
# Check for broken datetimes
t_df['Start Date'] = pd.to_datetime(t_df['Start Date'], errors='coerce', format='%m/%d/%Y %H:%M')
t_df['End Date'] = pd.to_datetime(t_df['End Date'], errors='coerce', format='%m/%d/%Y %H:%M')

# Identify rows where either datetime column couldn't be converted (contains NaT)
invalid_rows = t_df[t_df['Start Date'].isna() | t_df['End Date'].isna()]

#print(invalid_rows[['Start Date', 'End Date']])

# %%
# Define a function to convert duration string to timedelta
def parse_duration(duration_str):
    hours, minutes, seconds = map(int, duration_str.split(':'))
    return timedelta(hours=hours, minutes=minutes, seconds=seconds)

# Update 'End Date' where it is invalid
for index, row in t_df.iterrows():
    if pd.isna(row['End Date']):
        duration = parse_duration(row['Total Duration'])
        t_df.at[index, 'End Date'] = row['Start Date'] + duration

# Identify rows where either datetime column couldn't be converted (contains NaT)
invalid_rows = t_df[t_df['Start Date'].isna() | t_df['End Date'].isna()]

# Print rows with formatting errors
print(invalid_rows[['Start Date', 'End Date']])
# Out:
# Empty DataFrame
# Columns: [Start Date, End Date]
# Index: []

# %% [markdown]
# ## Set cutoff date because there are too many transactions

# %%
# Format transaction_date in POSIX time
t_df['transaction_date'] = pd.to_datetime(t_df['End Date'], format='%m/%d/%Y %H:%M')
t_df['transaction_date'] = (t_df['transaction_date'] - pd.Timestamp("1970-01-01")) // pd.Timedelta('1ms')

# %%
min_transaction_date = t_df['transaction_date'].min()
max_transaction_date = t_df['transaction_date'].max()

# Print the results
print("Minimum Transaction Date:", min_transaction_date)
print("Maximum Transaction Date:", max_transaction_date)
# Out:
# Minimum Transaction Date: 1311981600000
# Maximum Transaction Date: 1609794060000

# %%
# Sample start_date in yyyy-mm-dd format
start_date = '2019-06-01'

# Convert start_date to POSIX time (assuming UTC timezone for simplicity)
start_date_posix = int(time.mktime(datetime.strptime(start_date, '%Y-%m-%d').timetuple()) * 1000)

print(f"Start date in POSIX time: {start_date_posix}")

# Assuming df is your DataFrame and it has columns 'transaction_date', 'Charging Station', 'Address', 'Latitude', 'Longitude'

# Filter the DataFrame
filtered_df = t_df[t_df['transaction_date'] >= start_date_posix]

# Count total number of transactions
transaction_count = filtered_df.shape[0]
all_transaction_count = t_df.shape[0]

# Count unique Address values
site_count = filtered_df['Address'].nunique()
all_site_count = t_df['Address'].nunique()

# Count unique Charging Station values
station_count = filtered_df['Charging Station'].nunique()
all_station_count = t_df['Charging Station'].nunique()

# Count unique Latitude and Longitude combinations
evse_count = filtered_df.groupby(['Latitude', 'Longitude']).ngroups
all_evse_count = t_df.groupby(['Latitude', 'Longitude']).ngroups

print(f"Transactions:  {transaction_count} of {all_transaction_count}")
print(f"Sites:         {site_count} of {all_site_count}")
print(f"Stations:      {station_count} of {all_station_count}")
print(f"EVSEs:         {evse_count} of {all_evse_count}")
# Out:
# Start date in POSIX time: 1559372400000
# Transactions:  48327 of 259406
# Sites:         9 of 9
# Stations:      46 of 46
# EVSEs:         48 of 66

# %%
t_df = filtered_df

# %% [markdown]
# ## Helper Functions

# %%
def common_substring(strings):
    if not strings:
        return ""
    shortest_str = min(strings, key=len)
    for i, char in enumerate(shortest_str):
        for other in strings:
            if other[i] != char:
                return shortest_str[:i]
    return shortest_str 

def map_state_name_to_abbreviation(state_name):
    # Dictionary mapping state names to their abbreviations
    state_map = {
        "alabama": "AL", "alaska": "AK", "arizona": "AZ", "arkansas": "AR", "california": "CA",
        "colorado": "CO", "connecticut": "CT", "delaware": "DE", "florida": "FL", "georgia": "GA",
        "hawaii": "HI", "idaho": "ID", "illinois": "IL", "indiana": "IN", "iowa": "IA",
        "kansas": "KS", "kentucky": "KY", "louisiana": "LA", "maine": "ME", "maryland": "MD",
        "massachusetts": "MA", "michigan": "MI", "minnesota": "MN", "mississippi": "MS", "missouri": "MO",
        "montana": "MT", "nebraska": "NE", "nevada": "NV", "new hampshire": "NH", "new jersey": "NJ",
        "new mexico": "NM", "new york": "NY", "north carolina": "NC", "north dakota": "ND", "ohio": "OH",
        "oklahoma": "OK", "oregon": "OR", "pennsylvania": "PA", "rhode island": "RI", "south carolina": "SC",
        "south dakota": "SD", "tennessee": "TN", "texas": "TX", "utah": "UT", "vermont": "VT",
        "virginia": "VA", "washington": "WA", "west virginia": "WV", "wisconsin": "WI", "wyoming": "WY"
    }
    
    # Convert the input to lowercase to handle case insensitivity
    normalized_input = state_name.strip().lower()
    
    # Check if the normalized input is already a valid abbreviation
    if normalized_input.upper() in state_map.values():
        return normalized_input.upper()
    
    # Return the state abbreviation or the original if not found
    return state_map.get(normalized_input, state_name.upper())

def format_datetime(date_str):
    """Convert datetime from 'm/d/Y H:M' format to 'Y-m-d H:M:S' format."""
    try:
        # Parse the date with the correct format
        return datetime.strptime(date_str, '%m/%d/%Y %H:%M').strftime('%Y-%m-%d %H:%M:%S')
    except ValueError:
        # Handle incorrect format by returning a default datetime
        return datetime.now().strftime('%Y-%m-%d %H:%M:%S')

def posix_time(dt):
    """Convert a datetime object to POSIX time in milliseconds."""
    posix_seconds = time.mktime(dt.timetuple())  # POSIX time in seconds
    return int(posix_seconds * 1000)

# %% [markdown]
# ## First Pass - Build Sites, Stations, EVSEs from transaction data

# %%
# Initialize counters and dictionaries for storing data
site_id_gen = count(1)
station_id_gen = count(1)
evse_id_gen = count(1)
sites = {}
stations = {}
evses = {}

# Process each row
for idx, row in t_df.iterrows():
    address = row['Address']
    station_name = row['Charging Station']
    lat_long = (row['Latitude'], row['Longitude'])
    
    # Process sites
    if address not in sites:
        sites[address] = {
            'id': next(site_id_gen),
            'owner_id': np.random.choice([1, 2]),
            'street_address': address,
            'latitude': [],
            'longitude': [],
            'name': [],
            'city': row['City'],
            'state': map_state_name_to_abbreviation(row['State']), 
            'country': 'USA',
            'zip_code': row['ZipCode'],
            'created_at': [],
            'updated_at': []
        }
    
    # Process stations
    if station_name not in stations:
        stations[station_name] = {
            'id': next(station_id_gen),
            'name': station_name,
            'latitude': [],
            'longitude': [],
            'site_id': sites[address]['id'],
            'created_at': [],
            'updated_at': []
        }
    
    # Process EVSEs
    if lat_long not in evses:
        evses[lat_long] = {
            'id': next(evse_id_gen),
            'station_id': stations[station_name]['id'],
            'connector_type': row['Plug Type'],
            'charge_level': row['Charging Port Type'],
            'created_at': [],
            'updated_at': [],
            'latitude': lat_long[0],
            'longitude': lat_long[1]
        }
    
    # Append data for aggregation
    sites[address]['latitude'].append(row['Latitude'])
    sites[address]['longitude'].append(row['Longitude'])
    sites[address]['name'].append(station_name)
    sites[address]['created_at'].append(row['Start Date'])
    sites[address]['updated_at'].append(row['End Date'])
    
    stations[station_name]['latitude'].append(row['Latitude'])
    stations[station_name]['longitude'].append(row['Longitude'])
    stations[station_name]['created_at'].append(row['Start Date'])
    stations[station_name]['updated_at'].append(row['End Date'])
    
    evses[lat_long]['created_at'].append(row['Start Date'])
    evses[lat_long]['updated_at'].append(row['End Date'])

# Finalize aggregation for sites, stations, and EVSEs
for site in sites.values():
    site['latitude'] = np.mean(site['latitude'])
    site['longitude'] = np.mean(site['longitude'])
    site['name'] = common_substring(site['name']).strip(' #')
    site['created_at'] = min(site['created_at'])
    site['updated_at'] = max(site['updated_at'])

for station in stations.values():
    station['latitude'] = np.mean(station['latitude'])
    station['longitude'] = np.mean(station['longitude'])
    station['created_at'] = min(station['created_at'])
    station['updated_at'] = max(station['updated_at'])

for evse in evses.values():
    evse['created_at'] = min(evse['created_at'])
    evse['updated_at'] = max(evse['updated_at'])

# %% [markdown]
# ## Populate SQL DB with prereq entities

# %%
staff_ids = []
owner_ids = []
driver_ids = []

staff_count = 1  
owner_count = 100  
owners_reserved = 3

# %% [markdown]
# ### Owners and Staff

# %%
def construct_insert_query(staff_count, owner_count):
    base_query = """
    INSERT INTO User (user_type, email, password, name, status, created_at, updated_at) VALUES 
    """
    values_list = []
    
    # Generate staff entries
    for i in range(1, staff_count + 1):
        values_list.append(
            f"('staff', 'staff{i}@example.com', '$2b$10$fx97CvpoF.SDQnuNs4HF0OXZBoty.bkfHlJDP6rM9kHMLJ/DaAQzO', 'staff{i}', 'Active', '2011-03-31 06:28:34', '2011-04-01 06:28:34')"
        )
    
    # Generate owner entries
    for i in range(1, owner_count + 1):
        values_list.append(
            f"('owner', 'owner{i}@example.com', '$2b$10$fx97CvpoF.SDQnuNs4HF0OXZBoty.bkfHlJDP6rM9kHMLJ/DaAQzO', 'owner{i}', 'Active', '2011-03-31 06:28:34', '2011-04-01 06:28:34')"
        )
    
    full_query = base_query + ",\n".join(values_list) + ";"
    return full_query

# Get the dynamically constructed query
dynamic_query = construct_insert_query(staff_count, owner_count)

# %%
try:
    cursor = sql_connection.cursor()  # Assuming sql_connection is already set up
    cursor.execute(dynamic_query)
    sql_connection.commit()  # Commit the transaction
    print(f"{cursor.rowcount} rows were inserted.")

except Exception as e:
    print("An error occurred:", e)

finally:
    cursor.close()
# Out:
# 101 rows were inserted.

# %%
cursor = sql_connection.cursor()

try:
    # Staff
    # Step 1: Select IDs from User table
    select_query = "SELECT id FROM User WHERE user_type='staff';"
    cursor.execute(select_query)
    staff_ids = cursor.fetchall()

    # Check if there are any IDs to process
    if staff_ids:
        # Step 2: Insert IDs into Driver table
        # Preparing the values string for the SQL query
        values_str = ','.join([f"({id[0]})" for id in staff_ids])
        insert_query = f"INSERT INTO Staff (id) VALUES {values_str};"
        cursor.execute(insert_query)
        sql_connection.commit()  # Commit the transaction
        print(f"{cursor.rowcount} rows were inserted into Staff.")
    else:
        print("No staff IDs found to insert.")

    # Owner
    # Step 1: Select IDs from User table
    select_query = "SELECT id FROM User WHERE user_type='owner';"
    cursor.execute(select_query)
    owner_ids = cursor.fetchall()

    # Check if there are any IDs to process
    if owner_ids:
        # Step 2: Insert IDs into Driver table
        # Preparing the values string for the SQL query
        values_str = ','.join([f"({id[0]})" for id in owner_ids])
        insert_query = f"INSERT INTO Station_Owner (id) VALUES {values_str};"
        cursor.execute(insert_query)
        sql_connection.commit()  # Commit the transaction
        print(f"{cursor.rowcount} rows were inserted into Station_Owner.")
    else:
        print("No owner IDs found to insert.")

except Exception as e:
    print("An error occurred:", e)

finally:
    # Close the cursor
    cursor.close()
# Out:
# 1 rows were inserted into Staff.
# 100 rows were inserted into Station_Owner.

# %% [markdown]
# ### Drivers

# %%
import mysql.connector
import os
import random

cursor = sql_connection.cursor()

def random_datetime(start, end):
    """Generate a random datetime between `start` and `end`."""
    start_timestamp = int(start.timestamp())
    end_timestamp = int(end.timestamp())
    random_timestamp = random.randint(start_timestamp, end_timestamp)
    return datetime.fromtimestamp(random_timestamp).strftime('%Y-%m-%d %H:%M:%S')

# Start and end dates for datetime generation
start_date = datetime(2011, 3, 31)
end_date = datetime(2024, 6, 1)

# Generating the SQL INSERT query
values = []
for i in range(1, 1001):
    user_type = 'driver'
    email = f"driver{i}@example.com"
    password = "$2b$10$fx97CvpoF.SDQnuNs4HF0OXZBoty.bkfHlJDP6rM9kHMLJ/DaAQzO"
    name = f"driver{i}"
    status = "Active"
    created_at = random_datetime(start_date, end_date)
    updated_at = created_at  # Assuming updated_at is the same as created_at for simplicity
    values.append(f"('{user_type}', '{email}', '{password}', '{name}', '{status}', '{created_at}', '{updated_at}')")

sql_insert_query = f"""
INSERT INTO User (user_type, email, password, name, status, created_at, updated_at) VALUES 
{','.join(values)};
"""

try:
    # Execute the SQL statement
    cursor.execute(sql_insert_query)
    sql_connection.commit()  # Commit the transaction
    print(f"{cursor.rowcount} rows were inserted.")

except Exception as e:
    print("An error occurred:", e)

finally:
    # Close the cursor
    cursor.close()
# Out:
# 1000 rows were inserted.

# %%
cursor = sql_connection.cursor()

try:
    # Step 1: Select IDs from User table
    select_query = "SELECT id FROM User WHERE user_type='driver';"
    cursor.execute(select_query)
    driver_ids = cursor.fetchall()

    # Check if there are any IDs to process
    if driver_ids:
        # Step 2: Insert IDs into Driver table
        # Preparing the values string for the SQL query
        values_str = ','.join([f"({id[0]})" for id in driver_ids])
        insert_query = f"INSERT INTO Driver (id) VALUES {values_str};"
        cursor.execute(insert_query)
        sql_connection.commit()  # Commit the transaction
        print(f"{cursor.rowcount} rows were inserted into Driver.")
    else:
        print("No driver IDs found to insert.")

except Exception as e:
    print("An error occurred:", e)

finally:
    # Close the cursor
    cursor.close()
# Out:
# 1000 rows were inserted into Driver.

# %% [markdown]
# ## Populate SQL DB with Sites, Stations, and EVSEs

# %% [markdown]
# ### Sites

# %%
cursor = sql_connection.cursor()

try:
    # Loop through each site and construct the INSERT command
    for site_key, site_details in sites.items():
        # Validate and format data
        id = site_details['id']
        owner_id = random.choice(owner_ids[:owners_reserved])[0]
        name = site_details['name'].replace("'", "''")  # Escape single quotes
        street_address = site_details['street_address'].replace("'", "''")  # Escape single quotes
        zip_code = int(site_details['zip_code'])  # Ensure zip_code is an integer
        latitude = site_details['latitude'] 
        longitude = site_details['longitude']  
        updated_at = site_details['updated_at']
        created_at = site_details['created_at']
        city = site_details['city'].replace("'", "''")  # Escape single quotes
        state = site_details['state'][:2]  # Ensure state is no longer than 2 characters
        country = site_details['country']

        # SQL INSERT command
        sql_insert_query = f"""
        INSERT INTO Site (id, owner_id, name, street_address, zip_code, latitude, longitude, updated_at, created_at, city, state, country) VALUES
        ({id}, {owner_id}, '{name}', '{street_address}', {zip_code}, '{latitude}', '{longitude}', '{updated_at}', '{created_at}', '{city}', '{state}', '{country}');
        """
        cursor.execute(sql_insert_query)
        sql_connection.commit()  # Commit the transaction
        print(f"Site '{name}' inserted successfully.")

except Exception as e:
    print("An error occurred:", e)
    print("Failed SQL Query:", sql_insert_query)

finally:
    # Close the cursor
    cursor.close()
# Out:
# Site 'PALO ALTO CA / BRYANT' inserted successfully.
# Site 'PALO ALTO CA / HAMILTON' inserted successfully.
# Site 'PALO ALTO CA / HIGH' inserted successfully.
# Site 'PALO ALTO CA / WEBSTER' inserted successfully.
# Site 'PALO ALTO CA / MPL' inserted successfully.
# Site 'PALO ALTO CA / RINCONADA LIB' inserted successfully.
# Site 'PALO ALTO CA / CAMBRIDGE' inserted successfully.
# Site 'PALO ALTO CA / SHERMAN' inserted successfully.
# Site 'PALO ALTO CA / TED THOMPSON' inserted successfully.

# %% [markdown]
# ### Stations

# %%
cursor = sql_connection.cursor()

# Execute each station insert
for key, station in stations.items():
    id = station['id']
    name = station['name'].replace("'", "''")  # Escape single quotes
    latitude = station['latitude']
    longitude = station['longitude']
    updated_at = station['updated_at']
    created_at = station['created_at']
    site_id = station['site_id']
    sql_insert_query = f"""
    INSERT INTO Station (id, name, latitude, longitude, created_at, updated_at, site_id) VALUES
    ({id}, '{name}', '{latitude}', '{longitude}', '{created_at}', '{updated_at}', {site_id});
    """
    try:
        cursor.execute(sql_insert_query)
        sql_connection.commit()  # Commit the transaction
        print(f"Station '{station['name']}' inserted successfully.")
    except Exception as e:
        print("An error occurred:", e)
        print("Failed SQL Query:", sql_insert_query)

# Close the cursor
cursor.close()
# Out:
# Station 'PALO ALTO CA / BRYANT #1' inserted successfully.
# Station 'PALO ALTO CA / BRYANT #2' inserted successfully.
# Station 'PALO ALTO CA / BRYANT #3' inserted successfully.
# Station 'PALO ALTO CA / BRYANT #4' inserted successfully.
# Station 'PALO ALTO CA / BRYANT #5' inserted successfully.
# Station 'PALO ALTO CA / BRYANT #6' inserted successfully.
# Station 'PALO ALTO CA / HAMILTON #1' inserted successfully.
# Station 'PALO ALTO CA / HAMILTON #2' inserted successfully.
# Station 'PALO ALTO CA / HIGH #1' inserted successfully.
# Station 'PALO ALTO CA / HIGH #2' inserted successfully.
# Station 'PALO ALTO CA / HIGH #3' inserted successfully.
# Station 'PALO ALTO CA / HIGH #4' inserted successfully.
# Station 'PALO ALTO CA / WEBSTER #1' inserted successfully.
# Station 'PALO ALTO CA / WEBSTER #2' inserted successfully.
# Station 'PALO ALTO CA / WEBSTER #3' inserted successfully.
# Station 'PALO ALTO CA / MPL #1' inserted successfully.
# Station 'PALO ALTO CA / MPL #2' inserted successfully.
# Station 'PALO ALTO CA / MPL #3' inserted successfully.
# Station 'PALO ALTO CA / MPL #4' inserted successfully.
# Station 'PALO ALTO CA / MPL #5' inserted successfully.
# Station 'PALO ALTO CA / MPL #6' inserted successfully.
# Station 'PALO ALTO CA / RINCONADA LIB 1' inserted successfully.
# Station 'PALO ALTO CA / RINCONADA LIB 2' inserted successfully.
# Station 'PALO ALTO CA / RINCONADA LIB 3' inserted successfully.
# Station 'PALO ALTO CA / CAMBRIDGE #1' inserted successfully.
# Station 'PALO ALTO CA / CAMBRIDGE #2' inserted successfully.
# Station 'PALO ALTO CA / CAMBRIDGE #3' inserted successfully.
# Station 'PALO ALTO CA / CAMBRIDGE #4' inserted successfully.
# Station 'PALO ALTO CA / CAMBRIDGE #5' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 1' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 11' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 14' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 15' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 17' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 2' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 3' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 4' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 5' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 6' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 7' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 8' inserted successfully.
# Station 'PALO ALTO CA / SHERMAN 9' inserted successfully.
# Station 'PALO ALTO CA / TED THOMPSON #1' inserted successfully.
# Station 'PALO ALTO CA / TED THOMPSON #2' inserted successfully.
# Station 'PALO ALTO CA / TED THOMPSON #3' inserted successfully.
# Station 'PALO ALTO CA / TED THOMPSON #4' inserted successfully.
# True

# %% [markdown]
# ### EVSEs

# %%
cursor = sql_connection.cursor()

# Execute each station insert
for key, evse in evses.items():
    id = evse['id']
    station_id = evse['station_id']
    connector_type = evse['connector_type']
    charge_level = evse['charge_level']
    latitude = evse['latitude']
    longitude = evse['longitude']
    updated_at = station['updated_at']
    created_at = station['created_at']
    sql_insert_query = f"""
    INSERT INTO EVSE (id, station_id, connector_type, charge_level, latitude, longitude, created_at, updated_at) VALUES
    ({id}, '{station_id}', '{connector_type}', '{charge_level}', '{latitude}', '{longitude}', '{created_at}', '{updated_at}');
    """
    try:
        cursor.execute(sql_insert_query)
        sql_connection.commit()  # Commit the transaction
        print(f"EVSE '{evse['id']}' inserted successfully.")
    except Exception as e:
        print("An error occurred:", e)
        print("Failed SQL Query:", sql_insert_query)

# Close the cursor
cursor.close()
# Out:
# EVSE '1' inserted successfully.
# EVSE '2' inserted successfully.
# EVSE '3' inserted successfully.
# EVSE '4' inserted successfully.
# EVSE '5' inserted successfully.
# EVSE '6' inserted successfully.
# EVSE '7' inserted successfully.
# EVSE '8' inserted successfully.
# EVSE '9' inserted successfully.
# EVSE '10' inserted successfully.
# EVSE '11' inserted successfully.
# EVSE '12' inserted successfully.
# EVSE '13' inserted successfully.
# EVSE '14' inserted successfully.
# EVSE '15' inserted successfully.
# EVSE '16' inserted successfully.
# EVSE '17' inserted successfully.
# EVSE '18' inserted successfully.
# EVSE '19' inserted successfully.
# EVSE '20' inserted successfully.
# EVSE '21' inserted successfully.
# EVSE '22' inserted successfully.
# EVSE '23' inserted successfully.
# EVSE '24' inserted successfully.
# EVSE '25' inserted successfully.
# EVSE '26' inserted successfully.
# EVSE '27' inserted successfully.
# EVSE '28' inserted successfully.
# EVSE '29' inserted successfully.
# EVSE '30' inserted successfully.
# EVSE '31' inserted successfully.
# EVSE '32' inserted successfully.
# EVSE '33' inserted successfully.
# EVSE '34' inserted successfully.
# EVSE '35' inserted successfully.
# EVSE '36' inserted successfully.
# EVSE '37' inserted successfully.
# EVSE '38' inserted successfully.
# EVSE '39' inserted successfully.
# EVSE '40' inserted successfully.
# EVSE '41' inserted successfully.
# EVSE '42' inserted successfully.
# EVSE '43' inserted successfully.
# EVSE '44' inserted successfully.
# EVSE '45' inserted successfully.
# EVSE '46' inserted successfully.
# EVSE '47' inserted successfully.
# EVSE '48' inserted successfully.
# True

# %% [markdown]
# ## Query stations and evses to match with transactions

# %%
evses_joined = []
try:
    # Create a cursor object using the existing connection
    cursor = sql_connection.cursor(dictionary=True)  # Ensure cursor returns dictionaries

    # Define your SQL query
    query = "SELECT * FROM evses_joined;"

    # Execute the query
    cursor.execute(query)

    # Fetch all rows and directly convert to a list of dictionaries
    evses_joined = cursor.fetchall()  # Each row is a dictionary

    print("Data loaded into list of dictionaries successfully!")

except mysql.connector.Error as e:
    print(f"Error fetching data from MySQL: {e}")

finally:
    # Ensure the cursor is closed properly
    cursor.close()
# Out:
# Data loaded into list of dictionaries successfully!

# %% [markdown]
# ## Second Pass - Populate Mongodb with transactions data

# %%
charging_sessions = mongo_db.charging_sessions
evse_status = mongo_db.evse_status

# %%
def find_evse_details(lat, long, evses_joined):
    """Find evse_id and station_id for the given latitude and longitude."""
    for item in evses_joined:
        if str(item['evse_latitude']) == str(lat) and str(item['evse_longitude']) == str(long):
            return item['evse_id'], item['station_id'], item['evse_number']
    return None, None, None

def update_evse_status(evse_id, station_id, evse_number, timestamp, new_status, evse_status):
    """Update or create evse_status document with new status update."""
    evse_status.update_one(
        {'evse_id': evse_id},  # Match document based on evse_id
        {
            '$setOnInsert': {  # Set these fields only when creating a new document
                'station_id': station_id,
                'evse_id': evse_id,
                'evse_number': evse_number
            },
            '$push': {'updates': {'timestamp': timestamp, 'new_status': new_status}}
        },
        upsert=True  # Create a new document if one doesn't exist
    )

# %%
# Define mapping functions for state abbreviation
def map_state_name_to_abbreviation(state):
    state_map = {
        "alabama": "AL", "alaska": "AK", "arizona": "AZ", "arkansas": "AR", "california": "CA",
        "colorado": "CO", "connecticut": "CT", "delaware": "DE", "florida": "FL", "georgia": "GA",
        "hawaii": "HI", "idaho": "ID", "illinois": "IL", "indiana": "IN", "iowa": "IA",
        "kansas": "KS", "kentucky": "KY", "louisiana": "LA", "maine": "ME", "maryland": "MD",
        "massachusetts": "MA", "michigan": "MI", "minnesota": "MN", "mississippi": "MS", "missouri": "MO",
        "montana": "MT", "nebraska": "NE", "nevada": "NV", "new hampshire": "NH", "new jersey": "NJ",
        "new mexico": "NM", "new york": "NY", "north carolina": "NC", "north dakota": "ND", "ohio": "OH",
        "oklahoma": "OK", "oregon": "OR", "pennsylvania": "PA", "rhode island": "RI", "south carolina": "SC",
        "south dakota": "SD", "tennessee": "TN", "texas": "TX", "utah": "UT", "vermont": "VT",
        "virginia": "VA", "washington": "WA", "west virginia": "WV", "wisconsin": "WI", "wyoming": "WY"
    }
    return state_map.get(state, state)

evse_details_map = {
    (f"{item['evse_latitude']:.6f}", f"{item['evse_longitude']:.6f}"): (item['evse_id'], item['station_id'], item['evse_number'])
    for item in evses_joined
}

def get_evse_details(row):
    lat_str = f"{row['Latitude']:.6f}"
    long_str = f"{row['Longitude']:.6f}"
    return evse_details_map.get((lat_str, long_str), (None, None, None))

# Apply the function to each row in the DataFrame
t_df[['evse_id', 'station_id', 'evse_number']] = t_df.apply(get_evse_details, axis=1, result_type='expand')

# Convert date fields and prepare additional columns
# t_df['transaction_date'] = pd.to_datetime(t_df['End Date']).astype('int64') // 10**6
t_df['state'] = t_df['State'].apply(map_state_name_to_abbreviation)
t_df['user_id'] = [random.choice(driver_ids)[0] for _ in range(len(t_df))]

# %%
# Prepare documents for MongoDB insertion
try:
    sessions_df = t_df.apply(lambda row: pd.Series({
        'evse_id': row['evse_id'],
        'station_name': row['Charging Station'],
        'station_id': row['station_id'],
        'evse_number': row['evse_number'],
        'start_date': row['Start Date'].strftime('%Y-%m-%d %H:%M:%S'),
        'end_date': row['End Date'].strftime('%Y-%m-%d %H:%M:%S'),
        'transaction_date': row['transaction_date'],
        'total_duration': row['Total Duration'],
        'charging_time': row['Charging Time'],
        'charge_level': row['Charging Port Type'],
        'port_number': row['Charging Ports'],
        'plug_type': row['Plug Type'],
        'energy_consumed_kwh': row['Energy Consumed'],
        'fee': row['Charges'],
        'user_id': row['user_id'],
        'city': row['City'],
        'state': row['state'],
        'country': 'USA',
        'postal_code': row['ZipCode'],
        'latitude':row['Latitude'],
        'longitude':row['Longitude']
    }), axis=1)

    sessions = sessions_df.to_dict('records')
    print("Documents prepared successfully for MongoDB insertion.")
except Exception as e:
    print(f"Failed to prepare documents: {e}")
# Out:
# Documents prepared successfully for MongoDB insertion.

# %%
# Define batch size
batch_size = 1000  # You can adjust the size based on performance and resource availability

# Insert documents in batches
try:
    for i in range(0, len(sessions), batch_size):
        batch = sessions[i:i+batch_size]
        charging_sessions.insert_many(batch)
        print(f"Processed {i + len(batch)} out of {len(sessions)} records successfully.")
        time.sleep(1)  # Optional: add a short delay to reduce system load (if necessary)
except Exception as e:
    print("Failed to bulk insert into charging_sessions:", e)

print("All documents have been inserted successfully.")
# Out:
# Processed 1000 out of 48327 records successfully.
# Processed 2000 out of 48327 records successfully.
# Processed 3000 out of 48327 records successfully.
# Processed 4000 out of 48327 records successfully.
# Processed 5000 out of 48327 records successfully.
# Processed 6000 out of 48327 records successfully.
# Processed 7000 out of 48327 records successfully.
# Processed 8000 out of 48327 records successfully.
# Processed 9000 out of 48327 records successfully.
# Processed 10000 out of 48327 records successfully.
# Processed 11000 out of 48327 records successfully.
# Processed 12000 out of 48327 records successfully.
# Processed 13000 out of 48327 records successfully.
# Processed 14000 out of 48327 records successfully.
# Processed 15000 out of 48327 records successfully.
# Processed 16000 out of 48327 records successfully.
# Processed 17000 out of 48327 records successfully.
# Processed 18000 out of 48327 records successfully.
# Processed 19000 out of 48327 records successfully.
# Processed 20000 out of 48327 records successfully.
# Processed 21000 out of 48327 records successfully.
# Processed 22000 out of 48327 records successfully.
# Processed 23000 out of 48327 records successfully.
# Processed 24000 out of 48327 records successfully.
# Processed 25000 out of 48327 records successfully.
# Processed 26000 out of 48327 records successfully.
# Processed 27000 out of 48327 records successfully.
# Processed 28000 out of 48327 records successfully.
# Processed 29000 out of 48327 records successfully.
# Processed 30000 out of 48327 records successfully.
# Processed 31000 out of 48327 records successfully.
# Processed 32000 out of 48327 records successfully.
# Processed 33000 out of 48327 records successfully.
# Processed 34000 out of 48327 records successfully.
# Processed 35000 out of 48327 records successfully.
# Processed 36000 out of 48327 records successfully.
# Processed 37000 out of 48327 records successfully.
# Processed 38000 out of 48327 records successfully.
# Processed 39000 out of 48327 records successfully.
# Processed 40000 out of 48327 records successfully.
# Processed 41000 out of 48327 records successfully.
# Processed 42000 out of 48327 records successfully.
# Processed 43000 out of 48327 records successfully.
# Processed 44000 out of 48327 records successfully.
# Processed 45000 out of 48327 records successfully.
# Processed 46000 out of 48327 records successfully.
# Processed 47000 out of 48327 records successfully.
# Processed 48000 out of 48327 records successfully.
# Processed 48327 out of 48327 records successfully.
# All documents have been inserted successfully.

# %% [markdown]
# ## Third Pass - Populate MongoDB with EVSE updates data

# %%
try:
    evses_df = t_df.apply(lambda row: pd.Series({
        'evse_id': row['evse_id'],
        'station_id': row['station_id'],
        'evse_number': row['evse_number'],
    }), axis = 1)
    evses_df = evses_df.drop_duplicates()

    evse_docs = evses_df.to_dict('records')
    print("Documents prepared successfully for MongoDB insertion.")
except Exception as e:
    print(f"Failed to prepare evse documents: {e}")
# Out:
# Documents prepared successfully for MongoDB insertion.

# %%
t_df['in_use_timestamp'] = pd.to_datetime(t_df['Start Date']).astype('int64') // 10**6

try:
    starts_df = t_df.apply(lambda row: pd.Series({
        'evse_id': row['evse_id'],
        'timestamp': row['in_use_timestamp'],
        'new_status': 'in-use'
    }), axis=1)

    start_docs = starts_df.to_dict('records')
    print("Documents prepared successfully for MongoDB insertion.")
except Exception as e:
    print(f"Failed to prepare start documents: {e}")
# Out:
# Documents prepared successfully for MongoDB insertion.

# %%
try:
    ends_df = t_df.apply(lambda row: pd.Series({
        'evse_id': row['evse_id'],
        'timestamp': row['transaction_date'],
        'new_status': 'available'
    }), axis=1)

    end_docs = ends_df.to_dict('records')
    print("Documents prepared successfully for MongoDB insertion.")
except Exception as e:
    print(f"Failed to prepare end documents: {e}")
# Out:
# Documents prepared successfully for MongoDB insertion.

# %%
# Create a lookup dictionary for quick access to evse_docs dictionaries by evse_id
evse_lookup = {}

for evse in evse_docs:
    evse['updates'] = []  # Initialize the 'updates' list
    evse_lookup[evse['evse_id']] = evse

# %%
# Function to process updates and print progress
def process_updates(docs, description):
    total_docs = len(docs)
    for index, doc in enumerate(docs):
        evse_id = doc['evse_id']
        if evse_id in evse_lookup:
            update_info = {'timestamp': doc['timestamp'], 'new_status': doc['new_status']}
            evse_lookup[evse_id]['updates'].append(update_info)
        
        # Print progress every 10,000 entries or at the end of the list
        if index % 10000 == 0 or index == total_docs - 1:
            print(f"Processed {index + 1}/{total_docs} {description}")

# Process start_docs and end_docs
process_updates(start_docs, "start documents")
process_updates(end_docs, "end documents")

# Sort each EVSE's updates list by 'timestamp'
for evse_id, evse in evse_lookup.items():
    evse['updates'].sort(key=lambda x: x['timestamp'])

# Optionally, convert evse_lookup back to a list if needed for further processing or output
sorted_evse_docs = list(evse_lookup.values())
# Out:
# Processed 1/48327 start documents
# Processed 10001/48327 start documents
# Processed 20001/48327 start documents
# Processed 30001/48327 start documents
# Processed 40001/48327 start documents
# Processed 48327/48327 start documents
# Processed 1/48327 end documents
# Processed 10001/48327 end documents
# Processed 20001/48327 end documents
# Processed 30001/48327 end documents
# Processed 40001/48327 end documents
# Processed 48327/48327 end documents

# %%
# Add simulated different statuses
# Get current time in milliseconds since the epoch
current_time_milliseconds = int(time.time() * 1000)

for evse in sorted_evse_docs:
    # Generate a random number between 0 and 1
    rand_num = random.random()

    # 20% chance to append 'in-use' status
    if rand_num < 0.20:
        evse['updates'].append({'timestamp': current_time_milliseconds, 'new_status': 'in-use'})
    # 10% chance to append 'out of service' status
    elif rand_num < 0.30:  # 0.20 to 0.30 range
        evse['updates'].append({'timestamp': current_time_milliseconds, 'new_status': 'out of service'})
    # 10% chance to append 'unavailable' status
    elif rand_num < 0.40:  # 0.30 to 0.40 range
        evse['updates'].append({'timestamp': current_time_milliseconds, 'new_status': 'unavailable'})

    # Optionally, ensure the updates remain sorted after adding new ones
    evse['updates'].sort(key=lambda x: x['timestamp'])

# Print some examples to verify
sorted_evse_docs[:2]
# Out:
# [{'evse_id': 1,
#   'station_id': 1,
#   'evse_number': 1,
#   'updates': [{'timestamp': 1593284700000, 'new_status': 'in-use'},
#    {'timestamp': 1593285420000, 'new_status': 'available'},
#    {'timestamp': 1593550020000, 'new_status': 'in-use'},
#    {'timestamp': 1593550620000, 'new_status': 'available'},
#    {'timestamp': 1594475040000, 'new_status': 'in-use'},
#    {'timestamp': 1594478040000, 'new_status': 'available'},
#    {'timestamp': 1595073060000, 'new_status': 'in-use'},
#    {'timestamp': 1595082540000, 'new_status': 'available'},
#    {'timestamp': 1595245860000, 'new_status': 'in-use'},
#    {'timestamp': 1595256480000, 'new_status': 'available'},
#    {'timestamp': 1596197940000, 'new_status': 'in-use'},
#    {'timestamp': 1596208020000, 'new_status': 'available'},
#    {'timestamp': 1596285360000, 'new_status': 'in-use'},
#    {'timestamp': 1596289500000, 'new_status': 'available'},
#    {'timestamp': 1596309840000, 'new_status': 'in-use'},
#    {'timestamp': 1596313500000, 'new_status': 'available'},
#    {'timestamp': 1596566940000, 'new_status': 'in-use'},
#    {'timestamp': 1596572580000, 'new_status': 'available'},
#    {'timestamp': 1596653520000, 'new_status': 'in-use'},
#    {'timestamp': 1596659880000, 'new_status': 'available'},
#    {'timestamp': 1597507740000, 'new_status': 'in-use'},
#    {'timestamp': 1597525260000, 'new_status': 'available'},
#    {'timestamp': 1597661040000, 'new_status': 'in-use'},
#    {'timestamp': 1597666320000, 'new_status': 'available'},
#    {'timestamp': 1597958220000, 'new_status': 'in-use'},
#    {'timestamp': 1597962300000, 'new_status': 'available'},
#    {'timestamp': 1598296320000, 'new_status': 'in-use'},
#    {'timestamp': 1598305980000, 'new_status': 'available'},
#    {'timestamp': 1598427000000, 'new_status': 'in-use'},
#    {'timestamp': 1598436060000, 'new_status': 'available'},
#    {'timestamp': 1598793720000, 'new_status': 'in-use'},
#    {'timestamp': 1598795700000, 'new_status': 'available'},
#    {'timestamp': 1599391320000, 'new_status': 'in-use'},
#    {'timestamp': 1599397380000, 'new_status': 'available'},
#    {'timestamp': 1599483060000, 'new_status': 'in-use'},
#    {'timestamp': 1599486240000, 'new_status': 'available'},
#    {'timestamp': 1602596400000, 'new_status': 'in-use'},
#    {'timestamp': 1602601260000, 'new_status': 'available'},
#    {'timestamp': 1602667380000, 'new_status': 'in-use'},
#    {'timestamp': 1602748320000, 'new_status': 'available'},
#    {'timestamp': 1602951720000, 'new_status': 'in-use'},
#    {'timestamp': 1602955080000, 'new_status': 'available'},
#    {'timestamp': 1602960360000, 'new_status': 'in-use'},
#    {'timestamp': 1602967140000, 'new_status': 'available'},
#    {'timestamp': 1602980640000, 'new_status': 'in-use'},
#    {'timestamp': 1602982320000, 'new_status': 'available'},
#    {'timestamp': 1603114200000, 'new_status': 'in-use'},
#    {'timestamp': 1603115340000, 'new_status': 'available'},
#    {'timestamp': 1603200120000, 'new_status': 'in-use'},
#    {'timestamp': 1603204560000, 'new_status': 'available'},
#    {'timestamp': 1603240320000, 'new_status': 'in-use'},
#    {'timestamp': 1603241220000, 'new_status': 'available'},
#    {'timestamp': 1603277640000, 'new_status': 'in-use'},
#    {'timestamp': 1603288200000, 'new_status': 'available'},
#    {'timestamp': 1608040740000, 'new_status': 'in-use'},
#    {'timestamp': 1608047040000, 'new_status': 'available'},
#    {'timestamp': 1608836220000, 'new_status': 'in-use'},
#    {'timestamp': 1608837900000, 'new_status': 'available'}]},
#  {'evse_id': 2,
#   'station_id': 1,
#   'evse_number': 2,
#   'updates': [{'timestamp': 1559392260000, 'new_status': 'in-use'},
#    {'timestamp': 1559397180000, 'new_status': 'available'},
#    {'timestamp': 1559475420000, 'new_status': 'in-use'},
#    {'timestamp': 1559485020000, 'new_status': 'available'},
#    {'timestamp': 1559553660000, 'new_status': 'in-use'},
#    {'timestamp': 1559566920000, 'new_status': 'available'},
#    {'timestamp': 1559571480000, 'new_status': 'in-use'},
#    {'timestamp': 1559587020000, 'new_status': 'available'},
#    {'timestamp': 1559632740000, 'new_status': 'in-use'},
#    {'timestamp': 1559646480000, 'new_status': 'available'},
#    {'timestamp': 1559648700000, 'new_status': 'in-use'},
#    {'timestamp': 1559652300000, 'new_status': 'available'},
#    {'timestamp': 1559652720000, 'new_status': 'in-use'},
#    {'timestamp': 1559661900000, 'new_status': 'available'},
#    {'timestamp': 1559671620000, 'new_status': 'in-use'},
#    {'timestamp': 1559682420000, 'new_status': 'available'},
#    {'timestamp': 1559724060000, 'new_status': 'in-use'},
#    {'timestamp': 1559736180000, 'new_status': 'available'},
#    {'timestamp': 1559811480000, 'new_status': 'in-use'},
#    {'timestamp': 1559819580000, 'new_status': 'available'},
#    {'timestamp': 1559822100000, 'new_status': 'in-use'},
#    {'timestamp': 1559835120000, 'new_status': 'available'},
#    {'timestamp': 1559896200000, 'new_status': 'in-use'},
#    {'timestamp': 1559907780000, 'new_status': 'available'},
#    {'timestamp': 1559910840000, 'new_status': 'in-use'},
#    {'timestamp': 1559913180000, 'new_status': 'available'},
#    {'timestamp': 1559923020000, 'new_status': 'in-use'},
#    {'timestamp': 1559941920000, 'new_status': 'available'},
#    {'timestamp': 1559999820000, 'new_status': 'in-use'},
#    {'timestamp': 1560009060000, 'new_status': 'available'},
#    {'timestamp': 1560014280000, 'new_status': 'in-use'},
#    {'timestamp': 1560020760000, 'new_status': 'available'},
#    {'timestamp': 1560026940000, 'new_status': 'in-use'},
#    {'timestamp': 1560034500000, 'new_status': 'available'},
#    {'timestamp': 1560074460000, 'new_status': 'in-use'},
#    {'timestamp': 1560076860000, 'new_status': 'available'},
#    {'timestamp': 1560088020000, 'new_status': 'in-use'},
#    {'timestamp': 1560117540000, 'new_status': 'available'},
#    {'timestamp': 1560156720000, 'new_status': 'in-use'},
#    {'timestamp': 1560168180000, 'new_status': 'available'},
#    {'timestamp': 1560187440000, 'new_status': 'in-use'},
#    {'timestamp': 1560191640000, 'new_status': 'available'},
#    {'timestamp': 1560194160000, 'new_status': 'in-use'},
#    {'timestamp': 1560197940000, 'new_status': 'available'},
#    {'timestamp': 1560245160000, 'new_status': 'in-use'},
#    {'timestamp': 1560249840000, 'new_status': 'available'},
#    {'timestamp': 1560267480000, 'new_status': 'in-use'},
#    {'timestamp': 1560274980000, 'new_status': 'available'},
#    {'timestamp': 1560331740000, 'new_status': 'in-use'},
#    {'timestamp': 1560341880000, 'new_status': 'available'},
#    {'timestamp': 1560347160000, 'new_status': 'in-use'},
#    {'timestamp': 1560364440000, 'new_status': 'available'},
#    {'timestamp': 1560417780000, 'new_status': 'in-use'},
#    {'timestamp': 1560428280000, 'new_status': 'available'},
#    {'timestamp': 1560429300000, 'new_status': 'in-use'},
#    {'timestamp': 1560446100000, 'new_status': 'available'},
#    {'timestamp': 1560455400000, 'new_status': 'in-use'},
#    {'timestamp': 1560458940000, 'new_status': 'available'},
#    {'timestamp': 1560513000000, 'new_status': 'in-use'},
#    {'timestamp': 1560517320000, 'new_status': 'available'},
#    {'timestamp': 1560517800000, 'new_status': 'in-use'},
#    {'timestamp': 1560525180000, 'new_status': 'available'},
#    {'timestamp': 1560537180000, 'new_status': 'in-use'},
#    {'timestamp': 1560554340000, 'new_status': 'available'},
#    {'timestamp': 1560678300000, 'new_status': 'in-use'},
#    {'timestamp': 1560682380000, 'new_status': 'available'},
#    {'timestamp': 1560760560000, 'new_status': 'in-use'},
#    {'timestamp': 1560772080000, 'new_status': 'available'},
#    {'timestamp': 1560779220000, 'new_status': 'in-use'},
#    {'timestamp': 1560787320000, 'new_status': 'available'},
#    {'timestamp': 1560847620000, 'new_status': 'in-use'},
#    {'timestamp': 1560854340000, 'new_status': 'available'},
#    {'timestamp': 1560861840000, 'new_status': 'in-use'},
#    {'timestamp': 1560877500000, 'new_status': 'available'},
#    {'timestamp': 1560881760000, 'new_status': 'in-use'},
#    {'timestamp': 1560886860000, 'new_status': 'available'},
#    {'timestamp': 1560943680000, 'new_status': 'in-use'},
#    {'timestamp': 1560947880000, 'new_status': 'available'},
#    {'timestamp': 1560950760000, 'new_status': 'in-use'},
#    {'timestamp': 1560957720000, 'new_status': 'available'},
#    {'timestamp': 1560971820000, 'new_status': 'in-use'},
#    {'timestamp': 1560976560000, 'new_status': 'available'},
#    {'timestamp': 1561028460000, 'new_status': 'in-use'},
#    {'timestamp': 1561044060000, 'new_status': 'available'},
#    {'timestamp': 1561108560000, 'new_status': 'in-use'},
#    {'timestamp': 1561118520000, 'new_status': 'available'},
#    {'timestamp': 1561120080000, 'new_status': 'in-use'},
#    {'timestamp': 1561121580000, 'new_status': 'available'},
#    {'timestamp': 1561124040000, 'new_status': 'in-use'},
#    {'timestamp': 1561132380000, 'new_status': 'available'},
#    {'timestamp': 1561142400000, 'new_status': 'in-use'},
#    {'timestamp': 1561144500000, 'new_status': 'available'},
#    {'timestamp': 1561146900000, 'new_status': 'in-use'},
#    {'timestamp': 1561159740000, 'new_status': 'available'},
#    {'timestamp': 1561230480000, 'new_status': 'in-use'},
#    {'timestamp': 1561238040000, 'new_status': 'available'},
#    {'timestamp': 1561291200000, 'new_status': 'in-use'},
#    {'timestamp': 1561295760000, 'new_status': 'available'},
#    {'timestamp': 1561299720000, 'new_status': 'in-use'},
#    {'timestamp': 1561313040000, 'new_status': 'available'},
#    {'timestamp': 1561369200000, 'new_status': 'in-use'},
#    {'timestamp': 1561379040000, 'new_status': 'available'},
#    {'timestamp': 1561379220000, 'new_status': 'in-use'},
#    {'timestamp': 1561389480000, 'new_status': 'available'},
#    {'timestamp': 1561399260000, 'new_status': 'in-use'},
#    {'timestamp': 1561410120000, 'new_status': 'available'},
#    {'timestamp': 1561452780000, 'new_status': 'in-use'},
#    {'timestamp': 1561464240000, 'new_status': 'available'},
#    {'timestamp': 1561468020000, 'new_status': 'in-use'},
#    {'timestamp': 1561479600000, 'new_status': 'available'},
#    {'timestamp': 1561484520000, 'new_status': 'in-use'},
#    {'timestamp': 1561495620000, 'new_status': 'available'},
#    {'timestamp': 1561546980000, 'new_status': 'in-use'},
#    {'timestamp': 1561566360000, 'new_status': 'available'},
#    {'timestamp': 1561575300000, 'new_status': 'in-use'},
#    {'timestamp': 1561585260000, 'new_status': 'available'},
#    {'timestamp': 1561643580000, 'new_status': 'in-use'},
#    {'timestamp': 1561648020000, 'new_status': 'available'},
#    {'timestamp': 1561720800000, 'new_status': 'in-use'},
#    {'timestamp': 1561730400000, 'new_status': 'available'},
#    {'timestamp': 1561732200000, 'new_status': 'in-use'},
#    {'timestamp': 1561732860000, 'new_status': 'available'},
#    {'timestamp': 1561735620000, 'new_status': 'in-use'},
#    {'timestamp': 1561747440000, 'new_status': 'available'},
#    {'timestamp': 1561753020000, 'new_status': 'in-use'},
#    {'timestamp': 1561760940000, 'new_status': 'available'},
#    {'timestamp': 1561805280000, 'new_status': 'in-use'},
#    {'timestamp': 1561813800000, 'new_status': 'available'},
#    {'timestamp': 1561815180000, 'new_status': 'in-use'},
#    {'timestamp': 1561818960000, 'new_status': 'available'},
#    {'timestamp': 1561833960000, 'new_status': 'in-use'},
#    {'timestamp': 1561842540000, 'new_status': 'available'},
#    {'timestamp': 1561975620000, 'new_status': 'in-use'},
#    {'timestamp': 1561985880000, 'new_status': 'available'},
#    {'timestamp': 1562003160000, 'new_status': 'in-use'},
#    {'timestamp': 1562014080000, 'new_status': 'available'},
#    {'timestamp': 1562057160000, 'new_status': 'in-use'},
#    {'timestamp': 1562060460000, 'new_status': 'available'},
#    {'timestamp': 1562068800000, 'new_status': 'in-use'},
#    {'timestamp': 1562077320000, 'new_status': 'available'},
#    {'timestamp': 1562089680000, 'new_status': 'in-use'},
#    {'timestamp': 1562098560000, 'new_status': 'available'},
#    {'timestamp': 1562148900000, 'new_status': 'in-use'},
#    {'timestamp': 1562159520000, 'new_status': 'available'},
#    {'timestamp': 1562169480000, 'new_status': 'in-use'},
#    {'timestamp': 1562176680000, 'new_status': 'available'},
#    {'timestamp': 1562319900000, 'new_status': 'in-use'},
#    {'timestamp': 1562323440000, 'new_status': 'available'},
#    {'timestamp': 1562435160000, 'new_status': 'in-use'},
#    {'timestamp': 1562445720000, 'new_status': 'available'},
#    {'timestamp': 1562574540000, 'new_status': 'in-use'},
#    {'timestamp': 1562576580000, 'new_status': 'available'},
#    {'timestamp': 1562581020000, 'new_status': 'in-use'},
#    {'timestamp': 1562590740000, 'new_status': 'available'},
#    {'timestamp': 1562596020000, 'new_status': 'in-use'},
#    {'timestamp': 1562599560000, 'new_status': 'available'},
#    {'timestamp': 1562608260000, 'new_status': 'in-use'},
#    {'timestamp': 1562618880000, 'new_status': 'available'},
#    {'timestamp': 1562663280000, 'new_status': 'in-use'},
#    {'timestamp': 1562669400000, 'new_status': 'available'},
#    {'timestamp': 1562669820000, 'new_status': 'in-use'},
#    {'timestamp': 1562678760000, 'new_status': 'available'},
#    {'timestamp': 1562679240000, 'new_status': 'in-use'},
#    {'timestamp': 1562687340000, 'new_status': 'available'},
#    {'timestamp': 1562756340000, 'new_status': 'in-use'},
#    {'timestamp': 1562760420000, 'new_status': 'available'},
#    {'timestamp': 1562761260000, 'new_status': 'in-use'},
#    {'timestamp': 1562781480000, 'new_status': 'available'},
#    {'timestamp': 1562781660000, 'new_status': 'in-use'},
#    {'timestamp': 1562785260000, 'new_status': 'available'},
#    {'timestamp': 1562840340000, 'new_status': 'in-use'},
#    {'timestamp': 1562851860000, 'new_status': 'available'},
#    {'timestamp': 1562854020000, 'new_status': 'in-use'},
#    {'timestamp': 1562867820000, 'new_status': 'available'},
#    {'timestamp': 1562869440000, 'new_status': 'in-use'},
#    {'timestamp': 1562883540000, 'new_status': 'available'},
#    {'timestamp': 1562914320000, 'new_status': 'in-use'},
#    {'timestamp': 1562916900000, 'new_status': 'available'},
#    {'timestamp': 1562928120000, 'new_status': 'in-use'},
#    {'timestamp': 1562933820000, 'new_status': 'available'},
#    {'timestamp': 1562939280000, 'new_status': 'in-use'},
#    {'timestamp': 1562952720000, 'new_status': 'available'},
#    {'timestamp': 1562955480000, 'new_status': 'in-use'},
#    {'timestamp': 1562958420000, 'new_status': 'available'},
#    {'timestamp': 1562960460000, 'new_status': 'in-use'},
#    {'timestamp': 1562965740000, 'new_status': 'available'},
#    {'timestamp': 1562968260000, 'new_status': 'in-use'},
#    {'timestamp': 1562975700000, 'new_status': 'available'},
#    {'timestamp': 1563021060000, 'new_status': 'in-use'},
#    {'timestamp': 1563039180000, 'new_status': 'available'},
#    {'timestamp': 1563043800000, 'new_status': 'in-use'},
#    {'timestamp': 1563046860000, 'new_status': 'available'},
#    {'timestamp': 1563056280000, 'new_status': 'in-use'},
#    {'timestamp': 1563064500000, 'new_status': 'available'},
#    {'timestamp': 1563185820000, 'new_status': 'in-use'},
#    {'timestamp': 1563195840000, 'new_status': 'available'},
#    {'timestamp': 1563195900000, 'new_status': 'in-use'},
#    {'timestamp': 1563196440000, 'new_status': 'available'},
#    {'timestamp': 1563197460000, 'new_status': 'in-use'},
#    {'timestamp': 1563208140000, 'new_status': 'available'},
#    {'timestamp': 1563211860000, 'new_status': 'in-use'},
#    {'timestamp': 1563222420000, 'new_status': 'available'},
#    {'timestamp': 1563273720000, 'new_status': 'in-use'},
#    {'timestamp': 1563280380000, 'new_status': 'available'},
#    {'timestamp': 1563280920000, 'new_status': 'in-use'},
#    {'timestamp': 1563286440000, 'new_status': 'available'},
#    {'timestamp': 1563286500000, 'new_status': 'in-use'},
#    {'timestamp': 1563302880000, 'new_status': 'available'},
#    {'timestamp': 1563352440000, 'new_status': 'in-use'},
#    {'timestamp': 1563369600000, 'new_status': 'available'},
#    {'timestamp': 1563370620000, 'new_status': 'in-use'},
#    {'timestamp': 1563383100000, 'new_status': 'available'},
#    {'timestamp': 1563391140000, 'new_status': 'in-use'},
#    {'timestamp': 1563405180000, 'new_status': 'available'},
#    {'timestamp': 1563444600000, 'new_status': 'in-use'},
#    {'timestamp': 1563462420000, 'new_status': 'available'},
#    {'timestamp': 1563463440000, 'new_status': 'in-use'},
#    {'timestamp': 1563473880000, 'new_status': 'available'},
#    {'timestamp': 1563529260000, 'new_status': 'in-use'},
#    {'timestamp': 1563540360000, 'new_status': 'available'},
#    {'timestamp': 1563540840000, 'new_status': 'in-use'},
#    {'timestamp': 1563556260000, 'new_status': 'available'},
#    {'timestamp': 1563573660000, 'new_status': 'in-use'},
#    {'timestamp': 1563580380000, 'new_status': 'available'},
#    {'timestamp': 1563648180000, 'new_status': 'in-use'},
#    {'timestamp': 1563657180000, 'new_status': 'available'},
#    {'timestamp': 1563784680000, 'new_status': 'in-use'},
#    {'timestamp': 1563800880000, 'new_status': 'available'},
#    {'timestamp': 1563802560000, 'new_status': 'in-use'},
#    {'timestamp': 1563815580000, 'new_status': 'available'},
#    {'timestamp': 1563817200000, 'new_status': 'in-use'},
#    {'timestamp': 1563826500000, 'new_status': 'available'},
#    {'timestamp': 1563872520000, 'new_status': 'in-use'},
#    {'timestamp': 1563884100000, 'new_status': 'available'},
#    {'timestamp': 1563887700000, 'new_status': 'in-use'},
#    {'timestamp': 1563896820000, 'new_status': 'available'},
#    {'timestamp': 1563958500000, 'new_status': 'in-use'},
#    {'timestamp': 1563969360000, 'new_status': 'available'},
#    {'timestamp': 1563976320000, 'new_status': 'in-use'},
#    {'timestamp': 1563983820000, 'new_status': 'available'},
#    {'timestamp': 1563984000000, 'new_status': 'in-use'},
#    {'timestamp': 1563989520000, 'new_status': 'available'},
#    {'timestamp': 1563992160000, 'new_status': 'in-use'},
#    {'timestamp': 1563999780000, 'new_status': 'available'},
#    {'timestamp': 1564046640000, 'new_status': 'in-use'},
#    {'timestamp': 1564050660000, 'new_status': 'available'},
#    {'timestamp': 1564050720000, 'new_status': 'in-use'},
#    {'timestamp': 1564082400000, 'new_status': 'available'},
#    {'timestamp': 1564085340000, 'new_status': 'in-use'},
#    {'timestamp': 1564096020000, 'new_status': 'available'},
#    {'timestamp': 1564135140000, 'new_status': 'in-use'},
#    {'timestamp': 1564146060000, 'new_status': 'available'},
#    {'timestamp': 1564149180000, 'new_status': 'in-use'},
#    {'timestamp': 1564160400000, 'new_status': 'available'},
#    {'timestamp': 1564166040000, 'new_status': 'in-use'},
#    {'timestamp': 1564171380000, 'new_status': 'available'},
#    {'timestamp': 1564231020000, 'new_status': 'in-use'},
#    {'timestamp': 1564237020000, 'new_status': 'available'},
#    {'timestamp': 1564237680000, 'new_status': 'in-use'},
#    {'timestamp': 1564249020000, 'new_status': 'available'},
#    {'timestamp': 1564249080000, 'new_status': 'in-use'},
#    {'timestamp': 1564251540000, 'new_status': 'available'},
#    {'timestamp': 1564305540000, 'new_status': 'in-use'},
#    {'timestamp': 1564314780000, 'new_status': 'available'},
#    {'timestamp': 1564393740000, 'new_status': 'in-use'},
#    {'timestamp': 1564405860000, 'new_status': 'available'},
#    {'timestamp': 1564410000000, 'new_status': 'in-use'},
#    {'timestamp': 1564421760000, 'new_status': 'available'},
#    {'timestamp': 1564476240000, 'new_status': 'in-use'},
#    {'timestamp': 1564492920000, 'new_status': 'available'},
#    {'timestamp': 1564495320000, 'new_status': 'in-use'},
#    {'timestamp': 1564498860000, 'new_status': 'available'},
#    {'timestamp': 1564499460000, 'new_status': 'in-use'},
#    {'timestamp': 1564502580000, 'new_status': 'available'},
#    {'timestamp': 1564508220000, 'new_status': 'in-use'},
#    {'timestamp': 1564509900000, 'new_status': 'available'},
#    {'timestamp': 1564574880000, 'new_status': 'in-use'},
#    {'timestamp': 1564579980000, 'new_status': 'available'},
#    {'timestamp': 1564586460000, 'new_status': 'in-use'},
#    {'timestamp': 1564594380000, 'new_status': 'available'},
#    {'timestamp': 1564658280000, 'new_status': 'in-use'},
#    {'timestamp': 1564669800000, 'new_status': 'available'},
#    {'timestamp': 1564674840000, 'new_status': 'in-use'},
#    {'timestamp': 1564680660000, 'new_status': 'available'},
#    {'timestamp': 1564684140000, 'new_status': 'in-use'},
#    {'timestamp': 1564688400000, 'new_status': 'available'},
#    {'timestamp': 1564737900000, 'new_status': 'in-use'},
#    {'timestamp': 1564747260000, 'new_status': 'available'},
#    {'timestamp': 1564768500000, 'new_status': 'in-use'},
#    {'timestamp': 1564777740000, 'new_status': 'available'},
#    {'timestamp': 1564781340000, 'new_status': 'in-use'},
#    {'timestamp': 1564785120000, 'new_status': 'available'},
#    {'timestamp': 1564866660000, 'new_status': 'in-use'},
#    {'timestamp': 1564868160000, 'new_status': 'available'},
#    {'timestamp': 1564907700000, 'new_status': 'in-use'},
#    {'timestamp': 1564915980000, 'new_status': 'available'},
#    {'timestamp': 1564932360000, 'new_status': 'in-use'},
#    {'timestamp': 1565000160000, 'new_status': 'available'},
#    {'timestamp': 1565015520000, 'new_status': 'in-use'},
#    {'timestamp': 1565029440000, 'new_status': 'available'},
#    {'timestamp': 1565079840000, 'new_status': 'in-use'},
#    {'timestamp': 1565091720000, 'new_status': 'available'},
#    {'timestamp': 1565094960000, 'new_status': 'in-use'},
#    {'timestamp': 1565101380000, 'new_status': 'available'},
#    {'timestamp': 1565102220000, 'new_status': 'in-use'},
#    {'timestamp': 1565110140000, 'new_status': 'available'},
#    {'timestamp': 1565164980000, 'new_status': 'in-use'},
#    {'timestamp': 1565178000000, 'new_status': 'available'},
#    {'timestamp': 1565179500000, 'new_status': 'in-use'},
#    {'timestamp': 1565204100000, 'new_status': 'available'},
#    {'timestamp': 1565207580000, 'new_status': 'in-use'},
#    {'timestamp': 1565216640000, 'new_status': 'available'},
#    {'timestamp': 1565253960000, 'new_status': 'in-use'},
#    {'timestamp': 1565261340000, 'new_status': 'available'},
#    {'timestamp': 1565262840000, 'new_status': 'in-use'},
#    {'timestamp': 1565273940000, 'new_status': 'available'},
#    {'timestamp': 1565286720000, 'new_status': 'in-use'},
#    {'timestamp': 1565294760000, 'new_status': 'available'},
#    {'timestamp': 1565298060000, 'new_status': 'in-use'},
#    {'timestamp': 1565302980000, 'new_status': 'available'},
#    {'timestamp': 1565341380000, 'new_status': 'in-use'},
#    {'timestamp': 1565352300000, 'new_status': 'available'},
#    {'timestamp': 1565356860000, 'new_status': 'in-use'},
#    {'timestamp': 1565370480000, 'new_status': 'available'},
#    {'timestamp': 1565449320000, 'new_status': 'in-use'},
#    {'timestamp': 1565459100000, 'new_status': 'available'},
#    {'timestamp': 1565465820000, 'new_status': 'in-use'},
#    {'timestamp': 1565468400000, 'new_status': 'available'},
#    {'timestamp': 1565604840000, 'new_status': 'in-use'},
#    {'timestamp': 1565610900000, 'new_status': 'available'},
#    {'timestamp': 1565616360000, 'new_status': 'in-use'},
#    {'timestamp': 1565623560000, 'new_status': 'available'},
#    {'timestamp': 1565626080000, 'new_status': 'in-use'},
#    {'timestamp': 1565630760000, 'new_status': 'available'},
#    {'timestamp': 1565631060000, 'new_status': 'in-use'},
#    {'timestamp': 1565633280000, 'new_status': 'available'},
#    {'timestamp': 1565634300000, 'new_status': 'in-use'},
#    {'timestamp': 1565636040000, 'new_status': 'available'},
#    {'timestamp': 1565694960000, 'new_status': 'in-use'},
#    {'timestamp': 1565703900000, 'new_status': 'available'},
#    {'timestamp': 1565705520000, 'new_status': 'in-use'},
#    {'timestamp': 1565715240000, 'new_status': 'available'},
#    {'timestamp': 1565718240000, 'new_status': 'in-use'},
#    {'timestamp': 1565729280000, 'new_status': 'available'},
#    {'timestamp': 1565784180000, 'new_status': 'in-use'},
#    {'timestamp': 1565791440000, 'new_status': 'available'},
#    {'timestamp': 1565796780000, 'new_status': 'in-use'},
#    {'timestamp': 1565808120000, 'new_status': 'available'},
#    {'timestamp': 1565810640000, 'new_status': 'in-use'},
#    {'timestamp': 1565821620000, 'new_status': 'available'},
#    {'timestamp': 1565870820000, 'new_status': 'in-use'},
#    {'timestamp': 1565877720000, 'new_status': 'available'},
#    {'timestamp': 1565893200000, 'new_status': 'in-use'},
#    {'timestamp': 1565897760000, 'new_status': 'available'},
#    {'timestamp': 1565968200000, 'new_status': 'in-use'},
#    {'timestamp': 1565970960000, 'new_status': 'available'},
#    {'timestamp': 1565985120000, 'new_status': 'in-use'},
#    {'timestamp': 1565986260000, 'new_status': 'available'},
#    {'timestamp': 1566056520000, 'new_status': 'in-use'},
#    {'timestamp': 1566058260000, 'new_status': 'available'},
#    {'timestamp': 1566064260000, 'new_status': 'in-use'},
#    {'timestamp': 1566069600000, 'new_status': 'available'},
#    {'timestamp': 1566121380000, 'new_status': 'in-use'},
#    {'timestamp': 1566129540000, 'new_status': 'available'},
#    {'timestamp': 1566134040000, 'new_status': 'in-use'},
#    {'timestamp': 1566140580000, 'new_status': 'available'},
#    {'timestamp': 1566152280000, 'new_status': 'in-use'},
#    {'timestamp': 1566156180000, 'new_status': 'available'},
#    {'timestamp': 1566202980000, 'new_status': 'in-use'},
#    {'timestamp': 1566213780000, 'new_status': 'available'},
#    {'timestamp': 1566214080000, 'new_status': 'in-use'},
#    {'timestamp': 1566218640000, 'new_status': 'available'},
#    {'timestamp': 1566294240000, 'new_status': 'in-use'},
#    {'timestamp': 1566328020000, 'new_status': 'available'},
#    {'timestamp': 1566384000000, 'new_status': 'in-use'},
#    {'timestamp': 1566390360000, 'new_status': 'available'},
#    {'timestamp': 1566390480000, 'new_status': 'in-use'},
#    {'timestamp': 1566391680000, 'new_status': 'available'},
#    {'timestamp': 1566392940000, 'new_status': 'in-use'},
#    {'timestamp': 1566402660000, 'new_status': 'available'},
#    {'timestamp': 1566404700000, 'new_status': 'in-use'},
#    {'timestamp': 1566405300000, 'new_status': 'available'},
#    {'timestamp': 1566466380000, 'new_status': 'in-use'},
#    {'timestamp': 1566476820000, 'new_status': 'available'},
#    {'timestamp': 1566477540000, 'new_status': 'in-use'},
#    {'timestamp': 1566482940000, 'new_status': 'available'},
#    {'timestamp': 1566498840000, 'new_status': 'in-use'},
#    {'timestamp': 1566502380000, 'new_status': 'available'},
#    {'timestamp': 1566550380000, 'new_status': 'in-use'},
#    {'timestamp': 1566560880000, 'new_status': 'available'},
#    {'timestamp': 1566561900000, 'new_status': 'in-use'},
#    {'timestamp': 1566564840000, 'new_status': 'in-use'},
#    {'timestamp': 1566564840000, 'new_status': 'available'},
#    {'timestamp': 1566574260000, 'new_status': 'available'},
#    {'timestamp': 1566574860000, 'new_status': 'in-use'},
#    {'timestamp': 1566578340000, 'new_status': 'available'},
#    {'timestamp': 1566585180000, 'new_status': 'in-use'},
#    {'timestamp': 1566587580000, 'new_status': 'available'},
#    {'timestamp': 1566640560000, 'new_status': 'in-use'},
#    {'timestamp': 1566645000000, 'new_status': 'available'},
#    {'timestamp': 1566646500000, 'new_status': 'in-use'},
#    {'timestamp': 1566650820000, 'new_status': 'available'},
#    {'timestamp': 1566811980000, 'new_status': 'in-use'},
#    {'timestamp': 1566822900000, 'new_status': 'available'},
#    {'timestamp': 1566824040000, 'new_status': 'in-use'},
#    {'timestamp': 1566825960000, 'new_status': 'available'},
#    {'timestamp': 1566898440000, 'new_status': 'in-use'},
#    {'timestamp': 1566900600000, 'new_status': 'available'},
#    {'timestamp': 1566904980000, 'new_status': 'in-use'},
#    {'timestamp': 1566915780000, 'new_status': 'available'},
#    {'timestamp': 1566923460000, 'new_status': 'in-use'},
#    {'timestamp': 1566929820000, 'new_status': 'available'},
#    {'timestamp': 1566982680000, 'new_status': 'in-use'},
#    {'timestamp': 1566995160000, 'new_status': 'available'},
#    {'timestamp': 1566995580000, 'new_status': 'in-use'},
#    {'timestamp': 1566998340000, 'new_status': 'available'},
#    {'timestamp': 1567001340000, 'new_status': 'in-use'},
#    {'timestamp': 1567011420000, 'new_status': 'available'},
#    {'timestamp': 1567020780000, 'new_status': 'in-use'},
#    {'timestamp': 1567023660000, 'new_status': 'available'},
#    {'timestamp': 1567074240000, 'new_status': 'in-use'},
#    {'timestamp': 1567081860000, 'new_status': 'available'},
#    {'timestamp': 1567089600000, 'new_status': 'in-use'},
#    {'timestamp': 1567093560000, 'new_status': 'available'},
#    {'timestamp': 1567159500000, 'new_status': 'in-use'},
#    {'timestamp': 1567169640000, 'new_status': 'available'},
#    {'timestamp': 1567170300000, 'new_status': 'in-use'},
#    {'timestamp': 1567173300000, 'new_status': 'available'},
#    {'timestamp': 1567174080000, 'new_status': 'in-use'},
#    {'timestamp': 1567177980000, 'new_status': 'available'},
#    {'timestamp': 1567256640000, 'new_status': 'in-use'},
#    {'timestamp': 1567259700000, 'new_status': 'available'},
#    {'timestamp': 1567260480000, 'new_status': 'in-use'},
#    {'timestamp': 1567265700000, 'new_status': 'available'},
#    {'timestamp': 1567338420000, 'new_status': 'in-use'},
#    {'timestamp': 1567344420000, 'new_status': 'available'},
#    {'timestamp': 1567425600000, 'new_status': 'in-use'},
#    {'timestamp': 1567436160000, 'new_status': 'available'},
#    {'timestamp': 1567533780000, 'new_status': 'in-use'},
#    {'timestamp': 1567544040000, 'new_status': 'available'},
#    {'timestamp': 1567593120000, 'new_status': 'in-use'},
#    {'timestamp': 1567605660000, 'new_status': 'available'},
#    {'timestamp': 1567612500000, 'new_status': 'in-use'},
#    {'timestamp': 1567615140000, 'new_status': 'available'},
#    {'timestamp': 1567619460000, 'new_status': 'in-use'},
#    {'timestamp': 1567622640000, 'new_status': 'available'},
#    {'timestamp': 1567707480000, 'new_status': 'in-use'},
#    {'timestamp': 1567724340000, 'new_status': 'available'},
#    {'timestamp': 1567772940000, 'new_status': 'in-use'},
#    {'timestamp': 1567776360000, 'new_status': 'available'},
#    {'timestamp': 1567779480000, 'new_status': 'in-use'},
#    {'timestamp': 1567782720000, 'new_status': 'available'},
#    {'timestamp': 1567797360000, 'new_status': 'in-use'},
#    {'timestamp': 1567811580000, 'new_status': 'available'},
#    {'timestamp': 1567853280000, 'new_status': 'in-use'},
#    {'timestamp': 1567866420000, 'new_status': 'available'},
#    {'timestamp': 1567960620000, 'new_status': 'in-use'},
#    {'timestamp': 1567962000000, 'new_status': 'available'},
#    {'timestamp': 1568026200000, 'new_status': 'in-use'},
#    {'timestamp': 1568044680000, 'new_status': 'available'},
#    {'timestamp': 1568052360000, 'new_status': 'in-use'},
#    {'timestamp': 1568062920000, 'new_status': 'available'},
#    {'timestamp': 1568105760000, 'new_status': 'in-use'},
#    {'timestamp': 1568117280000, 'new_status': 'available'},
#    {'timestamp': 1568130600000, 'new_status': 'in-use'},
#    {'timestamp': 1568137200000, 'new_status': 'available'},
#    {'timestamp': 1568138760000, 'new_status': 'in-use'},
#    {'timestamp': 1568141640000, 'new_status': 'available'},
#    {'timestamp': 1568195460000, 'new_status': 'in-use'},
#    {'timestamp': 1568210160000, 'new_status': 'available'},
#    {'timestamp': 1568214420000, 'new_status': 'in-use'},
#    {'timestamp': 1568259720000, 'new_status': 'available'},
#    {'timestamp': 1568288040000, 'new_status': 'in-use'},
#    {'timestamp': 1568303760000, 'new_status': 'available'},
#    {'timestamp': 1568368140000, 'new_status': 'in-use'},
#    {'timestamp': 1568379840000, 'new_status': 'available'},
#    {'timestamp': 1568383980000, 'new_status': 'in-use'},
#    {'timestamp': 1568388900000, 'new_status': 'available'},
#    {'timestamp': 1568389140000, 'new_status': 'in-use'},
#    {'timestamp': 1568409000000, 'new_status': 'available'},
#    {'timestamp': 1568461500000, 'new_status': 'in-use'},
#    {'timestamp': 1568467500000, 'new_status': 'available'},
#    {'timestamp': 1568469840000, 'new_status': 'in-use'},
#    {'timestamp': 1568472960000, 'new_status': 'available'},
#    {'timestamp': 1568487720000, 'new_status': 'in-use'},
#    {'timestamp': 1568495880000, 'new_status': 'available'},
#    {'timestamp': 1568500560000, 'new_status': 'in-use'},
#    {'timestamp': 1568505900000, 'new_status': 'available'},
#    {'timestamp': 1568584200000, 'new_status': 'in-use'},
#    {'timestamp': 1568587560000, 'new_status': 'available'},
#    {'timestamp': 1568626080000, 'new_status': 'in-use'},
#    {'timestamp': 1568636520000, 'new_status': 'available'},
#    {'timestamp': 1568642220000, 'new_status': 'in-use'},
#    {'timestamp': 1568652780000, 'new_status': 'available'},
#    {'timestamp': 1568662260000, 'new_status': 'in-use'},
#    {'timestamp': 1568664240000, 'new_status': 'available'},
#    {'timestamp': 1568710080000, 'new_status': 'in-use'},
#    {'timestamp': 1568721780000, 'new_status': 'available'},
#    {'timestamp': 1568723100000, 'new_status': 'in-use'},
#    {'timestamp': 1568735280000, 'new_status': 'available'},
#    {'timestamp': 1568809320000, 'new_status': 'in-use'},
#    {'timestamp': 1568814480000, 'new_status': 'available'},
#    {'timestamp': 1568888760000, 'new_status': 'in-use'},
#    {'timestamp': 1568899080000, 'new_status': 'available'},
#    {'timestamp': 1568908560000, 'new_status': 'in-use'},
#    {'timestamp': 1568978820000, 'new_status': 'available'},
#    {'timestamp': 1568980680000, 'new_status': 'in-use'},
#    {'timestamp': 1568998620000, 'new_status': 'available'},
#    {'timestamp': 1569002340000, 'new_status': 'in-use'},
#    {'timestamp': 1569006420000, 'new_status': 'available'},
#    {'timestamp': 1569010800000, 'new_status': 'in-use'},
#    {'timestamp': 1569014820000, 'new_status': 'available'},
#    {'timestamp': 1569071880000, 'new_status': 'in-use'},
#    {'timestamp': 1569078360000, 'new_status': 'available'},
#    {'timestamp': 1569099300000, 'new_status': 'in-use'},
#    {'timestamp': 1569109140000, 'new_status': 'available'},
#    {'timestamp': 1569160320000, 'new_status': 'in-use'},
#    {'timestamp': 1569162840000, 'new_status': 'available'},
#    {'timestamp': 1569237600000, 'new_status': 'in-use'},
#    {'timestamp': 1569247440000, 'new_status': 'available'},
#    {'timestamp': 1569249780000, 'new_status': 'in-use'},
#    {'timestamp': 1569253620000, 'new_status': 'available'},
#    {'timestamp': 1569261000000, 'new_status': 'in-use'},
#    {'timestamp': 1569271680000, 'new_status': 'available'},
#    {'timestamp': 1569399900000, 'new_status': 'in-use'},
#    {'timestamp': 1569411240000, 'new_status': 'available'},
#    {'timestamp': 1569412260000, 'new_status': 'in-use'},
#    {'timestamp': 1569416520000, 'new_status': 'available'},
#    {'timestamp': 1569421800000, 'new_status': 'in-use'},
#    {'timestamp': 1569443760000, 'new_status': 'available'},
#    {'timestamp': 1569486600000, 'new_status': 'in-use'},
#    {'timestamp': 1569519780000, 'new_status': 'available'},
#    {'timestamp': 1569522000000, 'new_status': 'in-use'},
#    {'timestamp': 1569529740000, 'new_status': 'available'},
#    {'timestamp': 1569682020000, 'new_status': 'in-use'},
#    {'timestamp': 1569691440000, 'new_status': 'available'},
#    {'timestamp': 1569770760000, 'new_status': 'in-use'},
#    {'timestamp': 1569778380000, 'new_status': 'available'},
#    {'timestamp': 1569847680000, 'new_status': 'in-use'},
#    {'timestamp': 1569854280000, 'new_status': 'available'},
#    {'timestamp': 1569930420000, 'new_status': 'in-use'},
#    {'timestamp': 1569934860000, 'new_status': 'available'},
#    {'timestamp': 1570005540000, 'new_status': 'in-use'},
#    {'timestamp': 1570012080000, 'new_status': 'available'},
#    {'timestamp': 1570015620000, 'new_status': 'in-use'},
#    {'timestamp': 1570023240000, 'new_status': 'available'},
#    {'timestamp': 1570027560000, 'new_status': 'in-use'},
#    {'timestamp': 1570039500000, 'new_status': 'available'},
#    {'timestamp': 1570043220000, 'new_status': 'in-use'},
#    {'timestamp': 1570047000000, 'new_status': 'available'},
#    {'timestamp': 1570092420000, 'new_status': 'in-use'},
#    {'timestamp': 1570098900000, 'new_status': 'available'},
#    {'timestamp': 1570125000000, 'new_status': 'in-use'},
#    {'timestamp': 1570135680000, 'new_status': 'available'},
#    {'timestamp': 1570181100000, 'new_status': 'in-use'},
#    {'timestamp': 1570190460000, 'new_status': 'available'},
#    {'timestamp': 1570198740000, 'new_status': 'in-use'},
#    {'timestamp': 1570204500000, 'new_status': 'available'},
#    {'timestamp': 1570214880000, 'new_status': 'in-use'},
#    {'timestamp': 1570220040000, 'new_status': 'available'},
#    {'timestamp': 1570296420000, 'new_status': 'in-use'},
#    {'timestamp': 1570310160000, 'new_status': 'available'},
#    {'timestamp': 1570375080000, 'new_status': 'in-use'},
#    {'timestamp': 1570378380000, 'new_status': 'available'},
#    {'timestamp': 1570446060000, 'new_status': 'in-use'},
#    {'timestamp': 1570452180000, 'new_status': 'available'},
#    {'timestamp': 1570457280000, 'new_status': 'in-use'},
#    {'timestamp': 1570468740000, 'new_status': 'available'},
#    {'timestamp': 1570476600000, 'new_status': 'in-use'},
#    {'timestamp': 1570484040000, 'new_status': 'available'},
#    {'timestamp': 1570529340000, 'new_status': 'in-use'},
#    {'timestamp': 1570548360000, 'new_status': 'available'},
#    {'timestamp': 1570616400000, 'new_status': 'in-use'},
#    {'timestamp': 1570624800000, 'new_status': 'available'},
#    {'timestamp': 1570625580000, 'new_status': 'in-use'},
#    {'timestamp': 1570625640000, 'new_status': 'available'},
#    {'timestamp': 1570625700000, 'new_status': 'in-use'},
#    {'timestamp': 1570633680000, 'new_status': 'available'},
#    {'timestamp': 1570705680000, 'new_status': 'in-use'},
#    {'timestamp': 1570717380000, 'new_status': 'available'},
#    {'timestamp': 1570729320000, 'new_status': 'in-use'},
#    {'timestamp': 1570733040000, 'new_status': 'available'},
#    {'timestamp': 1570785780000, 'new_status': 'in-use'},
#    {'timestamp': 1570794720000, 'new_status': 'available'},
#    {'timestamp': 1570796160000, 'new_status': 'in-use'},
#    {'timestamp': 1570799160000, 'new_status': 'available'},
#    {'timestamp': 1570799760000, 'new_status': 'in-use'},
#    {'timestamp': 1570809120000, 'new_status': 'available'},
#    {'timestamp': 1570824660000, 'new_status': 'in-use'},
#    {'timestamp': 1570829280000, 'new_status': 'available'},
#    {'timestamp': 1570895700000, 'new_status': 'in-use'},
#    {'timestamp': 1570902300000, 'new_status': 'available'},
#    {'timestamp': 1570967880000, 'new_status': 'in-use'},
#    {'timestamp': 1570990620000, 'new_status': 'available'},
#    {'timestamp': 1571075520000, 'new_status': 'in-use'},
#    {'timestamp': 1571083920000, 'new_status': 'available'},
#    {'timestamp': 1571128140000, 'new_status': 'in-use'},
#    {'timestamp': 1571143800000, 'new_status': 'available'},
#    {'timestamp': 1571145180000, 'new_status': 'in-use'},
#    {'timestamp': 1571153280000, 'new_status': 'available'},
#    {'timestamp': 1571153460000, 'new_status': 'in-use'},
#    {'timestamp': 1571160240000, 'new_status': 'available'},
#    {'timestamp': 1571226420000, 'new_status': 'in-use'},
#    {'timestamp': 1571236140000, 'new_status': 'available'},
#    {'timestamp': 1571239200000, 'new_status': 'in-use'},
#    {'timestamp': 1571245860000, 'new_status': 'available'},
#    {'timestamp': 1571249880000, 'new_status': 'in-use'},
#    {'timestamp': 1571258040000, 'new_status': 'available'},
#    {'timestamp': 1571300640000, 'new_status': 'in-use'},
#    {'timestamp': 1571312220000, 'new_status': 'available'},
#    {'timestamp': 1571317260000, 'new_status': 'in-use'},
#    {'timestamp': 1571328540000, 'new_status': 'available'},
#    {'timestamp': 1571336220000, 'new_status': 'in-use'},
#    {'timestamp': 1571338920000, 'new_status': 'available'},
#    {'timestamp': 1571394720000, 'new_status': 'in-use'},
#    {'timestamp': 1571410800000, 'new_status': 'available'},
#    {'timestamp': 1571422440000, 'new_status': 'in-use'},
#    {'timestamp': 1571430120000, 'new_status': 'available'},
#    {'timestamp': 1571430660000, 'new_status': 'in-use'},
#    {'timestamp': 1571431560000, 'new_status': 'available'},
#    {'timestamp': 1571483460000, 'new_status': 'in-use'},
#    {'timestamp': 1571487780000, 'new_status': 'available'},
#    {'timestamp': 1571489760000, 'new_status': 'in-use'},
#    {'timestamp': 1571492520000, 'new_status': 'available'},
#    {'timestamp': 1571581380000, 'new_status': 'in-use'},
#    {'timestamp': 1571589120000, 'new_status': 'available'},
#    {'timestamp': 1571593020000, 'new_status': 'in-use'},
#    {'timestamp': 1571600040000, 'new_status': 'available'},
#    {'timestamp': 1571649540000, 'new_status': 'in-use'},
#    {'timestamp': 1571655600000, 'new_status': 'available'},
#    {'timestamp': 1571665320000, 'new_status': 'in-use'},
#    {'timestamp': 1571674500000, 'new_status': 'available'},
#    {'timestamp': 1571743740000, 'new_status': 'in-use'},
#    {'timestamp': 1571752920000, 'new_status': 'available'},
#    {'timestamp': 1571755140000, 'new_status': 'in-use'},
#    {'timestamp': 1571765520000, 'new_status': 'available'},
#    {'timestamp': 1571831280000, 'new_status': 'in-use'},
#    {'timestamp': 1571835480000, 'new_status': 'available'},
#    {'timestamp': 1571838180000, 'new_status': 'in-use'},
#    {'timestamp': 1571848140000, 'new_status': 'available'},
#    {'timestamp': 1571918160000, 'new_status': 'in-use'},
#    {'timestamp': 1571922360000, 'new_status': 'available'},
#    {'timestamp': 1571925000000, 'new_status': 'in-use'},
#    {'timestamp': 1571940660000, 'new_status': 'available'},
#    {'timestamp': 1571942640000, 'new_status': 'in-use'},
#    {'timestamp': 1571947680000, 'new_status': 'available'},
#    {'timestamp': 1571995440000, 'new_status': 'in-use'},
#    {'timestamp': 1571998380000, 'new_status': 'available'},
#    {'timestamp': 1571999100000, 'new_status': 'in-use'},
#    {'timestamp': 1572027060000, 'new_status': 'available'},
#    {'timestamp': 1572029940000, 'new_status': 'in-use'},
#    {'timestamp': 1572037920000, 'new_status': 'available'},
#    {'timestamp': 1572117960000, 'new_status': 'in-use'},
#    {'timestamp': 1572122040000, 'new_status': 'available'},
#    {'timestamp': 1572183420000, 'new_status': 'in-use'},
#    {'timestamp': 1572188400000, 'new_status': 'available'},
#    {'timestamp': 1572260820000, 'new_status': 'in-use'},
#    {'timestamp': 1572271380000, 'new_status': 'available'},
#    {'timestamp': 1572282360000, 'new_status': 'in-use'},
#    {'timestamp': 1572291780000, 'new_status': 'available'},
#    {'timestamp': 1572336420000, 'new_status': 'in-use'},
#    {'timestamp': 1572348540000, 'new_status': 'available'},
#    {'timestamp': 1572369060000, 'new_status': 'in-use'},
#    {'timestamp': 1572376860000, 'new_status': 'available'},
#    {'timestamp': 1572384360000, 'new_status': 'in-use'},
#    {'timestamp': 1572423900000, 'new_status': 'available'},
#    {'timestamp': 1572426780000, 'new_status': 'in-use'},
#    {'timestamp': 1572438600000, 'new_status': 'available'},
#    {'timestamp': 1572444540000, 'new_status': 'in-use'},
#    {'timestamp': 1572462300000, 'new_status': 'available'},
#    {'timestamp': 1572524220000, 'new_status': 'in-use'},
#    {'timestamp': 1572529500000, 'new_status': 'available'},
#    {'timestamp': 1572598980000, 'new_status': 'in-use'},
#    {'timestamp': 1572611100000, 'new_status': 'available'},
#    {'timestamp': 1572617520000, 'new_status': 'in-use'},
#    {'timestamp': 1572623160000, 'new_status': 'available'},
#    {'timestamp': 1572630660000, 'new_status': 'in-use'},
#    {'timestamp': 1572637620000, 'new_status': 'available'},
#    {'timestamp': 1572639540000, 'new_status': 'in-use'},
#    {'timestamp': 1572649860000, 'new_status': 'available'},
#    {'timestamp': 1572705900000, 'new_status': 'in-use'},
#    {'timestamp': 1572708540000, 'new_status': 'available'},
#    {'timestamp': 1572718620000, 'new_status': 'in-use'},
#    {'timestamp': 1572738000000, 'new_status': 'available'},
#    {'timestamp': 1572807120000, 'new_status': 'in-use'},
#    {'timestamp': 1572810780000, 'new_status': 'available'},
#    {'timestamp': 1572859140000, 'new_status': 'in-use'},
#    {'timestamp': 1572862920000, 'new_status': 'available'},
#    {'timestamp': 1572864540000, 'new_status': 'in-use'},
#    {'timestamp': 1572874800000, 'new_status': 'available'},
#    {'timestamp': 1572893040000, 'new_status': 'in-use'},
#    {'timestamp': 1572897780000, 'new_status': 'available'},
#    {'timestamp': 1572946980000, 'new_status': 'in-use'},
#    {'timestamp': 1572981780000, 'new_status': 'available'},
#    {'timestamp': 1573032240000, 'new_status': 'in-use'},
#    {'timestamp': 1573052100000, 'new_status': 'available'},
#    {'timestamp': 1573115760000, 'new_status': 'in-use'},
#    {'timestamp': 1573126920000, 'new_status': 'available'},
#    {'timestamp': 1573127100000, 'new_status': 'in-use'},
#    {'timestamp': 1573142520000, 'new_status': 'available'},
#    {'timestamp': 1573200480000, 'new_status': 'in-use'},
#    {'timestamp': 1573212180000, 'new_status': 'available'},
#    {'timestamp': 1573212840000, 'new_status': 'in-use'},
#    {'timestamp': 1573212960000, 'new_status': 'in-use'},
#    {'timestamp': 1573212960000, 'new_status': 'available'},
#    {'timestamp': 1573213980000, 'new_status': 'in-use'},
#    {'timestamp': 1573217940000, 'new_status': 'available'},
#    {'timestamp': 1573224300000, 'new_status': 'available'},
#    {'timestamp': 1573226940000, 'new_status': 'in-use'},
#    {'timestamp': 1573233360000, 'new_status': 'available'},
#    {'timestamp': 1573236960000, 'new_status': 'in-use'},
#    {'timestamp': 1573244760000, 'new_status': 'available'},
#    {'timestamp': 1573314780000, 'new_status': 'in-use'},
#    {'timestamp': 1573321980000, 'new_status': 'available'},
#    {'timestamp': 1573328940000, 'new_status': 'in-use'},
#    {'timestamp': 1573334880000, 'new_status': 'available'},
#    {'timestamp': 1573388580000, 'new_status': 'in-use'},
#    {'timestamp': 1573395300000, 'new_status': 'available'},
#    {'timestamp': 1573397400000, 'new_status': 'in-use'},
#    {'timestamp': 1573399920000, 'new_status': 'available'},
#    {'timestamp': 1573459680000, 'new_status': 'in-use'},
#    {'timestamp': 1573470840000, 'new_status': 'available'},
#    {'timestamp': 1573473540000, 'new_status': 'in-use'},
#    {'timestamp': 1573480560000, 'new_status': 'available'},
#    {'timestamp': 1573481460000, 'new_status': 'in-use'},
#    {'timestamp': 1573489080000, 'new_status': 'available'},
#    {'timestamp': 1573501500000, 'new_status': 'in-use'},
#    {'timestamp': 1573506480000, 'new_status': 'available'},
#    {'timestamp': 1573557720000, 'new_status': 'in-use'},
#    {'timestamp': 1573570200000, 'new_status': 'available'},
#    {'timestamp': 1573572840000, 'new_status': 'in-use'},
#    {'timestamp': 1573582500000, 'new_status': 'available'},
#    {'timestamp': 1573637640000, 'new_status': 'in-use'},
#    {'timestamp': 1573652100000, 'new_status': 'available'},
#    {'timestamp': 1573667280000, 'new_status': 'in-use'},
#    {'timestamp': 1573673460000, 'new_status': 'available'},
#    {'timestamp': 1573716840000, 'new_status': 'in-use'},
#    {'timestamp': 1573721160000, 'new_status': 'available'},
#    {'timestamp': 1573727280000, 'new_status': 'in-use'},
#    {'timestamp': 1573735200000, 'new_status': 'available'},
#    {'timestamp': 1573736940000, 'new_status': 'in-use'},
#    {'timestamp': 1573747980000, 'new_status': 'available'},
#    {'timestamp': 1573757820000, 'new_status': 'in-use'},
#    {'timestamp': 1573762980000, 'new_status': 'available'},
#    {'timestamp': 1573817760000, 'new_status': 'in-use'},
#    {'timestamp': 1573828980000, 'new_status': 'available'},
#    {'timestamp': 1573830600000, 'new_status': 'in-use'},
#    {'timestamp': 1573838280000, 'new_status': 'available'},
#    {'timestamp': 1573840440000, 'new_status': 'in-use'},
#    {'timestamp': 1573846740000, 'new_status': 'available'},
#    {'timestamp': 1573914060000, 'new_status': 'in-use'},
#    {'timestamp': 1573917420000, 'new_status': 'available'},
#    {'timestamp': 1573931640000, 'new_status': 'in-use'},
#    {'timestamp': 1573941780000, 'new_status': 'available'},
#    {'timestamp': 1573982340000, 'new_status': 'in-use'},
#    {'timestamp': 1573985940000, 'new_status': 'available'},
#    {'timestamp': 1573988520000, 'new_status': 'in-use'},
#    {'timestamp': 1573993740000, 'new_status': 'available'},
#    {'timestamp': 1574065860000, 'new_status': 'in-use'},
#    {'timestamp': 1574076060000, 'new_status': 'available'},
#    {'timestamp': 1574077440000, 'new_status': 'in-use'},
#    {'timestamp': 1574083320000, 'new_status': 'available'},
#    {'timestamp': 1574084160000, 'new_status': 'in-use'},
#    {'timestamp': 1574091900000, 'new_status': 'available'},
#    {'timestamp': 1574099520000, 'new_status': 'in-use'},
#    {'timestamp': 1574110200000, 'new_status': 'available'},
#    {'timestamp': 1574153760000, 'new_status': 'in-use'},
#    {'timestamp': 1574163840000, 'new_status': 'available'},
#    {'timestamp': 1574164500000, 'new_status': 'in-use'},
#    {'timestamp': 1574174040000, 'new_status': 'available'},
#    {'timestamp': 1574239980000, 'new_status': 'in-use'},
#    {'timestamp': 1574250540000, 'new_status': 'available'},
#    {'timestamp': 1574275740000, 'new_status': 'in-use'},
#    {'timestamp': 1574322660000, 'new_status': 'available'},
#    {'timestamp': 1574323860000, 'new_status': 'in-use'},
#    {'timestamp': 1574337300000, 'new_status': 'available'},
#    {'timestamp': 1574362140000, 'new_status': 'in-use'},
#    {'timestamp': 1574369400000, 'new_status': 'available'},
#    {'timestamp': 1574410740000, 'new_status': 'in-use'},
#    {'timestamp': 1574412780000, 'new_status': 'available'},
#    {'timestamp': 1574413740000, 'new_status': 'in-use'},
#    {'timestamp': 1574442120000, 'new_status': 'available'},
#    {'timestamp': 1574449440000, 'new_status': 'in-use'},
#    {'timestamp': 1574454420000, 'new_status': 'available'},
#    {'timestamp': 1574513760000, 'new_status': 'in-use'},
#    {'timestamp': 1574527260000, 'new_status': 'available'},
#    {'timestamp': 1574604840000, 'new_status': 'in-use'},
#    {'timestamp': 1574610780000, 'new_status': 'available'},
#    {'timestamp': 1574670480000, 'new_status': 'in-use'},
#    {'timestamp': 1574680860000, 'new_status': 'available'},
#    {'timestamp': 1574681040000, 'new_status': 'in-use'},
#    {'timestamp': 1574689320000, 'new_status': 'available'},
#    {'timestamp': 1574712300000, 'new_status': 'in-use'},
#    {'timestamp': 1574713980000, 'new_status': 'available'},
#    {'timestamp': 1574758500000, 'new_status': 'in-use'},
#    {'timestamp': 1574773560000, 'new_status': 'available'},
#    {'timestamp': 1574774280000, 'new_status': 'in-use'},
#    {'timestamp': 1574792160000, 'new_status': 'available'},
#    {'timestamp': 1574795460000, 'new_status': 'in-use'},
#    {'timestamp': 1574795760000, 'new_status': 'available'},
#    {'timestamp': 1574798160000, 'new_status': 'in-use'},
#    {'timestamp': 1574800080000, 'new_status': 'available'},
#    {'timestamp': 1574855340000, 'new_status': 'in-use'},
#    {'timestamp': 1574857140000, 'new_status': 'available'},
#    {'timestamp': 1574863320000, 'new_status': 'in-use'},
#    {'timestamp': 1574866440000, 'new_status': 'available'},
#    {'timestamp': 1574874000000, 'new_status': 'in-use'},
#    {'timestamp': 1574883180000, 'new_status': 'available'},
#    {'timestamp': 1575019200000, 'new_status': 'in-use'},
#    {'timestamp': 1575031140000, 'new_status': 'available'},
#    {'timestamp': 1575055860000, 'new_status': 'in-use'},
#    {'timestamp': 1575058800000, 'new_status': 'available'},
#    {'timestamp': 1575114660000, 'new_status': 'in-use'},
#    {'timestamp': 1575122460000, 'new_status': 'available'},
#    {'timestamp': 1575277260000, 'new_status': 'in-use'},
#    {'timestamp': 1575281280000, 'new_status': 'available'},
#    {'timestamp': 1575298020000, 'new_status': 'in-use'},
#    {'timestamp': 1575307740000, 'new_status': 'available'},
#    {'timestamp': 1575366720000, 'new_status': 'in-use'},
#    {'timestamp': 1575396480000, 'new_status': 'available'},
#    {'timestamp': 1575458760000, 'new_status': 'in-use'},
#    {'timestamp': 1575464100000, 'new_status': 'available'},
#    {'timestamp': 1575466740000, 'new_status': 'in-use'},
#    {'timestamp': 1575477420000, 'new_status': 'available'},
#    {'timestamp': 1575486060000, 'new_status': 'in-use'},
#    {'timestamp': 1575490440000, 'new_status': 'available'},
#    {'timestamp': 1575536640000, 'new_status': 'in-use'},
#    {'timestamp': 1575550860000, 'new_status': 'available'},
#    {'timestamp': 1575552120000, 'new_status': 'in-use'},
#    {'timestamp': 1575563640000, 'new_status': 'available'},
#    {'timestamp': 1575565620000, 'new_status': 'in-use'},
#    {'timestamp': 1575579300000, 'new_status': 'available'},
#    {'timestamp': 1575628200000, 'new_status': 'in-use'},
#    {'timestamp': 1575641280000, 'new_status': 'available'},
#    {'timestamp': 1575643620000, 'new_status': 'in-use'},
#    {'timestamp': 1575646080000, 'new_status': 'available'},
#    {'timestamp': 1575658020000, 'new_status': 'in-use'},
#    {'timestamp': 1575662160000, 'new_status': 'available'},
#    {'timestamp': 1575747180000, 'new_status': 'in-use'},
#    {'timestamp': 1575751200000, 'new_status': 'available'},
#    {'timestamp': 1575823440000, 'new_status': 'in-use'},
#    {'timestamp': 1575832080000, 'new_status': 'available'},
#    {'timestamp': 1575877980000, 'new_status': 'in-use'},
#    {'timestamp': 1575879120000, 'new_status': 'available'},
#    {'timestamp': 1575880380000, 'new_status': 'in-use'},
#    {'timestamp': 1575891600000, 'new_status': 'available'},
#    {'timestamp': 1575894720000, 'new_status': 'in-use'},
#    {'timestamp': 1575899100000, 'new_status': 'available'},
#    {'timestamp': 1575899220000, 'new_status': 'in-use'},
#    {'timestamp': 1575914940000, 'new_status': 'available'},
#    {'timestamp': 1575977100000, 'new_status': 'in-use'},
#    {'timestamp': 1575995280000, 'new_status': 'available'},
#    {'timestamp': 1576002840000, 'new_status': 'in-use'},
#    {'timestamp': 1576008360000, 'new_status': 'available'},
#    {'timestamp': 1576059300000, 'new_status': 'in-use'},
#    {'timestamp': 1576068960000, 'new_status': 'available'},
#    {'timestamp': 1576088040000, 'new_status': 'in-use'},
#    {'timestamp': 1576091580000, 'new_status': 'available'},
#    {'timestamp': 1576092540000, 'new_status': 'in-use'},
#    {'timestamp': 1576093920000, 'new_status': 'available'},
#    {'timestamp': 1576148520000, 'new_status': 'in-use'},
#    {'timestamp': 1576156500000, 'new_status': 'available'},
#    {'timestamp': 1576157580000, 'new_status': 'in-use'},
#    {'timestamp': 1576179240000, 'new_status': 'available'},
#    {'timestamp': 1576224300000, 'new_status': 'in-use'},
#    {'timestamp': 1576227480000, 'new_status': 'available'},
#    {'timestamp': 1576235700000, 'new_status': 'in-use'},
#    {'timestamp': 1576262820000, 'new_status': 'available'},
#    {'timestamp': 1576329600000, 'new_status': 'in-use'},
#    {'timestamp': 1576338840000, 'new_status': 'available'},
#    {'timestamp': 1576406640000, 'new_status': 'in-use'},
#    {'timestamp': 1576419120000, 'new_status': 'available'},
#    {'timestamp': 1576488120000, 'new_status': 'in-use'},
#    {'timestamp': 1576490640000, 'new_status': 'available'},
#    {'timestamp': 1576490700000, 'new_status': 'in-use'},
#    {'timestamp': 1576496280000, 'new_status': 'available'},
#    {'timestamp': 1576499400000, 'new_status': 'in-use'},
#    {'timestamp': 1576515120000, 'new_status': 'available'},
#    {'timestamp': 1576517400000, 'new_status': 'in-use'},
#    {'timestamp': 1576523520000, 'new_status': 'available'},
#    {'timestamp': 1576576260000, 'new_status': 'in-use'},
#    {'timestamp': 1576578120000, 'new_status': 'available'},
#    {'timestamp': 1576579080000, 'new_status': 'in-use'},
#    {'timestamp': 1576585380000, 'new_status': 'available'},
#    {'timestamp': 1576587240000, 'new_status': 'in-use'},
#    {'timestamp': 1576596360000, 'new_status': 'available'},
#    {'timestamp': 1576596600000, 'new_status': 'in-use'},
#    {'timestamp': 1576605720000, 'new_status': 'available'},
#    {'timestamp': 1576606500000, 'new_status': 'in-use'},
#    {'timestamp': 1576616220000, 'new_status': 'available'},
#    {'timestamp': 1576665540000, 'new_status': 'in-use'},
#    {'timestamp': 1576675680000, 'new_status': 'available'},
#    {'timestamp': 1576677180000, 'new_status': 'in-use'},
#    {'timestamp': 1576681620000, 'new_status': 'available'},
#    {'timestamp': 1576682400000, 'new_status': 'in-use'},
#    {'timestamp': 1576691640000, 'new_status': 'available'},
#    {'timestamp': 1576692000000, 'new_status': 'in-use'},
#    {'timestamp': 1576697100000, 'new_status': 'available'},
#    {'timestamp': 1576745820000, 'new_status': 'in-use'},
#    {'timestamp': 1576748520000, 'new_status': 'available'},
#    {'timestamp': 1576748640000, 'new_status': 'in-use'},
#    {'timestamp': 1576754700000, 'new_status': 'available'},
#    {'timestamp': 1576756380000, 'new_status': 'in-use'},
#    {'timestamp': 1576764900000, 'new_status': 'available'},
#    {'timestamp': 1576766700000, 'new_status': 'in-use'},
#    {'timestamp': 1576770360000, 'new_status': 'available'},
#    {'timestamp': 1576828860000, 'new_status': 'in-use'},
#    {'timestamp': 1576839840000, 'new_status': 'available'},
#    {'timestamp': 1576843320000, 'new_status': 'in-use'},
#    {'timestamp': 1576849380000, 'new_status': 'available'},
#    {'timestamp': 1576867800000, 'new_status': 'in-use'},
#    {'timestamp': 1576877340000, 'new_status': 'available'},
#    {'timestamp': 1577016600000, 'new_status': 'in-use'},
#    {'timestamp': 1577025360000, 'new_status': 'available'},
#    {'timestamp': 1577032260000, 'new_status': 'in-use'},
#    {'timestamp': 1577040600000, 'new_status': 'available'},
#    {'timestamp': 1577094660000, 'new_status': 'in-use'},
#    {'timestamp': 1577100840000, 'new_status': 'available'},
#    {'timestamp': 1577106420000, 'new_status': 'in-use'},
#    {'timestamp': 1577113320000, 'new_status': 'available'},
#    {'timestamp': 1577123460000, 'new_status': 'in-use'},
#    {'timestamp': 1577129640000, 'new_status': 'available'},
#    {'timestamp': 1577159220000, 'new_status': 'in-use'},
#    {'timestamp': 1577160000000, 'new_status': 'available'},
#    {'timestamp': 1577160060000, 'new_status': 'in-use'},
#    {'timestamp': 1577171520000, 'new_status': 'available'},
#    {'timestamp': 1577213340000, 'new_status': 'in-use'},
#    {'timestamp': 1577217840000, 'new_status': 'available'},
#    {'timestamp': 1577365020000, 'new_status': 'in-use'},
#    {'timestamp': 1577370420000, 'new_status': 'available'},
#    {'timestamp': 1577386920000, 'new_status': 'in-use'},
#    {'timestamp': 1577392980000, 'new_status': 'available'},
#    {'timestamp': 1577457480000, 'new_status': 'in-use'},
#    {'timestamp': 1577464200000, 'new_status': 'available'},
#    {'timestamp': 1577613120000, 'new_status': 'in-use'},
#    {'timestamp': 1577621640000, 'new_status': 'available'},
#    {'timestamp': 1577631540000, 'new_status': 'in-use'},
#    {'timestamp': 1577645760000, 'new_status': 'available'},
#    {'timestamp': 1577791320000, 'new_status': 'in-use'},
#    {'timestamp': 1577801520000, 'new_status': 'available'},
#    {'timestamp': 1577956260000, 'new_status': 'in-use'},
#    {'timestamp': 1577965020000, 'new_status': 'available'},
#    {'timestamp': 1577966400000, 'new_status': 'in-use'},
#    {'timestamp': 1577971140000, 'new_status': 'available'},
#    {'timestamp': 1577971380000, 'new_status': 'in-use'},
#    {'timestamp': 1577980020000, 'new_status': 'available'},
#    {'timestamp': 1578049440000, 'new_status': 'in-use'},
#    {'timestamp': 1578052200000, 'new_status': 'available'},
#    {'timestamp': 1578052380000, 'new_status': 'in-use'},
#    {'timestamp': 1578056700000, 'new_status': 'available'},
#    {'timestamp': 1578138480000, 'new_status': 'in-use'},
#    {'timestamp': 1578146940000, 'new_status': 'available'},
#    {'timestamp': 1578147120000, 'new_status': 'in-use'},
#    {'timestamp': 1578149700000, 'new_status': 'available'},
#    {'timestamp': 1578163860000, 'new_status': 'in-use'},
#    {'timestamp': 1578166500000, 'new_status': 'available'},
#    {'timestamp': 1578297960000, 'new_status': 'in-use'},
#    {'timestamp': 1578308580000, 'new_status': 'available'},
#    {'timestamp': 1578315780000, 'new_status': 'in-use'},
#    {'timestamp': 1578327000000, 'new_status': 'available'},
#    {'timestamp': 1578332820000, 'new_status': 'in-use'},
#    {'timestamp': 1578343560000, 'new_status': 'available'},
#    {'timestamp': 1578387780000, 'new_status': 'in-use'},
#    {'timestamp': 1578402180000, 'new_status': 'available'},
#    {'timestamp': 1578402540000, 'new_status': 'in-use'},
#    {'timestamp': 1578413400000, 'new_status': 'available'},
#    {'timestamp': 1578479700000, 'new_status': 'in-use'},
#    {'timestamp': 1578491640000, 'new_status': 'available'},
#    {'timestamp': 1578561240000, 'new_status': 'in-use'},
#    {'timestamp': 1578572340000, 'new_status': 'available'},
#    {'timestamp': 1578572400000, 'new_status': 'in-use'},
#    {'timestamp': 1578578820000, 'new_status': 'available'},
#    {'timestamp': 1578579060000, 'new_status': 'in-use'},
#    {'timestamp': 1578593760000, 'new_status': 'available'},
#    {'timestamp': 1578593880000, 'new_status': 'in-use'},
#    {'timestamp': 1578610020000, 'new_status': 'available'},
#    {'timestamp': 1578654780000, 'new_status': 'in-use'},
#    {'timestamp': 1578665340000, 'new_status': 'available'},
#    {'timestamp': 1578668820000, 'new_status': 'in-use'},
#    {'timestamp': 1578678540000, 'new_status': 'available'},
#    {'timestamp': 1578686520000, 'new_status': 'in-use'},
#    {'timestamp': 1578693300000, 'new_status': 'available'},
#    {'timestamp': 1578750480000, 'new_status': 'in-use'},
#    {'timestamp': 1578760860000, 'new_status': 'available'},
#    {'timestamp': 1578829080000, 'new_status': 'in-use'},
#    {'timestamp': 1578833520000, 'new_status': 'available'},
#    {'timestamp': 1578856020000, 'new_status': 'in-use'},
#    {'timestamp': 1578858540000, 'new_status': 'available'},
#    {'timestamp': 1578905520000, 'new_status': 'in-use'},
#    {'timestamp': 1578915060000, 'new_status': 'available'},
#    {'timestamp': 1578915960000, 'new_status': 'in-use'},
#    {'timestamp': 1578921420000, 'new_status': 'available'},
#    {'timestamp': 1578922320000, 'new_status': 'in-use'},
#    {'timestamp': 1578933480000, 'new_status': 'available'},
#    {'timestamp': 1579000560000, 'new_status': 'in-use'},
#    {'timestamp': 1579005240000, 'new_status': 'available'},
#    {'timestamp': 1579010100000, 'new_status': 'in-use'},
#    {'timestamp': 1579015920000, 'new_status': 'available'},
#    {'timestamp': 1579025880000, 'new_status': 'in-use'},
#    {'timestamp': 1579041180000, 'new_status': 'available'},
#    ...]}]

# %%
# Define batch size
batch_size = 10 

# Insert documents in batches
try:
    for i in range(0, len(sorted_evse_docs), batch_size):
        batch = sorted_evse_docs[i:i+batch_size]
        evse_status.insert_many(batch)
        print(f"Processed {i + len(batch)} out of {len(sorted_evse_docs)} records successfully.")
        time.sleep(1)  # Optional: add a short delay to reduce system load (if necessary)
except Exception as e:
    print("Failed to bulk insert into evse_status:", e)

print("All documents have been inserted successfully.")
# Out:
# Processed 10 out of 48 records successfully.
# Processed 20 out of 48 records successfully.
# Processed 30 out of 48 records successfully.
# Processed 40 out of 48 records successfully.
# Processed 48 out of 48 records successfully.
# All documents have been inserted successfully.

# %% [markdown]
# # Process Stations Data

# %%
# Read the CSV file into a dataframe
stations_file_path = 'data/g6stations.csv'
s_df = pd.read_csv(stations_file_path)

# Handle missing values (NaN) in the dataframe
s_df = s_df.fillna('')

# Print the dataframe
print(s_df.shape[0])
for column in s_df.columns.tolist():
    print(column)

# %%
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Print the dataframe
print(s_df.shape[0])
# Assuming your dataframe is named df and the relevant columns are 'Street Address', 'City', and 'State'
grouped = s_df.groupby(['Street Address', 'City', 'State']).size()

# DataFrame with counts
counts_df = grouped.reset_index(name='Count')

# Addresses with only one entry
single_entry_addresses = counts_df[counts_df['Count'] == 1]

# Addresses with multiple entries
multiple_entries_addresses = counts_df[counts_df['Count'] > 1]

# Count unique Latitude and Longitude combinations
lat_lons = s_df.groupby(['Latitude', 'Longitude']).ngroups

# Display the results
print(f"Number of addresses with a single entry: {len(single_entry_addresses)}")
print(f"Number of addresses with multiple entries: {len(multiple_entries_addresses)}")
print(f"Number of unique lat-lons: {lat_lons}")

# %%
# Remove Palo Alto stations because they are already accounted for
s_df = s_df[~s_df['ZIP'].between(94301, 94306)]

# %%
# Print the dataframe
print(s_df.shape[0])
# Assuming your dataframe is named df and the relevant columns are 'Street Address', 'City', and 'State'
grouped = s_df.groupby(['Street Address', 'City', 'State']).size()

# DataFrame with counts
counts_df = grouped.reset_index(name='Count')

# Addresses with only one entry
single_entry_addresses = counts_df[counts_df['Count'] == 1]

# Addresses with multiple entries
multiple_entries_addresses = counts_df[counts_df['Count'] > 1]

# Count unique Latitude and Longitude combinations
lat_lons = s_df.groupby(['Latitude', 'Longitude']).ngroups

# Display the results
print(f"Number of addresses with a single entry: {len(single_entry_addresses)}")
print(f"Number of addresses with multiple entries: {len(multiple_entries_addresses)}")
print(f"Number of unique lat-lons: {lat_lons}")
